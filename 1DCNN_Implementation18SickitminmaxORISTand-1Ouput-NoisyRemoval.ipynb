# %% [markdown]
# # ResNet Model Building Pipeline for 1D Signals with DEMO
# #### ResNet18, ResNet34, ResNet50, ResNet101, ResNet152

# %%
import socket
import tornado.iostream

# Create a TCP connection to a server running on localhost at port 8000
sock = socket.create_connection(('localhost', 8888))

# Create an IOStream object with a large buffer size
stream = tornado.iostream.IOStream(sock, max_buffer_size=1073741824)

# %% [markdown]
# Build Model

# %%
# class AdamW(Adam):
#     def __init__(self, learning_rate=0.0001, weight_decay=0.01, **kwargs):
#         super(AdamW, self).__init__(learning_rate, **kwargs)
#         self.weight_decay = weight_decay

#     def get_gradients(self, loss, params):
#         gradients = super(AdamW, self).get_gradients(loss, params)
#         if self.weight_decay > 0.0:
#             for i in range(len(gradients)):
#                 if gradients[i] is not None:
#                     gradients[i] += self.weight_decay * params[i]
#         return gradients

# Regression_Model = ResNet(length, num_channel, model_width, problem_type=problem_type, output_nums=output_number).ResNet18() # Build Model
# # ResNet Models supported: ResNet18, ResNet34, ResNet50, ResNet101, ResNet152, 
# Regression_Model.compile(loss='mse', optimizer=AdamW(learning_rate=0.0001, weight_decay=0.01), metrics= ['mse']) # Compile Model
# # Here, Model validation metric is set as Mean Squared Error or MSE

# %% [markdown]
# Model_Summary

# %%
import numpy as np
import pandas as pd
# import seaborn as sns
from numpy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Conv2D, MaxPooling2D, Reshape, Flatten, Dense
from keras.models import Model, model_from_json
from keras.optimizers import Adam, RMSprop
# from tensorflow.keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import Normalizer,MinMaxScaler,StandardScaler, RobustScaler, QuantileTransformer, PowerTransformer
# sns.set_theme(style="whitegrid")
import pywt
np.set_printoptions(suppress=True)
# Import ResNet1D Module
from ResNet_12DCNN import ResNet
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error, r2_score

def seed_everything(seed=42):
    np.random.seed(seed)
    tf.random.set_seed(seed)

columns = ['Fx']
wavelet = 'db4'
max_iter = 50
iter = 0

# Training Process
Insole = pd.read_csv('0310AyuStand5Min1.txt', header=None, low_memory=False)
SIData =  np.asarray(Insole)

df = pd.read_csv('0310AyuStand5Min1.csv', low_memory=False)
selected_df = df[columns]
FPDatas = selected_df[:]

SmartInsole = np.array(SIData).astype('float64')
FPData = np.array(FPDatas).astype('float64')

# SIDWTcoeffs = []
# for i in range(89):
#     coeffs = pywt.wavedec(SmartInsole[:, i], wavelet)
#     coeffs[-1] = np.zeros_like(coeffs[-1])
# #     coeffs[-2] = np.zeros_like(coeffs[-2])
# #     coeffs[-3] = np.zeros_like(coeffs[-3])
# #     coeffs[-4] = np.zeros_like(coeffs[-4])
# #     coeffs[-5] = np.zeros_like(coeffs[-5])
# #     coeffs[-6] = np.zeros_like(coeffs[-6])
#     SIDWTcoeffs.append(coeffs)

# SIData_filtered = np.zeros(SmartInsole.shape)
# for i in range(89):
#     SIData_filtered[:, i] = pywt.waverec(SIDWTcoeffs[i], wavelet, mode='symmetric', axis=0)

max_iter = 50
iter = 0
for i in range(len(SmartInsole)):
    SmartInsole[i][0] = SmartInsole[i][0] + (iter % max_iter) + 1
    iter += 1

# Scale the smart insole data
minInsole = SmartInsole.min()
maxInsole = SmartInsole.max()
smart_insole_data_scaled = (SmartInsole - minInsole) / ( maxInsole - minInsole )

# Scale the force plate data
minForcePlate = FPData.min()
maxForcePlate = FPData.max()
force_plate_data_scaled = (FPData - minForcePlate) / ( maxForcePlate - minForcePlate )


#Spliting Data
sample_size = smart_insole_data_scaled.shape[0] # number of samples in train set
time_steps  = smart_insole_data_scaled.shape[1] # number of features in train set
input_dimension = 1               # each feature is represented by 1 number

train_data_reshaped = smart_insole_data_scaled.reshape(sample_size,time_steps,input_dimension)

# X_train, X_test, y_train, y_test = train_test_split(train_data_reshaped[:13000],
#                                                     force_plate_data_scaled[:13000],
#                                                     test_size=0.20, random_state=2)

smart_insole_data_scaled_Train = smart_insole_data_scaled[:13000]
smart_insole_data_scaled_Test = smart_insole_data_scaled[13000:]
force_plate_data_scaled_Train = force_plate_data_scaled[:13000]
force_plate_data_scaled_Test = force_plate_data_scaled[13000:]

# seed_everything(42)
# Generate random indices for shuffling the data
indices = np.arange(smart_insole_data_scaled_Train.shape[0])
np.random.shuffle(indices)

# Use the shuffled indices to randomly select training data
X_train = smart_insole_data_scaled_Train[indices]
y_train = force_plate_data_scaled_Train[indices]

Test_indices = np.arange(smart_insole_data_scaled_Test.shape[0])
np.random.shuffle(Test_indices)

# # Assign the test data
X_test = smart_insole_data_scaled_Test[Test_indices]
y_test = force_plate_data_scaled_Test[Test_indices]

print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)

"Configurations for ResNet in Regression Mode"
length = X_train.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

Regression_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet18()
Regression_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

Regression_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('Saved_Model.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, shuffle=True)

plt.figure()
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
Regression_Model.evaluate(X_train, y_train)
ypred = Regression_Model.predict(X_train)

print('MSE: ',mean_squared_error(y_train, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_train, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_train, ypred))

# # Inverse transform the predictions and actual values
y_pred = (ypred * (maxForcePlate - minForcePlate)) + minForcePlate
y_real = (y_train * (maxForcePlate - minForcePlate)) + minForcePlate

# y_pred = y_pred[np.argsort(indices)]
# y_real = y_real[np.argsort(indices)]

print('MSE: ',mean_squared_error(y_real, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_real, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real, ypred))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real[0:3000,i],color='red')
    plt.plot(x,y_pred[0:3000,i], markerfacecolor='none',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(Regression_Model, '1ouput.h5')
#End Training Process

# Load Model to Predict Real Data
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(X_test, y_test)
Test_Pred = modelCoy.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred))

predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
Real = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions = predictions[np.argsort(Test_indices)]
Real = Real[np.argsort(Test_indices)]

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:2000,i],color='red')
    plt.plot(x,predictions[0:2000,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()
# Out:
# (13000, 89) (2000, 89)
# (13000, 1) (2000, 1)
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 89, 1)]      0           []
#
#  conv1d_17 (Conv1D)             (None, 45, 64)       512         ['input_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 45, 64)      256         ['conv1d_17[0][0]']
#  alization)
#
#  activation_22 (Activation)     (None, 45, 64)       0           ['batch_normalization[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 22, 64)      0           ['activation_22[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 22, 64)       12352       ['max_pooling1d_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 22, 64)      256         ['conv1d_18[0][0]']
#  rmalization)
#
# ...

# %%
# # Step 3: Calculate the loss
# loss_values = np.mean((y_pred - y_real) ** 2, axis=1)  # Using mean squared error as an example

# # Step 4: Rank the loss results
# sorted_indices = np.argsort(loss_values)[::-1]  # Sort loss values in descending order
# sorted_loss_values = loss_values[sorted_indices]

# # Step 5: Set a threshold
# threshold = np.percentile(sorted_loss_values, 10)  # Set the threshold to remove top 10% of examples

# # Step 6: Remove data based on the threshold
# filtered_data = np.delete(X_train, sorted_indices[sorted_loss_values > threshold], axis=0)
# filtered_labels = np.delete(y_train, sorted_indices[sorted_loss_values > threshold], axis=0)

# %%
# min(loss_values)

# %%
# # Step 3: Calculate the loss
# loss_values = np.mean((y_pred - y_real) ** 2, axis=1)  # Using mean squared error as an example

# # Step 4: Rank the loss results in ascending order
# sorted_indices = np.argsort(loss_values)  # Sort loss values in ascending order
# sorted_loss_values = loss_values[sorted_indices]

# # Step 5: Set a threshold
# threshold = np.percentile(sorted_loss_values, 70)  # Set the threshold to remove the last 10% of examples

# # Step 6: Remove data based on the threshold
# filtered_data = np.delete(X_train, sorted_indices[sorted_loss_values > threshold], axis=0)
# filtered_labels = np.delete(y_train, sorted_indices[sorted_loss_values > threshold], axis=0)

# %%
# Step 3: Calculate the loss
loss_values = np.mean((y_pred - y_real) ** 2, axis=1)  # Using mean squared error as an example
rmse_loss_values = np.sqrt(loss_values)  # Root Mean Squared Error


# Step 4: Rank the loss results in ascending order
# sorted_indices = np.argsort(loss_values)  # Sort loss values in ascending order
sorted_indices = np.argsort(rmse_loss_values)  # Sort loss values in ascending order
sorted_loss_values = loss_values[sorted_indices]

# Step 5: Set a threshold
thresholdonepercent = np.percentile(sorted_loss_values, 99)  # Set the threshold to remove the last 1% of examples
thresholdfivepercent = np.percentile(sorted_loss_values, 95)  # Set the threshold to remove the last 1% of examples
thresholdtenpercent = np.percentile(sorted_loss_values, 90)  # Set the threshold to remove the last 1% of examples
thresholdfivetenpercent = np.percentile(sorted_loss_values, 85)  # Set the threshold to remove the last 1% of examples
thresholdtwentypercent = np.percentile(sorted_loss_values, 80)  # Set the threshold to remove the last 1% of examples
thresholdtwentyfivepercent = np.percentile(sorted_loss_values, 75)  # Set the threshold to remove the last 1% of examples
thresholdthirtypercent = np.percentile(sorted_loss_values, 70)  # Set the threshold to remove the last 1% of examples

# Step 6: Remove data based on the threshold
filtered_data_one_percent = np.delete(X_train, sorted_indices[sorted_loss_values > thresholdonepercent], axis=0)
filtered_labels_one_percent = np.delete(y_train, sorted_indices[sorted_loss_values > thresholdonepercent], axis=0)

filtered_data_five_percent = np.delete(X_train, sorted_indices[sorted_loss_values > thresholdfivepercent], axis=0)
filtered_labels_five_percent = np.delete(y_train, sorted_indices[sorted_loss_values > thresholdfivepercent], axis=0)

filtered_data_ten_percent = np.delete(X_train, sorted_indices[sorted_loss_values > thresholdtenpercent], axis=0)
filtered_labels_ten_percent = np.delete(y_train, sorted_indices[sorted_loss_values > thresholdtenpercent], axis=0)

filtered_data_fiveten_percent = np.delete(X_train, sorted_indices[sorted_loss_values > thresholdfivetenpercent], axis=0)
filtered_labels_fiveten_percent = np.delete(y_train, sorted_indices[sorted_loss_values > thresholdfivetenpercent], axis=0)

filtered_data_twenty_percent = np.delete(X_train, sorted_indices[sorted_loss_values > thresholdtwentypercent], axis=0)
filtered_labels_twenty_percent = np.delete(y_train, sorted_indices[sorted_loss_values > thresholdtwentypercent], axis=0)

filtered_data_twentyfive_percent = np.delete(X_train, sorted_indices[sorted_loss_values > thresholdtwentyfivepercent], axis=0)
filtered_labels_twentyfive_percent = np.delete(y_train, sorted_indices[sorted_loss_values > thresholdtwentyfivepercent], axis=0)

filtered_data_thirty_percent = np.delete(X_train, sorted_indices[sorted_loss_values > thresholdthirtypercent], axis=0)
filtered_labels_thirty_percent = np.delete(y_train, sorted_indices[sorted_loss_values > thresholdthirtypercent], axis=0)

# %%
print(filtered_data_one_percent.shape)
print(filtered_data_five_percent.shape)
print(filtered_data_ten_percent.shape)
print(filtered_data_fiveten_percent.shape)
print(filtered_data_twenty_percent.shape)
print(filtered_data_twentyfive_percent.shape)
print(filtered_data_thirty_percent.shape)

# %%
"Configurations for ResNet in Regression Mode"
length = filtered_data_one_percent.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

one_percent_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet18()
one_percent_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

one_percent_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('one_percent.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
one_percent_Model_history = one_percent_Model.fit(filtered_data_one_percent, filtered_labels_one_percent, 
                                                  epochs=500, batch_size=64, verbose=1, shuffle=True)

plt.figure()
plt.plot(one_percent_Model_history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
one_percent_Model.evaluate(filtered_data_one_percent, filtered_labels_one_percent)
ypred_one_percent = one_percent_Model.predict(filtered_data_one_percent)

print('MSE: ',mean_squared_error(filtered_labels_one_percent, ypred_one_percent))
print('RMSE: ',math.sqrt(mean_squared_error(filtered_labels_one_percent, ypred_one_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(filtered_labels_one_percent, ypred_one_percent))

# # Inverse transform the predictions and actual values
ypred_one_percent = (ypred_one_percent * (maxForcePlate - minForcePlate)) + minForcePlate
y_real_one_percent = (filtered_labels_one_percent * (maxForcePlate - minForcePlate)) + minForcePlate


print('MSE: ',mean_squared_error(y_real_one_percent, ypred_one_percent))
print('RMSE: ',math.sqrt(mean_squared_error(y_real_one_percent, ypred_one_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real_one_percent, ypred_one_percent))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real_one_percent[0:3000,i],color='red')
    plt.plot(x,ypred_one_percent[0:3000,i], markerfacecolor='none',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(one_percent_Model, 'one_percent.h5')
#End Training Process

# Load Model to Predict Real Data
load_one_percent_Model = tf.keras.models.load_model('one_percent.h5')

load_one_percent_Model.evaluate(X_test, y_test)
Test_Pred_one_percent = load_one_percent_Model.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred_one_percent))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred_one_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred_one_percent))

predictions_one_percent = (Test_Pred_one_percent * (maxForcePlate - minForcePlate)) + minForcePlate
Real_one_percent = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions_one_percent = predictions_one_percent[np.argsort(Test_indices)]
Real_one_percent = Real_one_percent[np.argsort(Test_indices)]

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real_one_percent[0:2000,i],color='red')
    plt.plot(x,predictions_one_percent[0:2000,i], color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
"Configurations for ResNet in Regression Mode"
length = filtered_data_five_percent.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

five_percent_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet18()
five_percent_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

five_percent_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('five_percent.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
five_percent_Model_history = five_percent_Model.fit(filtered_data_five_percent, filtered_labels_five_percent, 
                                                  epochs=500, batch_size=64, verbose=1, shuffle=True)

plt.figure()
plt.plot(five_percent_Model_history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
five_percent_Model.evaluate(filtered_data_five_percent, filtered_labels_five_percent)
ypred_five_percent = five_percent_Model.predict(filtered_data_five_percent)

print('MSE: ',mean_squared_error(filtered_labels_five_percent, ypred_five_percent))
print('RMSE: ',math.sqrt(mean_squared_error(filtered_labels_five_percent, ypred_five_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(filtered_labels_five_percent, ypred_five_percent))

# # Inverse transform the predictions and actual values
ypred_five_percent = (ypred_five_percent * (maxForcePlate - minForcePlate)) + minForcePlate
y_real_five_percent = (filtered_labels_five_percent * (maxForcePlate - minForcePlate)) + minForcePlate

print('MSE: ',mean_squared_error(y_real_five_percent, ypred_five_percent))
print('RMSE: ',math.sqrt(mean_squared_error(y_real_five_percent, ypred_five_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real_five_percent, ypred_five_percent))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real_five_percent[0:3000,i],color='red')
    plt.plot(x,ypred_five_percent[0:3000,i], markerfacecolor='nfive',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(five_percent_Model, 'five_percent.h5')
#End Training Process

# Load Model to Predict Real Data
load_five_percent_Model = tf.keras.models.load_model('five_percent.h5')

load_five_percent_Model.evaluate(X_test, y_test)
Test_Pred_five_percent = load_five_percent_Model.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred_five_percent))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred_five_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred_five_percent))


predictions_five_percent = (Test_Pred_five_percent * (maxForcePlate - minForcePlate)) + minForcePlate
Real_five_percent = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions_five_percent = predictions_five_percent[np.argsort(Test_indices)]
Real_five_percent = Real_five_percent[np.argsort(Test_indices)]

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real_five_percent[0:2000,i],color='red')
    plt.plot(x,predictions_five_percent[0:2000,i], color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
"Configurations for ResNet in Regression Mode"
length = filtered_data_ten_percent.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

ten_percent_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet18()
ten_percent_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

ten_percent_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('ten_percent.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
ten_percent_Model_history = ten_percent_Model.fit(filtered_data_ten_percent, filtered_labels_ten_percent, 
                                                  epochs=500, batch_size=64, verbose=1, shuffle=True)

plt.figure()
plt.plot(ten_percent_Model_history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
ten_percent_Model.evaluate(filtered_data_ten_percent, filtered_labels_ten_percent)
ypred_ten_percent = ten_percent_Model.predict(filtered_data_ten_percent)

print('MSE: ',mean_squared_error(filtered_labels_ten_percent, ypred_ten_percent))
print('RMSE: ',math.sqrt(mean_squared_error(filtered_labels_ten_percent, ypred_ten_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(filtered_labels_ten_percent, ypred_ten_percent))

# # Inverse transform the predictions and actual values
ypred_ten_percent = (ypred_ten_percent * (maxForcePlate - minForcePlate)) + minForcePlate
y_real_ten_percent = (filtered_labels_ten_percent * (maxForcePlate - minForcePlate)) + minForcePlate

print('MSE: ',mean_squared_error(y_real_ten_percent, ypred_ten_percent))
print('RMSE: ',math.sqrt(mean_squared_error(y_real_ten_percent, ypred_ten_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real_ten_percent, ypred_ten_percent))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real_ten_percent[0:3000,i],color='red')
    plt.plot(x,ypred_ten_percent[0:3000,i], markerfacecolor='nten',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(ten_percent_Model, 'ten_percent.h5')
#End Training Process

# Load Model to Predict Real Data
load_ten_percent_Model = tf.keras.models.load_model('ten_percent.h5')

load_ten_percent_Model.evaluate(X_test, y_test)
Test_Pred_ten_percent = load_ten_percent_Model.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred_ten_percent))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred_ten_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred_ten_percent))


predictions_ten_percent = (Test_Pred_ten_percent * (maxForcePlate - minForcePlate)) + minForcePlate
Real_ten_percent = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions_ten_percent = predictions_ten_percent[np.argsort(Test_indices)]
Real_ten_percent = Real_ten_percent[np.argsort(Test_indices)]

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real_ten_percent[0:2000,i],color='red')
    plt.plot(x,predictions_ten_percent[0:2000,i], color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
"Configurations for ResNet in Regression Mode"
length = filtered_data_fiveten_percent.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

fiveten_percent_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet18()
fiveten_percent_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

fiveten_percent_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('fiveten_percent.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
fiveten_percent_Model_history = fiveten_percent_Model.fit(filtered_data_fiveten_percent, filtered_labels_fiveten_percent, 
                                                  epochs=500, batch_size=64, verbose=1, shuffle=True)

plt.figure()
plt.plot(fiveten_percent_Model_history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
fiveten_percent_Model.evaluate(filtered_data_fiveten_percent, filtered_labels_fiveten_percent)
ypred_fiveten_percent = fiveten_percent_Model.predict(filtered_data_fiveten_percent)

print('MSE: ',mean_squared_error(filtered_labels_fiveten_percent, ypred_fiveten_percent))
print('RMSE: ',math.sqrt(mean_squared_error(filtered_labels_fiveten_percent, ypred_fiveten_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(filtered_labels_fiveten_percent, ypred_fiveten_percent))

# # Inverse transform the predictions and actual values
ypred_fiveten_percent = (ypred_fiveten_percent * (maxForcePlate - minForcePlate)) + minForcePlate
y_real_fiveten_percent = (filtered_labels_fiveten_percent * (maxForcePlate - minForcePlate)) + minForcePlate

print('MSE: ',mean_squared_error(y_real_fiveten_percent, ypred_fiveten_percent))
print('RMSE: ',math.sqrt(mean_squared_error(y_real_fiveten_percent, ypred_fiveten_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real_fiveten_percent, ypred_fiveten_percent))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real_fiveten_percent[0:3000,i],color='red')
    plt.plot(x,ypred_fiveten_percent[0:3000,i], markerfacecolor='nfiveten',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(fiveten_percent_Model, 'fiveten_percent.h5')
#End Training Process

# Load Model to Predict Real Data
load_fiveten_percent_Model = tf.keras.models.load_model('fiveten_percent.h5')

load_fiveten_percent_Model.evaluate(X_test, y_test)
Test_Pred_fiveten_percent = load_fiveten_percent_Model.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred_fiveten_percent))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred_fiveten_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred_fiveten_percent))


predictions_fiveten_percent = (Test_Pred_fiveten_percent * (maxForcePlate - minForcePlate)) + minForcePlate
Real_fiveten_percent = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions_fiveten_percent = predictions_fiveten_percent[np.argsort(Test_indices)]
Real_fiveten_percent = Real_fiveten_percent[np.argsort(Test_indices)]

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real_fiveten_percent[0:2000,i],color='red')
    plt.plot(x,predictions_fiveten_percent[0:2000,i],color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
"Configurations for ResNet in Regression Mode"
length = filtered_data_twenty_percent.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

twenty_percent_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet18()
twenty_percent_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

twenty_percent_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('twenty_percent.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
twenty_percent_Model_history = twenty_percent_Model.fit(filtered_data_twenty_percent, filtered_labels_twenty_percent, 
                                                  epochs=500, batch_size=64, verbose=1, shuffle=True)

plt.figure()
plt.plot(twenty_percent_Model_history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
twenty_percent_Model.evaluate(filtered_data_twenty_percent, filtered_labels_twenty_percent)
ypred_twenty_percent = twenty_percent_Model.predict(filtered_data_twenty_percent)

print('MSE: ',mean_squared_error(filtered_labels_twenty_percent, ypred_twenty_percent))
print('RMSE: ',math.sqrt(mean_squared_error(filtered_labels_twenty_percent, ypred_twenty_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(filtered_labels_twenty_percent, ypred_twenty_percent))

# # Inverse transform the predictions and actual values
ypred_twenty_percent = (ypred_twenty_percent * (maxForcePlate - minForcePlate)) + minForcePlate
y_real_twenty_percent = (filtered_labels_twenty_percent * (maxForcePlate - minForcePlate)) + minForcePlate


print('MSE: ',mean_squared_error(y_real_twenty_percent, ypred_twenty_percent))
print('RMSE: ',math.sqrt(mean_squared_error(y_real_twenty_percent, ypred_twenty_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real_twenty_percent, ypred_twenty_percent))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real_twenty_percent[0:3000,i],color='red')
    plt.plot(x,ypred_twenty_percent[0:3000,i], markerfacecolor='ntwenty',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(twenty_percent_Model, 'twenty_percent.h5')
#End Training Process

# Load Model to Predict Real Data
load_twenty_percent_Model = tf.keras.models.load_model('twenty_percent.h5')

load_twenty_percent_Model.evaluate(X_test, y_test)
Test_Pred_twenty_percent = load_twenty_percent_Model.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred_twenty_percent))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred_twenty_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred_twenty_percent))


predictions_twenty_percent = (Test_Pred_twenty_percent * (maxForcePlate - minForcePlate)) + minForcePlate
Real_twenty_percent = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions_twenty_percent = predictions_twenty_percent[np.argsort(Test_indices)]
Real_twenty_percent = Real_twenty_percent[np.argsort(Test_indices)]

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real_twenty_percent[0:2000,i],color='red')
    plt.plot(x,predictions_twenty_percent[0:2000,i],color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
"Configurations for ResNet in Regression Mode"
length = filtered_data_twentyfive_percent.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

twentyfive_percent_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet18()
twentyfive_percent_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

twentyfive_percent_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('twentyfive_percent.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
twentyfive_percent_Model_history = twentyfive_percent_Model.fit(filtered_data_twentyfive_percent, filtered_labels_twentyfive_percent, 
                                                  epochs=500, batch_size=64, verbose=1, shuffle=True)

plt.figure()
plt.plot(twentyfive_percent_Model_history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
twentyfive_percent_Model.evaluate(filtered_data_twentyfive_percent, filtered_labels_twentyfive_percent)
ypred_twentyfive_percent = twentyfive_percent_Model.predict(filtered_data_twentyfive_percent)

print('MSE: ',mean_squared_error(filtered_labels_twentyfive_percent, ypred_twentyfive_percent))
print('RMSE: ',math.sqrt(mean_squared_error(filtered_labels_twentyfive_percent, ypred_twentyfive_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(filtered_labels_twentyfive_percent, ypred_twentyfive_percent))

# # Inverse transform the predictions and actual values
ypred_twentyfive_percent = (ypred_twentyfive_percent * (maxForcePlate - minForcePlate)) + minForcePlate
y_real_twentyfive_percent = (filtered_labels_twentyfive_percent * (maxForcePlate - minForcePlate)) + minForcePlate

print('MSE: ',mean_squared_error(y_real_twentyfive_percent, ypred_twentyfive_percent))
print('RMSE: ',math.sqrt(mean_squared_error(y_real_twentyfive_percent, ypred_twentyfive_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real_twentyfive_percent, ypred_twentyfive_percent))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real_twentyfive_percent[0:3000,i],color='red')
    plt.plot(x,ypred_twentyfive_percent[0:3000,i], markerfacecolor='ntwentyfive',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(twentyfive_percent_Model, 'twentyfive_percent.h5')
#End Training Process

# Load Model to Predict Real Data
load_twentyfive_percent_Model = tf.keras.models.load_model('twentyfive_percent.h5')

load_twentyfive_percent_Model.evaluate(X_test, y_test)
Test_Pred_twentyfive_percent = load_twentyfive_percent_Model.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred_twentyfive_percent))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred_twentyfive_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred_twentyfive_percent)

predictions_twentyfive_percent = (Test_Pred_twentyfive_percent * (maxForcePlate - minForcePlate)) + minForcePlate
Real_twentyfive_percent = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions_twentyfive_percent = predictions_twentyfive_percent[np.argsort(Test_indices)]
Real_twentyfive_percent = Real_twentyfive_percent[np.argsort(Test_indices)]

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real_twentyfive_percent[0:2000,i],color='red')
    plt.plot(x,predictions_twentyfive_percent[0:2000,i],color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
"Configurations for ResNet in Regression Mode"
length = filtered_data_thirty_percent.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

thirty_percent_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet18()
thirty_percent_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

thirty_percent_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('thirty_percent.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
thirty_percent_Model_history = thirty_percent_Model.fit(filtered_data_thirty_percent, filtered_labels_thirty_percent, 
                                                  epochs=500, batch_size=64, verbose=1, shuffle=True)

plt.figure()
plt.plot(thirty_percent_Model_history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
thirty_percent_Model.evaluate(filtered_data_thirty_percent, filtered_labels_thirty_percent)
ypred_thirty_percent = thirty_percent_Model.predict(filtered_data_thirty_percent)

print('MSE: ',mean_squared_error(filtered_labels_thirty_percent, ypred_thirty_percent))
print('RMSE: ',math.sqrt(mean_squared_error(filtered_labels_thirty_percent, ypred_thirty_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(filtered_labels_thirty_percent, ypred_thirty_percent))

# # Inverse transform the predictions and actual values
ypred_thirty_percent = (ypred_thirty_percent * (maxForcePlate - minForcePlate)) + minForcePlate
y_real_thirty_percent = (filtered_labels_thirty_percent * (maxForcePlate - minForcePlate)) + minForcePlate

print('MSE: ',mean_squared_error(y_real_thirty_percent, ypred_thirty_percent))
print('RMSE: ',math.sqrt(mean_squared_error(y_real_thirty_percent, ypred_thirty_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real_thirty_percent, ypred_thirty_percent))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real_thirty_percent[0:3000,i],color='red')
    plt.plot(x,ypred_thirty_percent[0:3000,i], markerfacecolor='nthirty',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(thirty_percent_Model, 'thirty_percent.h5')
#End Training Process

# Load Model to Predict Real Data
load_thirty_percent_Model = tf.keras.models.load_model('thirty_percent.h5')

load_thirty_percent_Model.evaluate(X_test, y_test)
Test_Pred_thirty_percent = load_thirty_percent_Model.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred_thirty_percent))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred_thirty_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred_thirty_percent)


predictions_thirty_percent = (Test_Pred_thirty_percent * (maxForcePlate - minForcePlate)) + minForcePlate
Real_thirty_percent = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions_thirty_percent = predictions_thirty_percent[np.argsort(Test_indices)]
Real_thirty_percent = Real_thirty_percent[np.argsort(Test_indices)]

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real_thirty_percent[0:2000,i],color='red')
    plt.plot(x,predictions_thirty_percent[0:2000,i], color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
loss_before = np.mean((y_pred - y_real) ** 2, axis=1)  # Using mean squared error as an example
loss_one = np.mean((ypred_one_percent - y_real_one_percent) ** 2, axis=1)  # Using mean squared error as an example
loss_five = np.mean((ypred_five_percent - y_real_five_percent) ** 2, axis=1)  # Using mean squared error as an example
loss_ten = np.mean((ypred_ten_percent - y_real_ten_percent) ** 2, axis=1)  # Using mean squared error as an example
loss_fiveteen = np.mean((ypred_fiveten_percent - y_real_fiveten_percent) ** 2, axis=1)  # Using mean squared error as an example
loss_twenty = np.mean((ypred_twenty_percent - y_real_twenty_percent) ** 2, axis=1)  # Using mean squared error as an example
loss_twentyfive = np.mean((ypred_twentyfive_percent - y_real_twentyfive_percent) ** 2, axis=1)  # Using mean squared error as an example
loss_thirty = np.mean((ypred_thirty_percent - y_real_thirty_percent) ** 2, axis=1)  # Using mean squared error as an example

# %%
loss_thirty.shape

# %%
beforemax = np.max(loss_before[:9100])
beforemin = np.min(loss_before[:9100])
onepercentmax = np.max(loss_one[:9100])
onepercentmin = np.min(loss_one[:9100])
fivepercentmax = np.max(loss_five[:9100])
fivepercentmin = np.min(loss_five[:9100])
tenpercentmax = np.max(loss_ten[:9100])
tenpercentmin = np.min(loss_ten[:9100])
fiveteenpercentmax = np.max(loss_fiveteen[:9100])
fiveteenpercentmin = np.min(loss_fiveteen[:9100])
twentypercentmax = np.max(loss_twenty[:9100])
twentypercentmin = np.min(loss_twenty[:9100])
twentyfivepercentmax = np.max(loss_twentyfive[:9100])
twentyfivepercentmin = np.min(loss_twentyfive[:9100])
thirtypercentmax = np.max(loss_thirty[:9100])
thirtypercentmin = np.min(loss_thirty[:9100])
beforeaverage = np.average(loss_before[:9100])
onepercentaverage = np.average(loss_one[:9100])
fivepercentaverage = np.average(loss_five[:9100])
tenpercentaverage = np.average(loss_ten[:9100])
fiveteenpercentaverage = np.average(loss_fiveteen[:9100])
twentypercentaverage = np.average(loss_twenty[:9100])
twentyfivepercentaverage = np.average(loss_twentyfive[:9100])
thirtypercentaverage = np.average(loss_thirty[:9100])

# Average = np.concatenate(beforeaverage,onepercentaverage,fivepercentaverage,
#                         tenpercentaverage,twentypercentaverage,thirtypercentaverage, axis=1)
# Average = np.concatenate((beforeaverage, onepercentaverage, fivepercentaverage, 
#                           tenpercentaverage, twentypercentaverage, thirtypercentaverage), axis=1)
Average = np.hstack((beforeaverage, onepercentaverage, fivepercentaverage, tenpercentaverage, 
                     fiveteenpercentaverage, twentypercentaverage, twentyfivepercentaverage,
                     thirtypercentaverage)).reshape(-1,1)
Max = np.hstack((beforemax, onepercentmax, fivepercentmax, tenpercentmax, fiveteenpercentmax,
                 twentypercentmax,twentyfivepercentmax, thirtypercentmax)).reshape(-1,1)
Min = np.hstack((beforemin, onepercentmin, fivepercentmin, tenpercentmin, 
                 fiveteenpercentmin, twentypercentmin, twentyfivepercentmin, thirtypercentmin)).reshape(-1,1)

# %%
# RMSE_Before = math.sqrt(mean_squared_error(y_train, ypred))
# RMSE_one = math.sqrt(mean_squared_error(filtered_labels_one_percent, ypred_one_percent))
# RMSE_five = math.sqrt(mean_squared_error(filtered_labels_five_percent, ypred_five_percent))
# RMSE_ten = math.sqrt(mean_squared_error(filtered_labels_ten_percent, ypred_ten_percent))
# RMSE_fiveteen = math.sqrt(mean_squared_error(filtered_labels_fiveten_percent, ypred_fiveten_percent))
# RMSE_twenty = math.sqrt(mean_squared_error(filtered_labels_twenty_percent, ypred_twenty_percent))
# RMSE_twentyfive = math.sqrt(mean_squared_error(filtered_labels_twentyfive_percent, ypred_twentyfive_percent))
# RMSE_thirty = math.sqrt(mean_squared_error(filtered_labels_thirty_percent, ypred_thirty_percent))

# RMSE = np.hstack((RMSE_Before, RMSE_one, RMSE_five, RMSE_ten, 
#                  RMSE_fiveteen, RMSE_twenty, RMSE_twentyfive, RMSE_thirty)).reshape(-1,1)

# %%
RMSE_Before = 0.1371
RMSE_one = 0.1329
RMSE_five = 0.1309
RMSE_ten = 0.1299
RMSE_fiveteen = 0.1296
RMSE_twenty = 0.1390
RMSE_twentyfive = 0.0177
RMSE_thirty = 0.0162

# RMSE = np.hstack((RMSE_Before, RMSE_one, RMSE_five, RMSE_ten, 
#                  RMSE_fiveteen, RMSE_twenty, RMSE_twentyfive, RMSE_thirty)).reshape(-1,1)

RMSE = np.hstack((RMSE_Before, RMSE_one, RMSE_five, RMSE_ten, 
                 RMSE_fiveteen, RMSE_twenty)).reshape(-1,1)

# %%
# import pandas as pd
# import numpy as np

# columnsLoss = ['Loss_Values_Before', 'Loss_Values_After_1%', 'Loss_Values_After_5%',
#                'Loss_Values_After_10%', 'Loss_Values_After_20%', 'Loss_Values_After_30%']

# # Training Process
# dfLoss = pd.read_excel('loss_values.xlsx')
# selected_dfLoss = dfLoss[columnsLoss]
# Lossi = selected_dfLoss[:]

# Losssi = np.array(Lossi[:9100]).astype('float64')

# %%
# beforemax = np.max(Losssi[:,0])
# beforemin = np.min(Losssi[:,0])
# onepercentmax = np.max(Losssi[:,1])
# onepercentmin = np.min(Losssi[:,1])
# fivepercentmax = np.max(Losssi[:,2])
# fivepercentmin = np.min(Losssi[:,2])
# tenpercentmax = np.max(Losssi[:,3])
# tenpercentmin = np.min(Losssi[:,3])
# twentypercentmax = np.max(Losssi[:,4])
# twentypercentmin = np.min(Losssi[:,4])
# thirtypercentmax = np.max(Losssi[:,5])
# thirtypercentmin = np.min(Losssi[:,5])
# beforeaverage = np.average(Losssi[:,0])
# onepercentaverage = np.average(Losssi[:,1])
# fivepercentaverage = np.average(Losssi[:,2])
# tenpercentaverage = np.average(Losssi[:,3])
# twentypercentaverage = np.average(Losssi[:,4])
# thirtypercentaverage = np.average(Losssi[:,5])

# # Average = np.concatenate(beforeaverage,onepercentaverage,fivepercentaverage,
# #                         tenpercentaverage,twentypercentaverage,thirtypercentaverage, axis=1)
# # Average = np.concatenate((beforeaverage, onepercentaverage, fivepercentaverage, 
# #                           tenpercentaverage, twentypercentaverage, thirtypercentaverage), axis=1)
# Average = np.hstack((beforeaverage, onepercentaverage, fivepercentaverage,
#                     tenpercentaverage, twentypercentaverage, thirtypercentaverage)).reshape(-1,1)
# Max = np.hstack((beforemax, onepercentmax, fivepercentmax,
#                     tenpercentmax, twentypercentmax, thirtypercentmax)).reshape(-1,1)
# Min = np.hstack((beforemin, onepercentmin, fivepercentmin,
#                     tenpercentmin, twentypercentmin, thirtypercentmin)).reshape(-1,1)

# %%
Average.shape

# %%
print(thirtypercentmax)

# %%
# categories = ['Before', '1%', '5%', '10%', '15%', '20%', '25%', '30%']
categories = ['Before', '1%', '5%', '10%', '15%', '20%']

plt.figure(figsize=(15, 6))
plt.plot(categories, RMSE, marker='o', color='red')

# Add value labels
for i, value in enumerate(RMSE):
    plt.text(categories[i], value, str(value), ha='center', va='bottom')

plt.title('RMSE')
plt.ylabel('RMSE Error')
plt.show()

# %%
x = np.arange(0, 3000) * 40 / 3000
for i in range(0, 1):
    plt.figure(figsize=(15, 6))
#     plt.bar('Before', beforemax, color='orange')
#     plt.bar('1%', onepercentmax, color='orange')
#     plt.bar('5%', fivepercentmax, color='orange')
#     plt.bar('10%', tenpercentmax, color='orange')
#     plt.bar('15%', fiveteenpercentmax, color='orange')
#     plt.bar('20%', twentypercentmax, color='orange')
#     plt.bar('25%', twentyfivepercentmax, color='orange')
#     plt.bar('30%', thirtypercentmax, color='orange')
#     plt.bar('Before', beforemin, color='blue')
#     plt.bar('1%', onepercentmin, color='blue')
#     plt.bar('5%', fivepercentmin, color='blue')
#     plt.bar('10%', tenpercentmin, color='blue')
#     plt.bar('15%', fiveteenpercentmin, color='blue')
#     plt.bar('20%', twentypercentmin, color='blue')
#     plt.bar('25%', twentyfivepercentmin, color='blue')
#     plt.bar('30%', thirtypercentmin, color='blue')
#     plt.bar('Before', beforeaverage, color='green')
#     plt.bar('1%', onepercentaverage, color='green')
#     plt.bar('5%', fivepercentaverage, color='green')
#     plt.bar('10%', tenpercentaverage, color='green')
#     plt.bar('15%', fiveteenpercentaverage, color='green')
#     plt.bar('20%', twentypercentaverage, color='green')
#     plt.bar('25%', twentyfivepercentaverage, color='green')
#     plt.bar('30%', thirtypercentaverage, color='green')
    plt.bar('Before', RMSE_Before, color='red')
    plt.bar('1%', RMSE_one, color='red')
    plt.bar('5%', RMSE_five, color='red')
    plt.bar('10%', RMSE_ten, color='red')
    plt.bar('15%', RMSE_fiveteen, color='red')
    plt.bar('20%', RMSE_twenty, color='red')
#     plt.bar('25%', RMSE_twentyfive, color='red')
#     plt.bar('30%', RMSE_thirty, color='red')
    plt.title('RMSE')
    plt.ylabel('RMSE Error')
#     plt.xlabel('Time (s)')
#     plt.legend(['Before', 'After'], loc='best')
    plt.show()

# %%
x = np.arange(0, 3000) * 40 / 3000
for i in range(0, 1):
    plt.figure(figsize=(15, 6))
#     plt.bar('Before', beforemax, color='orange')
#     plt.bar('1%', onepercentmax, color='orange')
#     plt.bar('5%', fivepercentmax, color='orange')
#     plt.bar('10%', tenpercentmax, color='orange')
#     plt.bar('15%', fiveteenpercentmax, color='orange')
#     plt.bar('20%', twentypercentmax, color='orange')
#     plt.bar('25%', twentyfivepercentmax, color='orange')
#     plt.bar('30%', thirtypercentmax, color='orange')
#     plt.bar('Before', beforemin, color='blue')
#     plt.bar('1%', onepercentmin, color='blue')
#     plt.bar('5%', fivepercentmin, color='blue')
#     plt.bar('10%', tenpercentmin, color='blue')
#     plt.bar('15%', fiveteenpercentmin, color='blue')
#     plt.bar('20%', twentypercentmin, color='blue')
#     plt.bar('25%', twentyfivepercentmin, color='blue')
#     plt.bar('30%', thirtypercentmin, color='blue')
#     plt.bar('Before', beforeaverage, color='green')
#     plt.bar('1%', onepercentaverage, color='green')
#     plt.bar('5%', fivepercentaverage, color='green')
#     plt.bar('10%', tenpercentaverage, color='green')
#     plt.bar('15%', fiveteenpercentaverage, color='green')
#     plt.bar('20%', twentypercentaverage, color='green')
#     plt.bar('25%', twentyfivepercentaverage, color='green')
#     plt.bar('30%', thirtypercentaverage, color='green')
#     plt.bar('Before', RMSE_Before, color='red')
#     plt.bar('1%', RMSE_one, color='red')
#     plt.bar('5%', RMSE_five, color='red')
#     plt.bar('10%', RMSE_ten, color='red')
#     plt.bar('15%', RMSE_fiveteen, color='red')
#     plt.bar('20%', RMSE_twenty, color='red')
#     plt.bar('25%', RMSE_twentyfive, color='red')
#     plt.bar('30%', RMSE_thirty, color='red')
    plt.bar('Before', RMSE_Before, color='red')
    plt.bar('After', RMSE_After, color='red')
#     plt.bar('25%', RMSE_twentyfive, color='red')
#     plt.bar('30%', RMSE_thirty, color='red')
    plt.title('RMSE')
    plt.ylabel('RMSE Error')
#     plt.xlabel('Time (s)')
#     plt.legend(['Before', 'After'], loc='best')
    plt.show()

# %%
RMSE_Before = 0.0839
RMSE_After = 0.0832

# RMSE = np.hstack((RMSE_Before, RMSE_one, RMSE_five, RMSE_ten, 
#                  RMSE_fiveteen, RMSE_twenty, RMSE_twentyfive, RMSE_thirty)).reshape(-1,1)

RMSE = np.hstack((RMSE_Before,RMSE_After)).reshape(-1,1)

# categories = ['Before', '1%', '5%', '10%', '15%', '20%', '25%', '30%']
categories = ['Before', 'After']

plt.figure(figsize=(15, 6))
plt.plot(categories, RMSE, marker='o', color='red')

# Add value labels
for i, value in enumerate(RMSE):
    plt.text(categories[i], value, str(value), ha='center', va='bottom')

plt.title('RMSE')
plt.ylabel('RMSE Error')
plt.show()

# %%
import numpy as np
import pandas as pd
# import seaborn as sns
from numpy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Conv2D, MaxPooling2D, Reshape, Flatten, Dense
from keras.models import Model, model_from_json
from keras.optimizers import Adam, RMSprop
# from tensorflow.keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import Normalizer,MinMaxScaler,StandardScaler, RobustScaler, QuantileTransformer, PowerTransformer
# sns.set_theme(style="whitegrid")
import pywt
np.set_printoptions(suppress=True)
# Import ResNet1D Module
from ResNet_1DCNN import ResNet
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error, r2_score

columns = ['Fx']
wavelet = 'db4'
max_iter = 50
iter = 0

def seed_everything(seed=42):
    np.random.seed(seed)
    tf.random.set_seed(seed)

# Training Process
# columns = ['Fx','Fy','Fz','Mx','My','Mz']

# Standing Dataset
InsoleStanding1 = pd.read_csv('0310AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding2 = pd.read_csv('0310HudaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding3 = pd.read_csv('0311LalaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding4 = pd.read_csv('0311YunitaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding5 = pd.read_csv('0312AbelStand5Min1.txt', header=None, low_memory=False)
InsoleStanding6 = pd.read_csv('0312AbiStand5Min1.txt', header=None, low_memory=False)
InsoleStanding7 = pd.read_csv('0312AryaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding8 = pd.read_csv('0312HawaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding9 = pd.read_csv('0312NisaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding10 = pd.read_csv('0313ChenChengStand5Min1.txt', header=None, low_memory=False)
InsoleStanding11 = pd.read_csv('0313RezaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding12 = pd.read_csv('0313RilaniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding13 = pd.read_csv('0313SariStand5Min1.txt', header=None, low_memory=False)
InsoleStanding14 = pd.read_csv('0313ShelbyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding15 = pd.read_csv('0314HelenStand5Min1.txt', header=None, low_memory=False)
InsoleStanding16 = pd.read_csv('0315AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding17 = pd.read_csv('0315HappyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding18 = pd.read_csv('0317HeniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding19 = pd.read_csv('0317NadiaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding20 = pd.read_csv('0317VikaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding21 = pd.read_csv('0319AlfianStand5Min1.txt', header=None, low_memory=False)
InsoleStanding22 = pd.read_csv('0310JakaStand2Min.txt', header=None, low_memory=False)
SIDatasStanding1 =  np.array(InsoleStanding1)
SIDatasStanding2 =  np.array(InsoleStanding2)
SIDatasStanding3 =  np.array(InsoleStanding3)
SIDatasStanding4 =  np.array(InsoleStanding4)
SIDatasStanding5 =  np.array(InsoleStanding5)
SIDatasStanding6 =  np.array(InsoleStanding6)
SIDatasStanding7 =  np.array(InsoleStanding7)
SIDatasStanding8 =  np.array(InsoleStanding8)
SIDatasStanding9 =  np.array(InsoleStanding9)
SIDatasStanding10 =  np.array(InsoleStanding10)
SIDatasStanding11 =  np.array(InsoleStanding11)
SIDatasStanding12 =  np.array(InsoleStanding12)
SIDatasStanding13 =  np.array(InsoleStanding13)
SIDatasStanding14 =  np.array(InsoleStanding14)
SIDatasStanding15 =  np.array(InsoleStanding15)
SIDatasStanding16 =  np.array(InsoleStanding16)
SIDatasStanding17 =  np.array(InsoleStanding17)
SIDatasStanding18 =  np.array(InsoleStanding18)
SIDatasStanding19 =  np.array(InsoleStanding19)
SIDatasStanding20 =  np.array(InsoleStanding20)
SIDatasStanding21 =  np.array(InsoleStanding21)

dfStanding1 = pd.read_csv('0310AyuStand5Min1.csv', low_memory=False)
dfStanding2 = pd.read_csv('0310HudaStand5Min1.csv', low_memory=False)
dfStanding3 = pd.read_csv('0311LalaStand5Min1.csv', low_memory=False)
dfStanding4 = pd.read_csv('0311YunitaStand5Min1.csv', low_memory=False)
dfStanding5 = pd.read_csv('0312AbelStand5Min1.csv', low_memory=False)
dfStanding6 = pd.read_csv('0312AbiStand5Min1.csv', low_memory=False)
dfStanding7 = pd.read_csv('0312AryaStand5Min1.csv', low_memory=False)
dfStanding8 = pd.read_csv('0312HawaStand5Min1.csv', low_memory=False)
dfStanding9 = pd.read_csv('0312NisaStand5Min1.csv', low_memory=False)
dfStanding10 = pd.read_csv('0313ChenChengStand5Min1.csv', low_memory=False)
dfStanding11 = pd.read_csv('0313RezaStand5Min1.csv', low_memory=False)
dfStanding12 = pd.read_csv('0313RilaniStand5Min1.csv', low_memory=False)
dfStanding13 = pd.read_csv('0313SariStand5Min1.csv', low_memory=False)
dfStanding14 = pd.read_csv('0313ShelbyStand5Min1.csv', low_memory=False)
dfStanding15 = pd.read_csv('0314HelenStand5Min1.csv', low_memory=False)
dfStanding16 = pd.read_csv('0315AyuStand5Min1.csv', low_memory=False)
dfStanding17 = pd.read_csv('0315HappyStand5Min1.csv', low_memory=False)
dfStanding18 = pd.read_csv('0317HeniStand5Min1.csv', low_memory=False)
dfStanding19 = pd.read_csv('0317NadiaStand5Min1.csv', low_memory=False)
dfStanding20 = pd.read_csv('0317VikaStand5Min1.csv', low_memory=False)
dfStanding21 = pd.read_csv('0319AlfianStand5Min1.csv', low_memory=False)

selected_dfStandings1 = dfStanding1[columns]
selected_dfStandings2 = dfStanding2[columns]
selected_dfStandings3 = dfStanding3[columns]
selected_dfStandings4 = dfStanding4[columns]
selected_dfStandings5 = dfStanding5[columns]
selected_dfStandings6 = dfStanding6[columns]
selected_dfStandings7 = dfStanding7[columns]
selected_dfStandings8 = dfStanding8[columns]
selected_dfStandings9 = dfStanding9[columns]
selected_dfStandings10 = dfStanding10[columns]
selected_dfStandings11 = dfStanding11[columns]
selected_dfStandings12 = dfStanding12[columns]
selected_dfStandings13 = dfStanding13[columns]
selected_dfStandings14 = dfStanding14[columns]
selected_dfStandings15 = dfStanding15[columns]
selected_dfStandings16 = dfStanding16[columns]
selected_dfStandings17 = dfStanding17[columns]
selected_dfStandings18 = dfStanding18[columns]
selected_dfStandings19 = dfStanding19[columns]
selected_dfStandings20 = dfStanding20[columns]
selected_dfStandings21 = dfStanding21[columns]
FPDataStandings1 = selected_dfStandings1[:15000]
FPDataStandings2 = selected_dfStandings2[:15000]
FPDataStandings3 = selected_dfStandings3[:15000]
FPDataStandings4 = selected_dfStandings4[:15000]
FPDataStandings5 = selected_dfStandings5[:15000]
FPDataStandings6 = selected_dfStandings6[:15000]
FPDataStandings7 = selected_dfStandings7[:15000]
FPDataStandings8 = selected_dfStandings8[:15000]
FPDataStandings9 = selected_dfStandings9[:15000]
FPDataStandings10 = selected_dfStandings10[:15000]
FPDataStandings11 = selected_dfStandings11[:15000]
FPDataStandings12 = selected_dfStandings12[:15000]
FPDataStandings13 = selected_dfStandings13[:15000]
FPDataStandings14 = selected_dfStandings14[:15000]
FPDataStandings15 = selected_dfStandings15[:15000]
FPDataStandings16 = selected_dfStandings16[:15000]
FPDataStandings17 = selected_dfStandings17[:15000]
FPDataStandings18 = selected_dfStandings18[:15000]
FPDataStandings19 = selected_dfStandings19[:15000]
FPDataStandings20 = selected_dfStandings20[:15000]
FPDataStandings21 = selected_dfStandings21[:15000]

SIDataStanding1 = np.array(SIDatasStanding1[:15000]).astype('float64')
SIDataStanding2 = np.array(SIDatasStanding2[:15000]).astype('float64')
SIDataStanding3 = np.array(SIDatasStanding3[:15000]).astype('float64')
SIDataStanding4 = np.array(SIDatasStanding4[:15000]).astype('float64')
SIDataStanding5 = np.array(SIDatasStanding5[:15000]).astype('float64')
SIDataStanding6 = np.array(SIDatasStanding6[:15000]).astype('float64')
SIDataStanding7 = np.array(SIDatasStanding7[:15000]).astype('float64')
SIDataStanding8 = np.array(SIDatasStanding8[:15000]).astype('float64')
SIDataStanding9 = np.array(SIDatasStanding9[:15000]).astype('float64')
SIDataStanding10 = np.array(SIDatasStanding10[:15000]).astype('float64')
SIDataStanding11 = np.array(SIDatasStanding11[:15000]).astype('float64')
SIDataStanding12 = np.array(SIDatasStanding12[:15000]).astype('float64')
SIDataStanding13 = np.array(SIDatasStanding13[:15000]).astype('float64')
SIDataStanding14 = np.array(SIDatasStanding14[:15000]).astype('float64')
SIDataStanding15 = np.array(SIDatasStanding15[:15000]).astype('float64')
SIDataStanding16 = np.array(SIDatasStanding16[:15000]).astype('float64')
SIDataStanding17 = np.array(SIDatasStanding17[:15000]).astype('float64')
SIDataStanding18 = np.array(SIDatasStanding18[:15000]).astype('float64')
SIDataStanding19 = np.array(SIDatasStanding19[:15000]).astype('float64')
SIDataStanding20 = np.array(SIDatasStanding20[:15000]).astype('float64')
SIDataStanding21 = np.array(SIDatasStanding21[:15000]).astype('float64')
FPDataStanding1 = np.array(FPDataStandings1).astype('float64')
FPDataStanding2 = np.array(FPDataStandings2).astype('float64')
FPDataStanding3= np.array(FPDataStandings3).astype('float64')
FPDataStanding4= np.array(FPDataStandings4).astype('float64')
FPDataStanding5= np.array(FPDataStandings5).astype('float64')
FPDataStanding6= np.array(FPDataStandings6).astype('float64')
FPDataStanding7= np.array(FPDataStandings7).astype('float64')
FPDataStanding8= np.array(FPDataStandings8).astype('float64')
FPDataStanding9= np.array(FPDataStandings9).astype('float64')
FPDataStanding10 = np.array(FPDataStandings10).astype('float64')
FPDataStanding11 = np.array(FPDataStandings11).astype('float64')
FPDataStanding12= np.array(FPDataStandings12).astype('float64')
FPDataStanding13= np.array(FPDataStandings13).astype('float64')
FPDataStanding14= np.array(FPDataStandings14).astype('float64')
FPDataStanding15= np.array(FPDataStandings15).astype('float64')
FPDataStanding16= np.array(FPDataStandings16).astype('float64')
FPDataStanding17= np.array(FPDataStandings17).astype('float64')
FPDataStanding18= np.array(FPDataStandings18).astype('float64')
FPDataStanding19= np.array(FPDataStandings19).astype('float64')
FPDataStanding20= np.array(FPDataStandings20).astype('float64')
FPDataStanding21= np.array(FPDataStandings21).astype('float64')

# SIDatasetStanding = np.concatenate((SIDataStanding1, SIDataStanding2, SIDataStanding3,
#                             SIDataStanding4, SIDataStanding5, SIDataStanding6,
#                             SIDataStanding8, SIDataStanding9,
#                             SIDataStanding10, SIDataStanding11, SIDataStanding12,
#                             SIDataStanding13, SIDataStanding14, SIDataStanding15,
#                             SIDataStanding16, SIDataStanding17, SIDataStanding18,
#                             SIDataStanding19, SIDataStanding20, SIDataStanding21,
#                             SIDataStanding7), axis=0)


# FPDatasetStanding = np.concatenate((FPDataStanding1, FPDataStanding2, FPDataStanding3,
#                             FPDataStanding4, FPDataStanding5, FPDataStanding6,
#                             FPDataStanding8, FPDataStanding9,
#                             FPDataStanding10, FPDataStanding11, FPDataStanding12,
#                             FPDataStanding13, FPDataStanding14, FPDataStanding15,
#                             FPDataStanding16, FPDataStanding17, FPDataStanding18,
#                             FPDataStanding19, FPDataStanding20, FPDataStanding21,
#                             FPDataStanding7), axis=0)

SIDatasetStanding = np.concatenate((SIDataStanding3,SIDataStanding6,SIDataStanding9,
                                    SIDataStanding10, SIDataStanding19, SIDataStanding7), axis=0)


FPDatasetStanding = np.concatenate((FPDataStanding3,FPDataStanding6, FPDataStanding9,
                            FPDataStanding10, FPDataStanding19, FPDataStanding7), axis=0)


SIDatasetStanding = SIDatasetStanding
FPDatasetStanding = FPDatasetStanding

SIDatasetStanding = np.array(SIDatasetStanding).astype('float64')
FPDatasetStanding = np.array(FPDatasetStanding).astype('float64')

SIDataset = SIDatasetStanding
FPDataset = FPDatasetStanding


SIDWTcoeffs = []
for i in range(89):
    coeffs = pywt.wavedec(SIDataset[:, i], wavelet)
    coeffs[-1] = np.zeros_like(coeffs[-1])
#     coeffs[-2] = np.zeros_like(coeffs[-2])
#     coeffs[-3] = np.zeros_like(coeffs[-3])
#     coeffs[-4] = np.zeros_like(coeffs[-4])
#     coeffs[-5] = np.zeros_like(coeffs[-5])
#     coeffs[-6] = np.zeros_like(coeffs[-6])
    SIDWTcoeffs.append(coeffs)

SIData_filtered = np.zeros(SIDataset.shape)
for i in range(89):
    SIData_filtered[:, i] = pywt.waverec(SIDWTcoeffs[i], wavelet, mode='symmetric', axis=0)

# SIids = [0,10,11,12,22,41,42,48,49,50,59,63,74,75,76,77,78]

# SIselection=[]

# for i in range(len(SIData_filtered)):
#   SIselection.append(SIData_filtered[i][SIids])

# SIselection = np.array(SIselection)

# from sklearn.decomposition import PCA
# from sklearn.model_selection import KFold
# from numpy import zeros, newaxis
# from sklearn.feature_selection import f_regression, mutual_info_regression, mutual_info_classif
# from sklearn.feature_selection import SelectKBest
# from sklearn.feature_selection import f_regression

# SIDataPCA = SIData_filtered
# print(SIDataPCA.shape)
# pca = PCA(n_components=0.98)
# pca.fit(SIDataPCA)
# SIdata_pca = pca.transform(SIDataPCA)

# print(SIdata_pca.shape, FPDataset.shape)
# # define feature selection
# fs = SelectKBest(score_func=f_regression, k=5)
# # apply feature selection
# X_selected = fs.fit_transform(SIdata_pca, FPDataset)
# print(X_selected.shape)


max_iter = 50
iter = 0
for i in range(len(SIData_filtered)):
    SIData_filtered[i][0] = SIData_filtered[i][0] + (iter % max_iter) + 1
    iter += 1


# label = pd.read_csv('label.txt', header=None, low_memory=False)
# labelData = np.array(label)
# Label = np.array(labelData[:15000]).astype('float32')

# label_data = np.tile(Label, (X_selected.shape[0] // Label.shape[0], 1))
# print(label_data[15000:15010])

# SIlabeled = np.concatenate((label_data, X_selected), axis=1)

# Scale the smart insole data
minInsole = SIData_filtered.min()
maxInsole = SIData_filtered.max()
smart_insole_data_scaled = (SIData_filtered - minInsole) / ( maxInsole - minInsole )

# Scale the force plate data
minForcePlate = FPDataset.min()
maxForcePlate = FPDataset.max()
force_plate_data_scaled = (FPDataset - minForcePlate) / ( maxForcePlate - minForcePlate )


#Spliting Data
sample_size = smart_insole_data_scaled.shape[0] # number of samples in train set
time_steps  = smart_insole_data_scaled.shape[1] # number of features in train set
input_dimension = 1               # each feature is represented by 1 number

train_data_reshaped = smart_insole_data_scaled.reshape(sample_size,time_steps,input_dimension)

# X_train, X_test, y_train, y_test = train_test_split(train_data_reshaped[:13000],
#                                                     force_plate_data_scaled[:13000],
#                                                     test_size=0.20, random_state=2)

smart_insole_data_scaled_Train = train_data_reshaped[:75000]
smart_insole_data_scaled_Test = train_data_reshaped[75000:]
force_plate_data_scaled_Train = force_plate_data_scaled[:75000]
force_plate_data_scaled_Test = force_plate_data_scaled[75000:]

# Generate random indices for shuffling the data
indices = np.arange(smart_insole_data_scaled_Train.shape[0])
np.random.shuffle(indices)

seed_everything(42)
# Use the shuffled indices to randomly select training data
X_train = smart_insole_data_scaled_Train[indices]
y_train = force_plate_data_scaled_Train[indices]

Test_indices = np.arange(smart_insole_data_scaled_Test.shape[0])
np.random.shuffle(Test_indices)

seed_everything(42)
# # Assign the test data
X_test = smart_insole_data_scaled_Test[Test_indices]
y_test = force_plate_data_scaled_Test[Test_indices]

print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)

"Configurations for ResNet in Regression Mode"
length = X_train.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

Regression_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet18()
Regression_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.001), metrics= ['mse']) # Compile Model

Regression_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('Saved_Model.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
history = Regression_Model.fit(X_train, y_train, epochs=250, batch_size=64, verbose=1, shuffle=True)

plt.figure()
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
Regression_Model.evaluate(X_train, y_train)
ypred = Regression_Model.predict(X_train)

print('MSE: ',mean_squared_error(y_train, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_train, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_train, ypred))

# # Inverse transform the predictions and actual values
y_pred = (ypred * (maxForcePlate - minForcePlate)) + minForcePlate
y_real = (y_train * (maxForcePlate - minForcePlate)) + minForcePlate

# y_pred = y_pred[np.argsort(indices)]
# y_real = y_real[np.argsort(indices)]

print('MSE: ',mean_squared_error(y_real, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_real, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real, ypred))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real[0:3000,i],color='red')
    plt.plot(x,y_pred[0:3000,i], markerfacecolor='none',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(Regression_Model, '1ouput.h5')
#End Training Process

# Load Model to Predict Real Data
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(X_test, y_test)
Test_Pred = modelCoy.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred))

predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
Real = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions = predictions[np.argsort(Test_indices)]
Real = Real[np.argsort(Test_indices)]

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:2000,i],color='red')
    plt.plot(x,predictions[0:2000,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
# Step 3: Calculate the loss
loss_values = np.mean((y_pred - y_real) ** 2, axis=1)  # Using mean squared error as an example

# Step 4: Rank the loss results in ascending order
sorted_indices = np.argsort(loss_values)  # Sort loss values in ascending order
sorted_loss_values = loss_values[sorted_indices]

# Step 5: Set a threshold
thresholdonepercent = np.percentile(sorted_loss_values, 85)  # Set the threshold to remove the last 1% of examples
thresholdfivepercent = np.percentile(sorted_loss_values, 95)  # Set the threshold to remove the last 1% of examples
thresholdtenpercent = np.percentile(sorted_loss_values, 90)  # Set the threshold to remove the last 1% of examples
thresholdfivetenpercent = np.percentile(sorted_loss_values, 85)  # Set the threshold to remove the last 1% of examples
thresholdtwentypercent = np.percentile(sorted_loss_values, 80)  # Set the threshold to remove the last 1% of examples
thresholdtwentyfivepercent = np.percentile(sorted_loss_values, 75)  # Set the threshold to remove the last 1% of examples
thresholdthirtypercent = np.percentile(sorted_loss_values, 70)  # Set the threshold to remove the last 1% of examples

# Step 6: Remove data based on the threshold
filtered_data_one_percent = np.delete(X_train, sorted_indices[sorted_loss_values > thresholdonepercent], axis=0)
filtered_labels_one_percent = np.delete(y_train, sorted_indices[sorted_loss_values > thresholdonepercent], axis=0)

filtered_data_five_percent = np.delete(X_train, sorted_indices[sorted_loss_values > thresholdfivepercent], axis=0)
filtered_labels_five_percent = np.delete(y_train, sorted_indices[sorted_loss_values > thresholdfivepercent], axis=0)

filtered_data_ten_percent = np.delete(X_train, sorted_indices[sorted_loss_values > thresholdtenpercent], axis=0)
filtered_labels_ten_percent = np.delete(y_train, sorted_indices[sorted_loss_values > thresholdtenpercent], axis=0)

filtered_data_fiveten_percent = np.delete(X_train, sorted_indices[sorted_loss_values > thresholdfivetenpercent], axis=0)
filtered_labels_fiveten_percent = np.delete(y_train, sorted_indices[sorted_loss_values > thresholdfivetenpercent], axis=0)

filtered_data_twenty_percent = np.delete(X_train, sorted_indices[sorted_loss_values > thresholdtwentypercent], axis=0)
filtered_labels_twenty_percent = np.delete(y_train, sorted_indices[sorted_loss_values > thresholdtwentypercent], axis=0)

filtered_data_twentyfive_percent = np.delete(X_train, sorted_indices[sorted_loss_values > thresholdtwentyfivepercent], axis=0)
filtered_labels_twentyfive_percent = np.delete(y_train, sorted_indices[sorted_loss_values > thresholdtwentyfivepercent], axis=0)

filtered_data_thirty_percent = np.delete(X_train, sorted_indices[sorted_loss_values > thresholdthirtypercent], axis=0)
filtered_labels_thirty_percent = np.delete(y_train, sorted_indices[sorted_loss_values > thresholdthirtypercent], axis=0)

# %%
"Configurations for ResNet in Regression Mode"
length = filtered_data_one_percent.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

one_percent_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet50()
one_percent_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.001), metrics= ['mse']) # Compile Model

one_percent_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('one_percent.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
one_percent_Model_history = one_percent_Model.fit(filtered_data_one_percent, filtered_labels_one_percent, 
                                                  epochs=250, batch_size=64, verbose=1, shuffle=True)

plt.figure()
plt.plot(one_percent_Model_history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
one_percent_Model.evaluate(filtered_data_one_percent, filtered_labels_one_percent)
ypred_one_percent = one_percent_Model.predict(filtered_data_one_percent)

print('MSE: ',mean_squared_error(filtered_labels_one_percent, ypred_one_percent))
print('RMSE: ',math.sqrt(mean_squared_error(filtered_labels_one_percent, ypred_one_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(filtered_labels_one_percent, ypred_one_percent))

# # Inverse transform the predictions and actual values
ypred_one_percent = (ypred_one_percent * (maxForcePlate - minForcePlate)) + minForcePlate
y_real_one_percent = (filtered_labels_one_percent * (maxForcePlate - minForcePlate)) + minForcePlate


print('MSE: ',mean_squared_error(y_real_one_percent, ypred_one_percent))
print('RMSE: ',math.sqrt(mean_squared_error(y_real_one_percent, ypred_one_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real_one_percent, ypred_one_percent))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real_one_percent[0:3000,i],color='red')
    plt.plot(x,ypred_one_percent[0:3000,i], markerfacecolor='none',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(one_percent_Model, 'one_percent.h5')
#End Training Process

# Load Model to Predict Real Data
load_one_percent_Model = tf.keras.models.load_model('one_percent.h5')

load_one_percent_Model.evaluate(X_test, y_test)
Test_Pred_one_percent = load_one_percent_Model.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred_one_percent))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred_one_percent)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred_one_percent))

predictions_one_percent = (Test_Pred_one_percent * (maxForcePlate - minForcePlate)) + minForcePlate
Real_one_percent = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions_one_percent = predictions_one_percent[np.argsort(Test_indices)]
Real_one_percent = Real_one_percent[np.argsort(Test_indices)]

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real_one_percent[0:2000,i],color='red')
    plt.plot(x,predictions_one_percent[0:2000,i], color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
import numpy as np
import pandas as pd
# import seaborn as sns
from numpy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Conv2D, MaxPooling2D, Reshape, Flatten, Dense
from keras.models import Model, model_from_json
from keras.optimizers import Adam, RMSprop
# from tensorflow.keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import Normalizer,MinMaxScaler,StandardScaler, RobustScaler, QuantileTransformer, PowerTransformer
# sns.set_theme(style="whitegrid")
import pywt
np.set_printoptions(suppress=True)
# Import ResNet1D Module
from ResNet_1DCNN import ResNet
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error, r2_score

columns = ['Fx']
wavelet = 'db4'
max_iter = 50
iter = 0

def seed_everything(seed=42):
    np.random.seed(seed)
    tf.random.set_seed(seed)

# Training Process
# columns = ['Fx','Fy','Fz','Mx','My','Mz']

# Standing Dataset
InsoleStanding1 = pd.read_csv('0310AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding2 = pd.read_csv('0310HudaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding3 = pd.read_csv('0311LalaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding4 = pd.read_csv('0311YunitaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding5 = pd.read_csv('0312AbelStand5Min1.txt', header=None, low_memory=False)
InsoleStanding6 = pd.read_csv('0312AbiStand5Min1.txt', header=None, low_memory=False)
InsoleStanding7 = pd.read_csv('0312AryaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding8 = pd.read_csv('0312HawaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding9 = pd.read_csv('0312NisaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding10 = pd.read_csv('0313ChenChengStand5Min1.txt', header=None, low_memory=False)
InsoleStanding11 = pd.read_csv('0313RezaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding12 = pd.read_csv('0313RilaniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding13 = pd.read_csv('0313SariStand5Min1.txt', header=None, low_memory=False)
InsoleStanding14 = pd.read_csv('0313ShelbyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding15 = pd.read_csv('0314HelenStand5Min1.txt', header=None, low_memory=False)
InsoleStanding16 = pd.read_csv('0315AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding17 = pd.read_csv('0315HappyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding18 = pd.read_csv('0317HeniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding19 = pd.read_csv('0317NadiaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding20 = pd.read_csv('0317VikaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding21 = pd.read_csv('0319AlfianStand5Min1.txt', header=None, low_memory=False)
InsoleStanding22 = pd.read_csv('0310JakaStand2Min.txt', header=None, low_memory=False)
SIDatasStanding1 =  np.array(InsoleStanding1)
SIDatasStanding2 =  np.array(InsoleStanding2)
SIDatasStanding3 =  np.array(InsoleStanding3)
SIDatasStanding4 =  np.array(InsoleStanding4)
SIDatasStanding5 =  np.array(InsoleStanding5)
SIDatasStanding6 =  np.array(InsoleStanding6)
SIDatasStanding7 =  np.array(InsoleStanding7)
SIDatasStanding8 =  np.array(InsoleStanding8)
SIDatasStanding9 =  np.array(InsoleStanding9)
SIDatasStanding10 =  np.array(InsoleStanding10)
SIDatasStanding11 =  np.array(InsoleStanding11)
SIDatasStanding12 =  np.array(InsoleStanding12)
SIDatasStanding13 =  np.array(InsoleStanding13)
SIDatasStanding14 =  np.array(InsoleStanding14)
SIDatasStanding15 =  np.array(InsoleStanding15)
SIDatasStanding16 =  np.array(InsoleStanding16)
SIDatasStanding17 =  np.array(InsoleStanding17)
SIDatasStanding18 =  np.array(InsoleStanding18)
SIDatasStanding19 =  np.array(InsoleStanding19)
SIDatasStanding20 =  np.array(InsoleStanding20)
SIDatasStanding21 =  np.array(InsoleStanding21)

dfStanding1 = pd.read_csv('0310AyuStand5Min1.csv', low_memory=False)
dfStanding2 = pd.read_csv('0310HudaStand5Min1.csv', low_memory=False)
dfStanding3 = pd.read_csv('0311LalaStand5Min1.csv', low_memory=False)
dfStanding4 = pd.read_csv('0311YunitaStand5Min1.csv', low_memory=False)
dfStanding5 = pd.read_csv('0312AbelStand5Min1.csv', low_memory=False)
dfStanding6 = pd.read_csv('0312AbiStand5Min1.csv', low_memory=False)
dfStanding7 = pd.read_csv('0312AryaStand5Min1.csv', low_memory=False)
dfStanding8 = pd.read_csv('0312HawaStand5Min1.csv', low_memory=False)
dfStanding9 = pd.read_csv('0312NisaStand5Min1.csv', low_memory=False)
dfStanding10 = pd.read_csv('0313ChenChengStand5Min1.csv', low_memory=False)
dfStanding11 = pd.read_csv('0313RezaStand5Min1.csv', low_memory=False)
dfStanding12 = pd.read_csv('0313RilaniStand5Min1.csv', low_memory=False)
dfStanding13 = pd.read_csv('0313SariStand5Min1.csv', low_memory=False)
dfStanding14 = pd.read_csv('0313ShelbyStand5Min1.csv', low_memory=False)
dfStanding15 = pd.read_csv('0314HelenStand5Min1.csv', low_memory=False)
dfStanding16 = pd.read_csv('0315AyuStand5Min1.csv', low_memory=False)
dfStanding17 = pd.read_csv('0315HappyStand5Min1.csv', low_memory=False)
dfStanding18 = pd.read_csv('0317HeniStand5Min1.csv', low_memory=False)
dfStanding19 = pd.read_csv('0317NadiaStand5Min1.csv', low_memory=False)
dfStanding20 = pd.read_csv('0317VikaStand5Min1.csv', low_memory=False)
dfStanding21 = pd.read_csv('0319AlfianStand5Min1.csv', low_memory=False)

selected_dfStandings1 = dfStanding1[columns]
selected_dfStandings2 = dfStanding2[columns]
selected_dfStandings3 = dfStanding3[columns]
selected_dfStandings4 = dfStanding4[columns]
selected_dfStandings5 = dfStanding5[columns]
selected_dfStandings6 = dfStanding6[columns]
selected_dfStandings7 = dfStanding7[columns]
selected_dfStandings8 = dfStanding8[columns]
selected_dfStandings9 = dfStanding9[columns]
selected_dfStandings10 = dfStanding10[columns]
selected_dfStandings11 = dfStanding11[columns]
selected_dfStandings12 = dfStanding12[columns]
selected_dfStandings13 = dfStanding13[columns]
selected_dfStandings14 = dfStanding14[columns]
selected_dfStandings15 = dfStanding15[columns]
selected_dfStandings16 = dfStanding16[columns]
selected_dfStandings17 = dfStanding17[columns]
selected_dfStandings18 = dfStanding18[columns]
selected_dfStandings19 = dfStanding19[columns]
selected_dfStandings20 = dfStanding20[columns]
selected_dfStandings21 = dfStanding21[columns]
FPDataStandings1 = selected_dfStandings1[:15000]
FPDataStandings2 = selected_dfStandings2[:15000]
FPDataStandings3 = selected_dfStandings3[:15000]
FPDataStandings4 = selected_dfStandings4[:15000]
FPDataStandings5 = selected_dfStandings5[:15000]
FPDataStandings6 = selected_dfStandings6[:15000]
FPDataStandings7 = selected_dfStandings7[:15000]
FPDataStandings8 = selected_dfStandings8[:15000]
FPDataStandings9 = selected_dfStandings9[:15000]
FPDataStandings10 = selected_dfStandings10[:15000]
FPDataStandings11 = selected_dfStandings11[:15000]
FPDataStandings12 = selected_dfStandings12[:15000]
FPDataStandings13 = selected_dfStandings13[:15000]
FPDataStandings14 = selected_dfStandings14[:15000]
FPDataStandings15 = selected_dfStandings15[:15000]
FPDataStandings16 = selected_dfStandings16[:15000]
FPDataStandings17 = selected_dfStandings17[:15000]
FPDataStandings18 = selected_dfStandings18[:15000]
FPDataStandings19 = selected_dfStandings19[:15000]
FPDataStandings20 = selected_dfStandings20[:15000]
FPDataStandings21 = selected_dfStandings21[:15000]

SIDataStanding1 = np.array(SIDatasStanding1[:15000]).astype('float32')
SIDataStanding2 = np.array(SIDatasStanding2[:15000]).astype('float32')
SIDataStanding3 = np.array(SIDatasStanding3[:15000]).astype('float32')
SIDataStanding4 = np.array(SIDatasStanding4[:15000]).astype('float32')
SIDataStanding5 = np.array(SIDatasStanding5[:15000]).astype('float32')
SIDataStanding6 = np.array(SIDatasStanding6[:15000]).astype('float32')
SIDataStanding7 = np.array(SIDatasStanding7[:15000]).astype('float32')
SIDataStanding8 = np.array(SIDatasStanding8[:15000]).astype('float32')
SIDataStanding9 = np.array(SIDatasStanding9[:15000]).astype('float32')
SIDataStanding10 = np.array(SIDatasStanding10[:15000]).astype('float32')
SIDataStanding11 = np.array(SIDatasStanding11[:15000]).astype('float32')
SIDataStanding12 = np.array(SIDatasStanding12[:15000]).astype('float32')
SIDataStanding13 = np.array(SIDatasStanding13[:15000]).astype('float32')
SIDataStanding14 = np.array(SIDatasStanding14[:15000]).astype('float32')
SIDataStanding15 = np.array(SIDatasStanding15[:15000]).astype('float32')
SIDataStanding16 = np.array(SIDatasStanding16[:15000]).astype('float32')
SIDataStanding17 = np.array(SIDatasStanding17[:15000]).astype('float32')
SIDataStanding18 = np.array(SIDatasStanding18[:15000]).astype('float32')
SIDataStanding19 = np.array(SIDatasStanding19[:15000]).astype('float32')
SIDataStanding20 = np.array(SIDatasStanding20[:15000]).astype('float32')
SIDataStanding21 = np.array(SIDatasStanding21[:15000]).astype('float32')
FPDataStanding1 = np.array(FPDataStandings1).astype('float32')
FPDataStanding2 = np.array(FPDataStandings2).astype('float32')
FPDataStanding3= np.array(FPDataStandings3).astype('float32')
FPDataStanding4= np.array(FPDataStandings4).astype('float32')
FPDataStanding5= np.array(FPDataStandings5).astype('float32')
FPDataStanding6= np.array(FPDataStandings6).astype('float32')
FPDataStanding7= np.array(FPDataStandings7).astype('float32')
FPDataStanding8= np.array(FPDataStandings8).astype('float32')
FPDataStanding9= np.array(FPDataStandings9).astype('float32')
FPDataStanding10 = np.array(FPDataStandings10).astype('float32')
FPDataStanding11 = np.array(FPDataStandings11).astype('float32')
FPDataStanding12= np.array(FPDataStandings12).astype('float32')
FPDataStanding13= np.array(FPDataStandings13).astype('float32')
FPDataStanding14= np.array(FPDataStandings14).astype('float32')
FPDataStanding15= np.array(FPDataStandings15).astype('float32')
FPDataStanding16= np.array(FPDataStandings16).astype('float32')
FPDataStanding17= np.array(FPDataStandings17).astype('float32')
FPDataStanding18= np.array(FPDataStandings18).astype('float32')
FPDataStanding19= np.array(FPDataStandings19).astype('float32')
FPDataStanding20= np.array(FPDataStandings20).astype('float32')
FPDataStanding21= np.array(FPDataStandings21).astype('float32')

# SIDatasetStanding = np.concatenate((SIDataStanding1, SIDataStanding2, SIDataStanding3,
#                             SIDataStanding4, SIDataStanding5, SIDataStanding6,
#                             SIDataStanding8, SIDataStanding9,
#                             SIDataStanding10, SIDataStanding11, SIDataStanding12,
#                             SIDataStanding13, SIDataStanding14, SIDataStanding15,
#                             SIDataStanding16, SIDataStanding17, SIDataStanding18,
#                             SIDataStanding19, SIDataStanding20, SIDataStanding21,
#                             SIDataStanding7), axis=0)


# FPDatasetStanding = np.concatenate((FPDataStanding1, FPDataStanding2, FPDataStanding3,
#                             FPDataStanding4, FPDataStanding5, FPDataStanding6,
#                             FPDataStanding8, FPDataStanding9,
#                             FPDataStanding10, FPDataStanding11, FPDataStanding12,
#                             FPDataStanding13, FPDataStanding14, FPDataStanding15,
#                             FPDataStanding16, FPDataStanding17, FPDataStanding18,
#                             FPDataStanding19, FPDataStanding20, FPDataStanding21,
#                             FPDataStanding7), axis=0)

SIDatasetStanding = np.concatenate((SIDataStanding3,SIDataStanding6,SIDataStanding9,
                                    SIDataStanding10, SIDataStanding19, SIDataStanding7), axis=0)


FPDatasetStanding = np.concatenate((FPDataStanding3,FPDataStanding6, FPDataStanding9,
                            FPDataStanding10, FPDataStanding19, FPDataStanding7), axis=0)


SIDatasetStanding = SIDatasetStanding
FPDatasetStanding = FPDatasetStanding

SIDatasetStanding = np.array(SIDatasetStanding).astype('float32')
FPDatasetStanding = np.array(FPDatasetStanding).astype('float32')

SIDataset = SIDatasetStanding
FPDataset = FPDatasetStanding


SIDWTcoeffs = []
for i in range(89):
    coeffs = pywt.wavedec(SIDataset[:, i], wavelet)
    coeffs[-1] = np.zeros_like(coeffs[-1])
#     coeffs[-2] = np.zeros_like(coeffs[-2])
#     coeffs[-3] = np.zeros_like(coeffs[-3])
#     coeffs[-4] = np.zeros_like(coeffs[-4])
#     coeffs[-5] = np.zeros_like(coeffs[-5])
#     coeffs[-6] = np.zeros_like(coeffs[-6])
    SIDWTcoeffs.append(coeffs)

SIData_filtered = np.zeros(SIDataset.shape)
for i in range(89):
    SIData_filtered[:, i] = pywt.waverec(SIDWTcoeffs[i], wavelet, mode='symmetric', axis=0)

SIids = [0,10,11,12,22,41,42,48,49,50,59,63,74,75,76,77,78]

SIselection=[]

for i in range(len(SIDataset)):
  SIselection.append(SIDataset[i][SIids])

SIselection = np.array(SIselection)

# Exclude the first column
data = SIselection[:, 1:]

# Find zero values in the remaining data
zero_mask = (data == 0.0)

# Calculate the mean, excluding zero values
mean_value = np.mean(data[~zero_mask])

# Replace zero values with the mean, excluding the first column
SIselection[:, 1:][zero_mask] = mean_value

max_iter = 50
iter = 0
for i in range(len(SIselection)):
    SIselection[i][0] = SIselection[i][0] + (iter % max_iter) + 1
    iter += 1


# label = pd.read_csv('label.txt', header=None, low_memory=False)
# labelData = np.array(label)
# Label = np.array(labelData[:15000]).astype('float32')

# label_data = np.tile(Label, (X_selected.shape[0] // Label.shape[0], 1))
# print(label_data[15000:15010])

# SIlabeled = np.concatenate((label_data, X_selected), axis=1)

# Scale the smart insole data
minInsole = SIselection.min()
maxInsole = SIselection.max()
smart_insole_data_scaled = (SIselection - minInsole) / ( maxInsole - minInsole )

# Scale the force plate data
minForcePlate = FPDataset.min()
maxForcePlate = FPDataset.max()
force_plate_data_scaled = (FPDataset - minForcePlate) / ( maxForcePlate - minForcePlate )


#Spliting Data
sample_size = smart_insole_data_scaled.shape[0] # number of samples in train set
time_steps  = smart_insole_data_scaled.shape[1] # number of features in train set
input_dimension = 1               # each feature is represented by 1 number

train_data_reshaped = smart_insole_data_scaled.reshape(sample_size,time_steps,input_dimension)

# X_train, X_test, y_train, y_test = train_test_split(train_data_reshaped[:13000],
#                                                     force_plate_data_scaled[:13000],
#                                                     test_size=0.20, random_state=2)

smart_insole_data_scaled_Train = train_data_reshaped[:75000]
smart_insole_data_scaled_Test = train_data_reshaped[75000:]
force_plate_data_scaled_Train = force_plate_data_scaled[:75000]
force_plate_data_scaled_Test = force_plate_data_scaled[75000:]

# Generate random indices for shuffling the data
indices = np.arange(smart_insole_data_scaled_Train.shape[0])
np.random.shuffle(indices)

seed_everything(42)
# Use the shuffled indices to randomly select training data
X_train = smart_insole_data_scaled_Train[indices]
y_train = force_plate_data_scaled_Train[indices]

Test_indices = np.arange(smart_insole_data_scaled_Test.shape[0])
np.random.shuffle(Test_indices)

seed_everything(42)
# # Assign the test data
X_test = smart_insole_data_scaled_Test[Test_indices]
y_test = force_plate_data_scaled_Test[Test_indices]

print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)

"Configurations for ResNet in Regression Mode"
length = X_train.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

Regression_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet18()
Regression_Model.compile(loss='mae', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

Regression_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('Saved_Model.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, shuffle=True)

plt.figure()
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
Regression_Model.evaluate(X_train, y_train)
ypred = Regression_Model.predict(X_train)

print('MSE: ',mean_squared_error(y_train, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_train, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_train, ypred))

# # Inverse transform the predictions and actual values
y_pred = (ypred * (maxForcePlate - minForcePlate)) + minForcePlate
y_real = (y_train * (maxForcePlate - minForcePlate)) + minForcePlate

# y_pred = y_pred[np.argsort(indices)]
# y_real = y_real[np.argsort(indices)]

print('MSE: ',mean_squared_error(y_real, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_real, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real, ypred))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real[0:3000,i],color='red')
    plt.plot(x,y_pred[0:3000,i], markerfacecolor='none',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(Regression_Model, '1ouput.h5')
#End Training Process

# Load Model to Predict Real Data
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(X_test, y_test)
Test_Pred = modelCoy.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred))

predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
Real = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions = predictions[np.argsort(Test_indices)]
Real = Real[np.argsort(Test_indices)]

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:2000,i],color='red')
    plt.plot(x,predictions[0:2000,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
SIselection[10]

# %%
# # Calculate the mean, excluding zeros
# mean_value = np.mean(SIselection[SIselection[1:] != 0.0])

# # Replace zeros with the mean
# SIselection[SIselection[1:] == 0.0] = mean_value

# print(SIselection[10])

# Exclude the first column
data = SIselection[:, 1:]

# Find zero values in the remaining data
zero_mask = (data == 0.0)

# Calculate the mean, excluding zero values
mean_value = np.mean(data[~zero_mask])

# Replace zero values with the mean, excluding the first column
SIselection[:, 1:][zero_mask] = mean_value

print(SIselection[10])

# %%
import numpy as np

SmartInsole = np.array([
    [0.0, 78.0, 55.0, 45.0, 88.0],
    [0.0, 78.0, 55.0, 45.0, 88.0],
    [0.0, 53.0, 30.0, 57.0, 75.0],
    [0.0, 53.0, 30.0, 57.0, 75.0],
    [0.0, 53.0, 30.0, 57.0, 75.0],
    [0.0, 33.0, 70.0, 0.0, 90.0],
    [0.0, 33.0, 70.0, 34.0, 90.0],
    [0.0, 33.0, 70.0, 34.0, 90.0],
    [0.0, 33.0, 70.0, 34.0, 90.0],
    [0.0, 33.0, 70.0, 34.0, 90.0],
])

# Exclude the first column
data = SmartInsole[:, 1:]

# Find zero values in the remaining data
zero_mask = (data == 0.0)

# Calculate the mean, excluding zero values
mean_value = np.mean(data[~zero_mask])

# Replace zero values with the mean, excluding the first column
SmartInsole[:, 1:][zero_mask] = mean_value

print(SmartInsole)

# %%
import numpy as np
import pandas as pd
# import seaborn as sns
from numpy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Conv2D, MaxPooling2D, Reshape, Flatten, Dense
from keras.models import Model, model_from_json
from keras.optimizers import Adam, RMSprop
# from tensorflow.keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import Normalizer,MinMaxScaler,StandardScaler, RobustScaler, QuantileTransformer, PowerTransformer
# sns.set_theme(style="whitegrid")
import pywt
np.set_printoptions(suppress=True)
# Import ResNet1D Module
from ResNet_1DCNN import ResNet
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error, r2_score

columns = ['Fx']
wavelet = 'db4'
max_iter = 50
iter = 0

def seed_everything(seed=42):
    np.random.seed(seed)
    tf.random.set_seed(seed)

# Training Process
# columns = ['Fx','Fy','Fz','Mx','My','Mz']

# Standing Dataset
InsoleStanding1 = pd.read_csv('0310AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding2 = pd.read_csv('0310HudaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding3 = pd.read_csv('0311LalaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding4 = pd.read_csv('0311YunitaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding5 = pd.read_csv('0312AbelStand5Min1.txt', header=None, low_memory=False)
InsoleStanding6 = pd.read_csv('0312AbiStand5Min1.txt', header=None, low_memory=False)
InsoleStanding7 = pd.read_csv('0312AryaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding8 = pd.read_csv('0312HawaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding9 = pd.read_csv('0312NisaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding10 = pd.read_csv('0313ChenChengStand5Min1.txt', header=None, low_memory=False)
InsoleStanding11 = pd.read_csv('0313RezaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding12 = pd.read_csv('0313RilaniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding13 = pd.read_csv('0313SariStand5Min1.txt', header=None, low_memory=False)
InsoleStanding14 = pd.read_csv('0313ShelbyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding15 = pd.read_csv('0314HelenStand5Min1.txt', header=None, low_memory=False)
InsoleStanding16 = pd.read_csv('0315AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding17 = pd.read_csv('0315HappyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding18 = pd.read_csv('0317HeniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding19 = pd.read_csv('0317NadiaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding20 = pd.read_csv('0317VikaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding21 = pd.read_csv('0319AlfianStand5Min1.txt', header=None, low_memory=False)
InsoleStanding22 = pd.read_csv('0310JakaStand2Min.txt', header=None, low_memory=False)
SIDatasStanding1 =  np.array(InsoleStanding1)
SIDatasStanding2 =  np.array(InsoleStanding2)
SIDatasStanding3 =  np.array(InsoleStanding3)
SIDatasStanding4 =  np.array(InsoleStanding4)
SIDatasStanding5 =  np.array(InsoleStanding5)
SIDatasStanding6 =  np.array(InsoleStanding6)
SIDatasStanding7 =  np.array(InsoleStanding7)
SIDatasStanding8 =  np.array(InsoleStanding8)
SIDatasStanding9 =  np.array(InsoleStanding9)
SIDatasStanding10 =  np.array(InsoleStanding10)
SIDatasStanding11 =  np.array(InsoleStanding11)
SIDatasStanding12 =  np.array(InsoleStanding12)
SIDatasStanding13 =  np.array(InsoleStanding13)
SIDatasStanding14 =  np.array(InsoleStanding14)
SIDatasStanding15 =  np.array(InsoleStanding15)
SIDatasStanding16 =  np.array(InsoleStanding16)
SIDatasStanding17 =  np.array(InsoleStanding17)
SIDatasStanding18 =  np.array(InsoleStanding18)
SIDatasStanding19 =  np.array(InsoleStanding19)
SIDatasStanding20 =  np.array(InsoleStanding20)
SIDatasStanding21 =  np.array(InsoleStanding21)

dfStanding1 = pd.read_csv('0310AyuStand5Min1.csv', low_memory=False)
dfStanding2 = pd.read_csv('0310HudaStand5Min1.csv', low_memory=False)
dfStanding3 = pd.read_csv('0311LalaStand5Min1.csv', low_memory=False)
dfStanding4 = pd.read_csv('0311YunitaStand5Min1.csv', low_memory=False)
dfStanding5 = pd.read_csv('0312AbelStand5Min1.csv', low_memory=False)
dfStanding6 = pd.read_csv('0312AbiStand5Min1.csv', low_memory=False)
dfStanding7 = pd.read_csv('0312AryaStand5Min1.csv', low_memory=False)
dfStanding8 = pd.read_csv('0312HawaStand5Min1.csv', low_memory=False)
dfStanding9 = pd.read_csv('0312NisaStand5Min1.csv', low_memory=False)
dfStanding10 = pd.read_csv('0313ChenChengStand5Min1.csv', low_memory=False)
dfStanding11 = pd.read_csv('0313RezaStand5Min1.csv', low_memory=False)
dfStanding12 = pd.read_csv('0313RilaniStand5Min1.csv', low_memory=False)
dfStanding13 = pd.read_csv('0313SariStand5Min1.csv', low_memory=False)
dfStanding14 = pd.read_csv('0313ShelbyStand5Min1.csv', low_memory=False)
dfStanding15 = pd.read_csv('0314HelenStand5Min1.csv', low_memory=False)
dfStanding16 = pd.read_csv('0315AyuStand5Min1.csv', low_memory=False)
dfStanding17 = pd.read_csv('0315HappyStand5Min1.csv', low_memory=False)
dfStanding18 = pd.read_csv('0317HeniStand5Min1.csv', low_memory=False)
dfStanding19 = pd.read_csv('0317NadiaStand5Min1.csv', low_memory=False)
dfStanding20 = pd.read_csv('0317VikaStand5Min1.csv', low_memory=False)
dfStanding21 = pd.read_csv('0319AlfianStand5Min1.csv', low_memory=False)

selected_dfStandings1 = dfStanding1[columns]
selected_dfStandings2 = dfStanding2[columns]
selected_dfStandings3 = dfStanding3[columns]
selected_dfStandings4 = dfStanding4[columns]
selected_dfStandings5 = dfStanding5[columns]
selected_dfStandings6 = dfStanding6[columns]
selected_dfStandings7 = dfStanding7[columns]
selected_dfStandings8 = dfStanding8[columns]
selected_dfStandings9 = dfStanding9[columns]
selected_dfStandings10 = dfStanding10[columns]
selected_dfStandings11 = dfStanding11[columns]
selected_dfStandings12 = dfStanding12[columns]
selected_dfStandings13 = dfStanding13[columns]
selected_dfStandings14 = dfStanding14[columns]
selected_dfStandings15 = dfStanding15[columns]
selected_dfStandings16 = dfStanding16[columns]
selected_dfStandings17 = dfStanding17[columns]
selected_dfStandings18 = dfStanding18[columns]
selected_dfStandings19 = dfStanding19[columns]
selected_dfStandings20 = dfStanding20[columns]
selected_dfStandings21 = dfStanding21[columns]
FPDataStandings1 = selected_dfStandings1[:15000]
FPDataStandings2 = selected_dfStandings2[:15000]
FPDataStandings3 = selected_dfStandings3[:15000]
FPDataStandings4 = selected_dfStandings4[:15000]
FPDataStandings5 = selected_dfStandings5[:15000]
FPDataStandings6 = selected_dfStandings6[:15000]
FPDataStandings7 = selected_dfStandings7[:15000]
FPDataStandings8 = selected_dfStandings8[:15000]
FPDataStandings9 = selected_dfStandings9[:15000]
FPDataStandings10 = selected_dfStandings10[:15000]
FPDataStandings11 = selected_dfStandings11[:15000]
FPDataStandings12 = selected_dfStandings12[:15000]
FPDataStandings13 = selected_dfStandings13[:15000]
FPDataStandings14 = selected_dfStandings14[:15000]
FPDataStandings15 = selected_dfStandings15[:15000]
FPDataStandings16 = selected_dfStandings16[:15000]
FPDataStandings17 = selected_dfStandings17[:15000]
FPDataStandings18 = selected_dfStandings18[:15000]
FPDataStandings19 = selected_dfStandings19[:15000]
FPDataStandings20 = selected_dfStandings20[:15000]
FPDataStandings21 = selected_dfStandings21[:15000]

SIDataStanding1 = np.array(SIDatasStanding1[:15000]).astype('float64')
SIDataStanding2 = np.array(SIDatasStanding2[:15000]).astype('float64')
SIDataStanding3 = np.array(SIDatasStanding3[:15000]).astype('float64')
SIDataStanding4 = np.array(SIDatasStanding4[:15000]).astype('float64')
SIDataStanding5 = np.array(SIDatasStanding5[:15000]).astype('float64')
SIDataStanding6 = np.array(SIDatasStanding6[:15000]).astype('float64')
SIDataStanding7 = np.array(SIDatasStanding7[:15000]).astype('float64')
SIDataStanding8 = np.array(SIDatasStanding8[:15000]).astype('float64')
SIDataStanding9 = np.array(SIDatasStanding9[:15000]).astype('float64')
SIDataStanding10 = np.array(SIDatasStanding10[:15000]).astype('float64')
SIDataStanding11 = np.array(SIDatasStanding11[:15000]).astype('float64')
SIDataStanding12 = np.array(SIDatasStanding12[:15000]).astype('float64')
SIDataStanding13 = np.array(SIDatasStanding13[:15000]).astype('float64')
SIDataStanding14 = np.array(SIDatasStanding14[:15000]).astype('float64')
SIDataStanding15 = np.array(SIDatasStanding15[:15000]).astype('float64')
SIDataStanding16 = np.array(SIDatasStanding16[:15000]).astype('float64')
SIDataStanding17 = np.array(SIDatasStanding17[:15000]).astype('float64')
SIDataStanding18 = np.array(SIDatasStanding18[:15000]).astype('float64')
SIDataStanding19 = np.array(SIDatasStanding19[:15000]).astype('float64')
SIDataStanding20 = np.array(SIDatasStanding20[:15000]).astype('float64')
SIDataStanding21 = np.array(SIDatasStanding21[:15000]).astype('float64')
FPDataStanding1 = np.array(FPDataStandings1).astype('float64')
FPDataStanding2 = np.array(FPDataStandings2).astype('float64')
FPDataStanding3= np.array(FPDataStandings3).astype('float64')
FPDataStanding4= np.array(FPDataStandings4).astype('float64')
FPDataStanding5= np.array(FPDataStandings5).astype('float64')
FPDataStanding6= np.array(FPDataStandings6).astype('float64')
FPDataStanding7= np.array(FPDataStandings7).astype('float64')
FPDataStanding8= np.array(FPDataStandings8).astype('float64')
FPDataStanding9= np.array(FPDataStandings9).astype('float64')
FPDataStanding10 = np.array(FPDataStandings10).astype('float64')
FPDataStanding11 = np.array(FPDataStandings11).astype('float64')
FPDataStanding12= np.array(FPDataStandings12).astype('float64')
FPDataStanding13= np.array(FPDataStandings13).astype('float64')
FPDataStanding14= np.array(FPDataStandings14).astype('float64')
FPDataStanding15= np.array(FPDataStandings15).astype('float64')
FPDataStanding16= np.array(FPDataStandings16).astype('float64')
FPDataStanding17= np.array(FPDataStandings17).astype('float64')
FPDataStanding18= np.array(FPDataStandings18).astype('float64')
FPDataStanding19= np.array(FPDataStandings19).astype('float64')
FPDataStanding20= np.array(FPDataStandings20).astype('float64')
FPDataStanding21= np.array(FPDataStandings21).astype('float64')

# SIDatasetStanding = np.concatenate((SIDataStanding1, SIDataStanding2, SIDataStanding3,
#                             SIDataStanding4, SIDataStanding5, SIDataStanding6,
#                             SIDataStanding8, SIDataStanding9,
#                             SIDataStanding10, SIDataStanding11, SIDataStanding12,
#                             SIDataStanding13, SIDataStanding14, SIDataStanding15,
#                             SIDataStanding16, SIDataStanding17, SIDataStanding18,
#                             SIDataStanding19, SIDataStanding20, SIDataStanding21,
#                             SIDataStanding7), axis=0)


# FPDatasetStanding = np.concatenate((FPDataStanding1, FPDataStanding2, FPDataStanding3,
#                             FPDataStanding4, FPDataStanding5, FPDataStanding6,
#                             FPDataStanding8, FPDataStanding9,
#                             FPDataStanding10, FPDataStanding11, FPDataStanding12,
#                             FPDataStanding13, FPDataStanding14, FPDataStanding15,
#                             FPDataStanding16, FPDataStanding17, FPDataStanding18,
#                             FPDataStanding19, FPDataStanding20, FPDataStanding21,
#                             FPDataStanding7), axis=0)

SIDatasetStanding = np.concatenate((SIDataStanding3,SIDataStanding6,SIDataStanding9,
                                    SIDataStanding10, SIDataStanding19, SIDataStanding7), axis=0)


FPDatasetStanding = np.concatenate((FPDataStanding3,FPDataStanding6, FPDataStanding9,
                            FPDataStanding10, FPDataStanding19, FPDataStanding7), axis=0)


SIDatasetStanding = SIDatasetStanding
FPDatasetStanding = FPDatasetStanding

SIDatasetStanding = np.array(SIDatasetStanding).astype('float64')
FPDatasetStanding = np.array(FPDatasetStanding).astype('float64')

SIDataset = SIDatasetStanding
FPDataset = FPDatasetStanding


SIDWTcoeffs = []
for i in range(89):
    coeffs = pywt.wavedec(SIDataset[:, i], wavelet)
    coeffs[-1] = np.zeros_like(coeffs[-1])
#     coeffs[-2] = np.zeros_like(coeffs[-2])
#     coeffs[-3] = np.zeros_like(coeffs[-3])
#     coeffs[-4] = np.zeros_like(coeffs[-4])
#     coeffs[-5] = np.zeros_like(coeffs[-5])
#     coeffs[-6] = np.zeros_like(coeffs[-6])
    SIDWTcoeffs.append(coeffs)

SIData_filtered = np.zeros(SIDataset.shape)
for i in range(89):
    SIData_filtered[:, i] = pywt.waverec(SIDWTcoeffs[i], wavelet, mode='symmetric', axis=0)

# SIids = [0,10,11,12,22,41,42,48,49,50,59,63,74,75,76,77,78]

# SIselection=[]

# for i in range(len(SIData_filtered)):
#   SIselection.append(SIData_filtered[i][SIids])

# SIselection = np.array(SIselection)

# from sklearn.decomposition import PCA
# from sklearn.model_selection import KFold
# from numpy import zeros, newaxis
# from sklearn.feature_selection import f_regression, mutual_info_regression, mutual_info_classif
# from sklearn.feature_selection import SelectKBest
# from sklearn.feature_selection import f_regression

# SIDataPCA = SIData_filtered
# print(SIDataPCA.shape)
# pca = PCA(n_components=0.98)
# pca.fit(SIDataPCA)
# SIdata_pca = pca.transform(SIDataPCA)

# print(SIdata_pca.shape, FPDataset.shape)
# # define feature selection
# fs = SelectKBest(score_func=f_regression, k=5)
# # apply feature selection
# X_selected = fs.fit_transform(SIdata_pca, FPDataset)
# print(X_selected.shape)


max_iter = 50
iter = 0
for i in range(len(SIData_filtered)):
    SIData_filtered[i][0] = SIData_filtered[i][0] + (iter % max_iter) + 1
    iter += 1
    

FPDWTcoeffs = []
for i in range(1):
    coeffs = pywt.wavedec(FPDataset[:, i], wavelet)
    coeffs[-1] = np.zeros_like(coeffs[-1])
    coeffs[-2] = np.zeros_like(coeffs[-2])
    coeffs[-3] = np.zeros_like(coeffs[-3])
    coeffs[-4] = np.zeros_like(coeffs[-4])
    coeffs[-5] = np.zeros_like(coeffs[-5])
    coeffs[-6] = np.zeros_like(coeffs[-6])
    FPDWTcoeffs.append(coeffs)

FPData_filtered = np.zeros(FPDataset.shape)
for i in range(1):
    FPData_filtered[:, i] = pywt.waverec(FPDWTcoeffs[i], wavelet, mode='symmetric', axis=0)



# label = pd.read_csv('label.txt', header=None, low_memory=False)
# labelData = np.array(label)
# Label = np.array(labelData[:15000]).astype('float32')

# label_data = np.tile(Label, (X_selected.shape[0] // Label.shape[0], 1))
# print(label_data[15000:15010])

# SIlabeled = np.concatenate((label_data, X_selected), axis=1)

# Scale the smart insole data
minInsole = SIData_filtered.min()
maxInsole = SIData_filtered.max()
smart_insole_data_scaled = (SIData_filtered - minInsole) / ( maxInsole - minInsole )

# Scale the force plate data
minForcePlate = FPData_filtered.min()
maxForcePlate = FPData_filtered.max()
force_plate_data_scaled = (FPData_filtered - minForcePlate) / ( maxForcePlate - minForcePlate )


#Spliting Data
sample_size = smart_insole_data_scaled.shape[0] # number of samples in train set
time_steps  = smart_insole_data_scaled.shape[1] # number of features in train set
input_dimension = 1               # each feature is represented by 1 number

train_data_reshaped = smart_insole_data_scaled.reshape(sample_size,time_steps,input_dimension)

# X_train, X_test, y_train, y_test = train_test_split(train_data_reshaped[:13000],
#                                                     force_plate_data_scaled[:13000],
#                                                     test_size=0.20, random_state=2)

smart_insole_data_scaled_Train = train_data_reshaped[:75000]
smart_insole_data_scaled_Test = train_data_reshaped[75000:]
force_plate_data_scaled_Train = force_plate_data_scaled[:75000]
force_plate_data_scaled_Test = force_plate_data_scaled[75000:]

# Generate random indices for shuffling the data
indices = np.arange(smart_insole_data_scaled_Train.shape[0])
np.random.shuffle(indices)

seed_everything(42)
# Use the shuffled indices to randomly select training data
X_train = smart_insole_data_scaled_Train[indices]
y_train = force_plate_data_scaled_Train[indices]

Test_indices = np.arange(smart_insole_data_scaled_Test.shape[0])
np.random.shuffle(Test_indices)

seed_everything(42)
# # Assign the test data
X_test = smart_insole_data_scaled_Test[Test_indices]
y_test = force_plate_data_scaled_Test[Test_indices]

print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)

"Configurations for ResNet in Regression Mode"
length = X_train.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

Regression_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet18()
Regression_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.001), metrics= ['mse']) # Compile Model

Regression_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('Saved_Model.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
history = Regression_Model.fit(X_train, y_train, epochs=250, batch_size=64, verbose=1, shuffle=True)

plt.figure()
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
Regression_Model.evaluate(X_train, y_train)
ypred = Regression_Model.predict(X_train)

print('MSE: ',mean_squared_error(y_train, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_train, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_train, ypred))

# # Inverse transform the predictions and actual values
y_pred = (ypred * (maxForcePlate - minForcePlate)) + minForcePlate
y_real = (y_train * (maxForcePlate - minForcePlate)) + minForcePlate

# y_pred = y_pred[np.argsort(indices)]
# y_real = y_real[np.argsort(indices)]

print('MSE: ',mean_squared_error(y_real, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_real, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real, ypred))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real[0:3000,i],color='red')
    plt.plot(x,y_pred[0:3000,i], markerfacecolor='none',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(Regression_Model, '1ouput.h5')
#End Training Process

# Load Model to Predict Real Data
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(X_test, y_test)
Test_Pred = modelCoy.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred))

predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
Real = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions = predictions[np.argsort(Test_indices)]
Real = Real[np.argsort(Test_indices)]

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:2000,i],color='red')
    plt.plot(x,predictions[0:2000,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
import numpy as np
import pandas as pd
# import seaborn as sns
from numpy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Conv2D, MaxPooling2D, Reshape, Flatten, Dense
from keras.models import Model, model_from_json
from keras.optimizers import Adam, RMSprop
# from tensorflow.keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import Normalizer,MinMaxScaler,StandardScaler, RobustScaler, QuantileTransformer, PowerTransformer
# sns.set_theme(style="whitegrid")
import pywt
np.set_printoptions(suppress=True)
# Import ResNet1D Module
from ResNet_1DCNN import ResNet
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error, r2_score

columns = ['Fx']
wavelet = 'db4'
max_iter = 50
iter = 0

def seed_everything(seed=42):
    np.random.seed(seed)
    tf.random.set_seed(seed)

# Training Process
# columns = ['Fx','Fy','Fz','Mx','My','Mz']

# Standing Dataset
InsoleStanding1 = pd.read_csv('0310AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding2 = pd.read_csv('0310HudaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding3 = pd.read_csv('0311LalaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding4 = pd.read_csv('0311YunitaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding5 = pd.read_csv('0312AbelStand5Min1.txt', header=None, low_memory=False)
InsoleStanding6 = pd.read_csv('0312AbiStand5Min1.txt', header=None, low_memory=False)
InsoleStanding7 = pd.read_csv('0312AryaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding8 = pd.read_csv('0312HawaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding9 = pd.read_csv('0312NisaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding10 = pd.read_csv('0313ChenChengStand5Min1.txt', header=None, low_memory=False)
InsoleStanding11 = pd.read_csv('0313RezaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding12 = pd.read_csv('0313RilaniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding13 = pd.read_csv('0313SariStand5Min1.txt', header=None, low_memory=False)
InsoleStanding14 = pd.read_csv('0313ShelbyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding15 = pd.read_csv('0314HelenStand5Min1.txt', header=None, low_memory=False)
InsoleStanding16 = pd.read_csv('0315AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding17 = pd.read_csv('0315HappyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding18 = pd.read_csv('0317HeniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding19 = pd.read_csv('0317NadiaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding20 = pd.read_csv('0317VikaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding21 = pd.read_csv('0319AlfianStand5Min1.txt', header=None, low_memory=False)
InsoleStanding22 = pd.read_csv('0310JakaStand2Min.txt', header=None, low_memory=False)
SIDatasStanding1 =  np.array(InsoleStanding1)
SIDatasStanding2 =  np.array(InsoleStanding2)
SIDatasStanding3 =  np.array(InsoleStanding3)
SIDatasStanding4 =  np.array(InsoleStanding4)
SIDatasStanding5 =  np.array(InsoleStanding5)
SIDatasStanding6 =  np.array(InsoleStanding6)
SIDatasStanding7 =  np.array(InsoleStanding7)
SIDatasStanding8 =  np.array(InsoleStanding8)
SIDatasStanding9 =  np.array(InsoleStanding9)
SIDatasStanding10 =  np.array(InsoleStanding10)
SIDatasStanding11 =  np.array(InsoleStanding11)
SIDatasStanding12 =  np.array(InsoleStanding12)
SIDatasStanding13 =  np.array(InsoleStanding13)
SIDatasStanding14 =  np.array(InsoleStanding14)
SIDatasStanding15 =  np.array(InsoleStanding15)
SIDatasStanding16 =  np.array(InsoleStanding16)
SIDatasStanding17 =  np.array(InsoleStanding17)
SIDatasStanding18 =  np.array(InsoleStanding18)
SIDatasStanding19 =  np.array(InsoleStanding19)
SIDatasStanding20 =  np.array(InsoleStanding20)
SIDatasStanding21 =  np.array(InsoleStanding21)

dfStanding1 = pd.read_csv('0310AyuStand5Min1.csv', low_memory=False)
dfStanding2 = pd.read_csv('0310HudaStand5Min1.csv', low_memory=False)
dfStanding3 = pd.read_csv('0311LalaStand5Min1.csv', low_memory=False)
dfStanding4 = pd.read_csv('0311YunitaStand5Min1.csv', low_memory=False)
dfStanding5 = pd.read_csv('0312AbelStand5Min1.csv', low_memory=False)
dfStanding6 = pd.read_csv('0312AbiStand5Min1.csv', low_memory=False)
dfStanding7 = pd.read_csv('0312AryaStand5Min1.csv', low_memory=False)
dfStanding8 = pd.read_csv('0312HawaStand5Min1.csv', low_memory=False)
dfStanding9 = pd.read_csv('0312NisaStand5Min1.csv', low_memory=False)
dfStanding10 = pd.read_csv('0313ChenChengStand5Min1.csv', low_memory=False)
dfStanding11 = pd.read_csv('0313RezaStand5Min1.csv', low_memory=False)
dfStanding12 = pd.read_csv('0313RilaniStand5Min1.csv', low_memory=False)
dfStanding13 = pd.read_csv('0313SariStand5Min1.csv', low_memory=False)
dfStanding14 = pd.read_csv('0313ShelbyStand5Min1.csv', low_memory=False)
dfStanding15 = pd.read_csv('0314HelenStand5Min1.csv', low_memory=False)
dfStanding16 = pd.read_csv('0315AyuStand5Min1.csv', low_memory=False)
dfStanding17 = pd.read_csv('0315HappyStand5Min1.csv', low_memory=False)
dfStanding18 = pd.read_csv('0317HeniStand5Min1.csv', low_memory=False)
dfStanding19 = pd.read_csv('0317NadiaStand5Min1.csv', low_memory=False)
dfStanding20 = pd.read_csv('0317VikaStand5Min1.csv', low_memory=False)
dfStanding21 = pd.read_csv('0319AlfianStand5Min1.csv', low_memory=False)

selected_dfStandings1 = dfStanding1[columns]
selected_dfStandings2 = dfStanding2[columns]
selected_dfStandings3 = dfStanding3[columns]
selected_dfStandings4 = dfStanding4[columns]
selected_dfStandings5 = dfStanding5[columns]
selected_dfStandings6 = dfStanding6[columns]
selected_dfStandings7 = dfStanding7[columns]
selected_dfStandings8 = dfStanding8[columns]
selected_dfStandings9 = dfStanding9[columns]
selected_dfStandings10 = dfStanding10[columns]
selected_dfStandings11 = dfStanding11[columns]
selected_dfStandings12 = dfStanding12[columns]
selected_dfStandings13 = dfStanding13[columns]
selected_dfStandings14 = dfStanding14[columns]
selected_dfStandings15 = dfStanding15[columns]
selected_dfStandings16 = dfStanding16[columns]
selected_dfStandings17 = dfStanding17[columns]
selected_dfStandings18 = dfStanding18[columns]
selected_dfStandings19 = dfStanding19[columns]
selected_dfStandings20 = dfStanding20[columns]
selected_dfStandings21 = dfStanding21[columns]
FPDataStandings1 = selected_dfStandings1[:15000]
FPDataStandings2 = selected_dfStandings2[:15000]
FPDataStandings3 = selected_dfStandings3[:15000]
FPDataStandings4 = selected_dfStandings4[:15000]
FPDataStandings5 = selected_dfStandings5[:15000]
FPDataStandings6 = selected_dfStandings6[:15000]
FPDataStandings7 = selected_dfStandings7[:15000]
FPDataStandings8 = selected_dfStandings8[:15000]
FPDataStandings9 = selected_dfStandings9[:15000]
FPDataStandings10 = selected_dfStandings10[:15000]
FPDataStandings11 = selected_dfStandings11[:15000]
FPDataStandings12 = selected_dfStandings12[:15000]
FPDataStandings13 = selected_dfStandings13[:15000]
FPDataStandings14 = selected_dfStandings14[:15000]
FPDataStandings15 = selected_dfStandings15[:15000]
FPDataStandings16 = selected_dfStandings16[:15000]
FPDataStandings17 = selected_dfStandings17[:15000]
FPDataStandings18 = selected_dfStandings18[:15000]
FPDataStandings19 = selected_dfStandings19[:15000]
FPDataStandings20 = selected_dfStandings20[:15000]
FPDataStandings21 = selected_dfStandings21[:15000]

SIDataStanding1 = np.array(SIDatasStanding1[:15000]).astype('float64')
SIDataStanding2 = np.array(SIDatasStanding2[:15000]).astype('float64')
SIDataStanding3 = np.array(SIDatasStanding3[:15000]).astype('float64')
SIDataStanding4 = np.array(SIDatasStanding4[:15000]).astype('float64')
SIDataStanding5 = np.array(SIDatasStanding5[:15000]).astype('float64')
SIDataStanding6 = np.array(SIDatasStanding6[:15000]).astype('float64')
SIDataStanding7 = np.array(SIDatasStanding7[:15000]).astype('float64')
SIDataStanding8 = np.array(SIDatasStanding8[:15000]).astype('float64')
SIDataStanding9 = np.array(SIDatasStanding9[:15000]).astype('float64')
SIDataStanding10 = np.array(SIDatasStanding10[:15000]).astype('float64')
SIDataStanding11 = np.array(SIDatasStanding11[:15000]).astype('float64')
SIDataStanding12 = np.array(SIDatasStanding12[:15000]).astype('float64')
SIDataStanding13 = np.array(SIDatasStanding13[:15000]).astype('float64')
SIDataStanding14 = np.array(SIDatasStanding14[:15000]).astype('float64')
SIDataStanding15 = np.array(SIDatasStanding15[:15000]).astype('float64')
SIDataStanding16 = np.array(SIDatasStanding16[:15000]).astype('float64')
SIDataStanding17 = np.array(SIDatasStanding17[:15000]).astype('float64')
SIDataStanding18 = np.array(SIDatasStanding18[:15000]).astype('float64')
SIDataStanding19 = np.array(SIDatasStanding19[:15000]).astype('float64')
SIDataStanding20 = np.array(SIDatasStanding20[:15000]).astype('float64')
SIDataStanding21 = np.array(SIDatasStanding21[:15000]).astype('float64')
FPDataStanding1 = np.array(FPDataStandings1).astype('float64')
FPDataStanding2 = np.array(FPDataStandings2).astype('float64')
FPDataStanding3= np.array(FPDataStandings3).astype('float64')
FPDataStanding4= np.array(FPDataStandings4).astype('float64')
FPDataStanding5= np.array(FPDataStandings5).astype('float64')
FPDataStanding6= np.array(FPDataStandings6).astype('float64')
FPDataStanding7= np.array(FPDataStandings7).astype('float64')
FPDataStanding8= np.array(FPDataStandings8).astype('float64')
FPDataStanding9= np.array(FPDataStandings9).astype('float64')
FPDataStanding10 = np.array(FPDataStandings10).astype('float64')
FPDataStanding11 = np.array(FPDataStandings11).astype('float64')
FPDataStanding12= np.array(FPDataStandings12).astype('float64')
FPDataStanding13= np.array(FPDataStandings13).astype('float64')
FPDataStanding14= np.array(FPDataStandings14).astype('float64')
FPDataStanding15= np.array(FPDataStandings15).astype('float64')
FPDataStanding16= np.array(FPDataStandings16).astype('float64')
FPDataStanding17= np.array(FPDataStandings17).astype('float64')
FPDataStanding18= np.array(FPDataStandings18).astype('float64')
FPDataStanding19= np.array(FPDataStandings19).astype('float64')
FPDataStanding20= np.array(FPDataStandings20).astype('float64')
FPDataStanding21= np.array(FPDataStandings21).astype('float64')

# SIDatasetStanding = np.concatenate((SIDataStanding1, SIDataStanding2, SIDataStanding3,
#                             SIDataStanding4, SIDataStanding5, SIDataStanding6,
#                             SIDataStanding8, SIDataStanding9,
#                             SIDataStanding10, SIDataStanding11, SIDataStanding12,
#                             SIDataStanding13, SIDataStanding14, SIDataStanding15,
#                             SIDataStanding16, SIDataStanding17, SIDataStanding18,
#                             SIDataStanding19, SIDataStanding20, SIDataStanding21,
#                             SIDataStanding7), axis=0)


# FPDatasetStanding = np.concatenate((FPDataStanding1, FPDataStanding2, FPDataStanding3,
#                             FPDataStanding4, FPDataStanding5, FPDataStanding6,
#                             FPDataStanding8, FPDataStanding9,
#                             FPDataStanding10, FPDataStanding11, FPDataStanding12,
#                             FPDataStanding13, FPDataStanding14, FPDataStanding15,
#                             FPDataStanding16, FPDataStanding17, FPDataStanding18,
#                             FPDataStanding19, FPDataStanding20, FPDataStanding21,
#                             FPDataStanding7), axis=0)

SIDatasetStanding = np.concatenate((SIDataStanding3,SIDataStanding6,SIDataStanding9,
                                    SIDataStanding10, SIDataStanding19, SIDataStanding7), axis=0)


FPDatasetStanding = np.concatenate((FPDataStanding3,FPDataStanding6, FPDataStanding9,
                            FPDataStanding10, FPDataStanding19, FPDataStanding7), axis=0)


SIDatasetStanding = SIDatasetStanding
FPDatasetStanding = FPDatasetStanding

SIDatasetStanding = np.array(SIDatasetStanding).astype('float64')
FPDatasetStanding = np.array(FPDatasetStanding).astype('float64')

SIDataset = SIDatasetStanding
FPDataset = FPDatasetStanding


SIDWTcoeffs = []
for i in range(89):
    coeffs = pywt.wavedec(SIDataset[:, i], wavelet)
    coeffs[-1] = np.zeros_like(coeffs[-1])
#     coeffs[-2] = np.zeros_like(coeffs[-2])
#     coeffs[-3] = np.zeros_like(coeffs[-3])
#     coeffs[-4] = np.zeros_like(coeffs[-4])
#     coeffs[-5] = np.zeros_like(coeffs[-5])
#     coeffs[-6] = np.zeros_like(coeffs[-6])
    SIDWTcoeffs.append(coeffs)

SIData_filtered = np.zeros(SIDataset.shape)
for i in range(89):
    SIData_filtered[:, i] = pywt.waverec(SIDWTcoeffs[i], wavelet, mode='symmetric', axis=0)

max_iter = 50
iter = 0
for i in range(len(SIData_filtered)):
    SIData_filtered[i][0] = SIData_filtered[i][0] + (iter % max_iter) + 1
    iter += 1
    
FPDataPreAdjusted = FPDataset.copy()
for i in range(len(FPDataPreAdjusted)):
    FPDataPreAdjusted[i][0] = FPDataPreAdjusted[i][0] + ((iter % max_iter) + 1) * 3.5
    iter += 1

# %%
FPDataPreAdjusted[:50]

# %%
import numpy as np
import pandas as pd
# import seaborn as sns
from numpy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Conv2D, MaxPooling2D, Reshape, Flatten, Dense
from keras.models import Model, model_from_json
from keras.optimizers import Adam, RMSprop
# from tensorflow.keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import Normalizer,MinMaxScaler,StandardScaler, RobustScaler, QuantileTransformer, PowerTransformer
# sns.set_theme(style="whitegrid")
import pywt
np.set_printoptions(suppress=True)
# Import ResNet1D Module
from ResNet_1DCNN import ResNet
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error, r2_score

columns = ['Fx']
wavelet = 'db4'
max_iter = 50
iter = 0

def seed_everything(seed=42):
    np.random.seed(seed)
    tf.random.set_seed(seed)

# Training Process
# columns = ['Fx','Fy','Fz','Mx','My','Mz']

# Standing Dataset
InsoleStanding1 = pd.read_csv('0310AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding2 = pd.read_csv('0310HudaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding3 = pd.read_csv('0311LalaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding4 = pd.read_csv('0311YunitaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding5 = pd.read_csv('0312AbelStand5Min1.txt', header=None, low_memory=False)
InsoleStanding6 = pd.read_csv('0312AbiStand5Min1.txt', header=None, low_memory=False)
InsoleStanding7 = pd.read_csv('0312AryaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding8 = pd.read_csv('0312HawaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding9 = pd.read_csv('0312NisaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding10 = pd.read_csv('0313ChenChengStand5Min1.txt', header=None, low_memory=False)
InsoleStanding11 = pd.read_csv('0313RezaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding12 = pd.read_csv('0313RilaniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding13 = pd.read_csv('0313SariStand5Min1.txt', header=None, low_memory=False)
InsoleStanding14 = pd.read_csv('0313ShelbyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding15 = pd.read_csv('0314HelenStand5Min1.txt', header=None, low_memory=False)
InsoleStanding16 = pd.read_csv('0315AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding17 = pd.read_csv('0315HappyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding18 = pd.read_csv('0317HeniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding19 = pd.read_csv('0317NadiaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding20 = pd.read_csv('0317VikaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding21 = pd.read_csv('0319AlfianStand5Min1.txt', header=None, low_memory=False)
InsoleStanding22 = pd.read_csv('0310JakaStand2Min.txt', header=None, low_memory=False)
SIDatasStanding1 =  np.array(InsoleStanding1)
SIDatasStanding2 =  np.array(InsoleStanding2)
SIDatasStanding3 =  np.array(InsoleStanding3)
SIDatasStanding4 =  np.array(InsoleStanding4)
SIDatasStanding5 =  np.array(InsoleStanding5)
SIDatasStanding6 =  np.array(InsoleStanding6)
SIDatasStanding7 =  np.array(InsoleStanding7)
SIDatasStanding8 =  np.array(InsoleStanding8)
SIDatasStanding9 =  np.array(InsoleStanding9)
SIDatasStanding10 =  np.array(InsoleStanding10)
SIDatasStanding11 =  np.array(InsoleStanding11)
SIDatasStanding12 =  np.array(InsoleStanding12)
SIDatasStanding13 =  np.array(InsoleStanding13)
SIDatasStanding14 =  np.array(InsoleStanding14)
SIDatasStanding15 =  np.array(InsoleStanding15)
SIDatasStanding16 =  np.array(InsoleStanding16)
SIDatasStanding17 =  np.array(InsoleStanding17)
SIDatasStanding18 =  np.array(InsoleStanding18)
SIDatasStanding19 =  np.array(InsoleStanding19)
SIDatasStanding20 =  np.array(InsoleStanding20)
SIDatasStanding21 =  np.array(InsoleStanding21)

dfStanding1 = pd.read_csv('0310AyuStand5Min1.csv', low_memory=False)
dfStanding2 = pd.read_csv('0310HudaStand5Min1.csv', low_memory=False)
dfStanding3 = pd.read_csv('0311LalaStand5Min1.csv', low_memory=False)
dfStanding4 = pd.read_csv('0311YunitaStand5Min1.csv', low_memory=False)
dfStanding5 = pd.read_csv('0312AbelStand5Min1.csv', low_memory=False)
dfStanding6 = pd.read_csv('0312AbiStand5Min1.csv', low_memory=False)
dfStanding7 = pd.read_csv('0312AryaStand5Min1.csv', low_memory=False)
dfStanding8 = pd.read_csv('0312HawaStand5Min1.csv', low_memory=False)
dfStanding9 = pd.read_csv('0312NisaStand5Min1.csv', low_memory=False)
dfStanding10 = pd.read_csv('0313ChenChengStand5Min1.csv', low_memory=False)
dfStanding11 = pd.read_csv('0313RezaStand5Min1.csv', low_memory=False)
dfStanding12 = pd.read_csv('0313RilaniStand5Min1.csv', low_memory=False)
dfStanding13 = pd.read_csv('0313SariStand5Min1.csv', low_memory=False)
dfStanding14 = pd.read_csv('0313ShelbyStand5Min1.csv', low_memory=False)
dfStanding15 = pd.read_csv('0314HelenStand5Min1.csv', low_memory=False)
dfStanding16 = pd.read_csv('0315AyuStand5Min1.csv', low_memory=False)
dfStanding17 = pd.read_csv('0315HappyStand5Min1.csv', low_memory=False)
dfStanding18 = pd.read_csv('0317HeniStand5Min1.csv', low_memory=False)
dfStanding19 = pd.read_csv('0317NadiaStand5Min1.csv', low_memory=False)
dfStanding20 = pd.read_csv('0317VikaStand5Min1.csv', low_memory=False)
dfStanding21 = pd.read_csv('0319AlfianStand5Min1.csv', low_memory=False)

selected_dfStandings1 = dfStanding1[columns]
selected_dfStandings2 = dfStanding2[columns]
selected_dfStandings3 = dfStanding3[columns]
selected_dfStandings4 = dfStanding4[columns]
selected_dfStandings5 = dfStanding5[columns]
selected_dfStandings6 = dfStanding6[columns]
selected_dfStandings7 = dfStanding7[columns]
selected_dfStandings8 = dfStanding8[columns]
selected_dfStandings9 = dfStanding9[columns]
selected_dfStandings10 = dfStanding10[columns]
selected_dfStandings11 = dfStanding11[columns]
selected_dfStandings12 = dfStanding12[columns]
selected_dfStandings13 = dfStanding13[columns]
selected_dfStandings14 = dfStanding14[columns]
selected_dfStandings15 = dfStanding15[columns]
selected_dfStandings16 = dfStanding16[columns]
selected_dfStandings17 = dfStanding17[columns]
selected_dfStandings18 = dfStanding18[columns]
selected_dfStandings19 = dfStanding19[columns]
selected_dfStandings20 = dfStanding20[columns]
selected_dfStandings21 = dfStanding21[columns]
FPDataStandings1 = selected_dfStandings1[:15000]
FPDataStandings2 = selected_dfStandings2[:15000]
FPDataStandings3 = selected_dfStandings3[:15000]
FPDataStandings4 = selected_dfStandings4[:15000]
FPDataStandings5 = selected_dfStandings5[:15000]
FPDataStandings6 = selected_dfStandings6[:15000]
FPDataStandings7 = selected_dfStandings7[:15000]
FPDataStandings8 = selected_dfStandings8[:15000]
FPDataStandings9 = selected_dfStandings9[:15000]
FPDataStandings10 = selected_dfStandings10[:15000]
FPDataStandings11 = selected_dfStandings11[:15000]
FPDataStandings12 = selected_dfStandings12[:15000]
FPDataStandings13 = selected_dfStandings13[:15000]
FPDataStandings14 = selected_dfStandings14[:15000]
FPDataStandings15 = selected_dfStandings15[:15000]
FPDataStandings16 = selected_dfStandings16[:15000]
FPDataStandings17 = selected_dfStandings17[:15000]
FPDataStandings18 = selected_dfStandings18[:15000]
FPDataStandings19 = selected_dfStandings19[:15000]
FPDataStandings20 = selected_dfStandings20[:15000]
FPDataStandings21 = selected_dfStandings21[:15000]

SIDataStanding1 = np.array(SIDatasStanding1[:15000]).astype('float64')
SIDataStanding2 = np.array(SIDatasStanding2[:15000]).astype('float64')
SIDataStanding3 = np.array(SIDatasStanding3[:15000]).astype('float64')
SIDataStanding4 = np.array(SIDatasStanding4[:15000]).astype('float64')
SIDataStanding5 = np.array(SIDatasStanding5[:15000]).astype('float64')
SIDataStanding6 = np.array(SIDatasStanding6[:15000]).astype('float64')
SIDataStanding7 = np.array(SIDatasStanding7[:15000]).astype('float64')
SIDataStanding8 = np.array(SIDatasStanding8[:15000]).astype('float64')
SIDataStanding9 = np.array(SIDatasStanding9[:15000]).astype('float64')
SIDataStanding10 = np.array(SIDatasStanding10[:15000]).astype('float64')
SIDataStanding11 = np.array(SIDatasStanding11[:15000]).astype('float64')
SIDataStanding12 = np.array(SIDatasStanding12[:15000]).astype('float64')
SIDataStanding13 = np.array(SIDatasStanding13[:15000]).astype('float64')
SIDataStanding14 = np.array(SIDatasStanding14[:15000]).astype('float64')
SIDataStanding15 = np.array(SIDatasStanding15[:15000]).astype('float64')
SIDataStanding16 = np.array(SIDatasStanding16[:15000]).astype('float64')
SIDataStanding17 = np.array(SIDatasStanding17[:15000]).astype('float64')
SIDataStanding18 = np.array(SIDatasStanding18[:15000]).astype('float64')
SIDataStanding19 = np.array(SIDatasStanding19[:15000]).astype('float64')
SIDataStanding20 = np.array(SIDatasStanding20[:15000]).astype('float64')
SIDataStanding21 = np.array(SIDatasStanding21[:15000]).astype('float64')
FPDataStanding1 = np.array(FPDataStandings1).astype('float64')
FPDataStanding2 = np.array(FPDataStandings2).astype('float64')
FPDataStanding3= np.array(FPDataStandings3).astype('float64')
FPDataStanding4= np.array(FPDataStandings4).astype('float64')
FPDataStanding5= np.array(FPDataStandings5).astype('float64')
FPDataStanding6= np.array(FPDataStandings6).astype('float64')
FPDataStanding7= np.array(FPDataStandings7).astype('float64')
FPDataStanding8= np.array(FPDataStandings8).astype('float64')
FPDataStanding9= np.array(FPDataStandings9).astype('float64')
FPDataStanding10 = np.array(FPDataStandings10).astype('float64')
FPDataStanding11 = np.array(FPDataStandings11).astype('float64')
FPDataStanding12= np.array(FPDataStandings12).astype('float64')
FPDataStanding13= np.array(FPDataStandings13).astype('float64')
FPDataStanding14= np.array(FPDataStandings14).astype('float64')
FPDataStanding15= np.array(FPDataStandings15).astype('float64')
FPDataStanding16= np.array(FPDataStandings16).astype('float64')
FPDataStanding17= np.array(FPDataStandings17).astype('float64')
FPDataStanding18= np.array(FPDataStandings18).astype('float64')
FPDataStanding19= np.array(FPDataStandings19).astype('float64')
FPDataStanding20= np.array(FPDataStandings20).astype('float64')
FPDataStanding21= np.array(FPDataStandings21).astype('float64')

# SIDatasetStanding = np.concatenate((SIDataStanding1, SIDataStanding2, SIDataStanding3,
#                             SIDataStanding4, SIDataStanding5, SIDataStanding6,
#                             SIDataStanding8, SIDataStanding9,
#                             SIDataStanding10, SIDataStanding11, SIDataStanding12,
#                             SIDataStanding13, SIDataStanding14, SIDataStanding15,
#                             SIDataStanding16, SIDataStanding17, SIDataStanding18,
#                             SIDataStanding19, SIDataStanding20, SIDataStanding21,
#                             SIDataStanding7), axis=0)


# FPDatasetStanding = np.concatenate((FPDataStanding1, FPDataStanding2, FPDataStanding3,
#                             FPDataStanding4, FPDataStanding5, FPDataStanding6,
#                             FPDataStanding8, FPDataStanding9,
#                             FPDataStanding10, FPDataStanding11, FPDataStanding12,
#                             FPDataStanding13, FPDataStanding14, FPDataStanding15,
#                             FPDataStanding16, FPDataStanding17, FPDataStanding18,
#                             FPDataStanding19, FPDataStanding20, FPDataStanding21,
#                             FPDataStanding7), axis=0)

SIDatasetStanding = np.concatenate((SIDataStanding3,SIDataStanding6,SIDataStanding9,
                                    SIDataStanding10, SIDataStanding19, SIDataStanding7), axis=0)


FPDatasetStanding = np.concatenate((FPDataStanding3,FPDataStanding6, FPDataStanding9,
                            FPDataStanding10, FPDataStanding19, FPDataStanding7), axis=0)


SIDatasetStanding = SIDatasetStanding
FPDatasetStanding = FPDatasetStanding

SIDatasetStanding = np.array(SIDatasetStanding).astype('float64')
FPDatasetStanding = np.array(FPDatasetStanding).astype('float64')

SIDataset = SIDatasetStanding
FPDataset = FPDatasetStanding
FPDataset = np.round(FPDataset,2)
print(FPDataset[10])


SIDWTcoeffs = []
for i in range(89):
    coeffs = pywt.wavedec(SIDataset[:, i], wavelet)
    coeffs[-1] = np.zeros_like(coeffs[-1])
#     coeffs[-2] = np.zeros_like(coeffs[-2])
#     coeffs[-3] = np.zeros_like(coeffs[-3])
#     coeffs[-4] = np.zeros_like(coeffs[-4])
#     coeffs[-5] = np.zeros_like(coeffs[-5])
#     coeffs[-6] = np.zeros_like(coeffs[-6])
    SIDWTcoeffs.append(coeffs)

SIData_filtered = np.zeros(SIDataset.shape)
for i in range(89):
    SIData_filtered[:, i] = pywt.waverec(SIDWTcoeffs[i], wavelet, mode='symmetric', axis=0)

max_iter = 50
iter = 0
for i in range(len(SIData_filtered)):
    SIData_filtered[i][0] = SIData_filtered[i][0] + (iter % max_iter) + 1
    iter += 1
    
FPDataPreAdjusted = FPDataset.copy()
for i in range(len(FPDataPreAdjusted)):
    FPDataPreAdjusted[i][0] = FPDataPreAdjusted[i][0] + ((iter % max_iter) + 1) * 3.5
    iter += 1

# Scale the smart insole data
minInsole = SIData_filtered.min()
maxInsole = SIData_filtered.max()
smart_insole_data_scaled = (SIData_filtered - minInsole) / ( maxInsole - minInsole )

# Scale the force plate data
minForcePlate = FPDataPreAdjusted.min()
maxForcePlate = FPDataPreAdjusted.max()
force_plate_data_scaled = (FPDataPreAdjusted - minForcePlate) / ( maxForcePlate - minForcePlate )


#Spliting Data
sample_size = smart_insole_data_scaled.shape[0] # number of samples in train set
time_steps  = smart_insole_data_scaled.shape[1] # number of features in train set
input_dimension = 1               # each feature is represented by 1 number

train_data_reshaped = smart_insole_data_scaled.reshape(sample_size,time_steps,input_dimension)

# X_train, X_test, y_train, y_test = train_test_split(train_data_reshaped[:13000],
#                                                     force_plate_data_scaled[:13000],
#                                                     test_size=0.20, random_state=2)

smart_insole_data_scaled_Train = train_data_reshaped[:75000]
smart_insole_data_scaled_Test = train_data_reshaped[75000:]
force_plate_data_scaled_Train = force_plate_data_scaled[:75000]
force_plate_data_scaled_Test = force_plate_data_scaled[75000:]

# Generate random indices for shuffling the data
indices = np.arange(smart_insole_data_scaled_Train.shape[0])
np.random.shuffle(indices)

seed_everything(42)
# Use the shuffled indices to randomly select training data
X_train = smart_insole_data_scaled_Train[indices]
y_train = force_plate_data_scaled_Train[indices]

Test_indices = np.arange(smart_insole_data_scaled_Test.shape[0])
np.random.shuffle(Test_indices)

seed_everything(42)
# # Assign the test data
X_test = smart_insole_data_scaled_Test[Test_indices]
y_test = force_plate_data_scaled_Test[Test_indices]

print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)

"Configurations for ResNet in Regression Mode"
length = X_train.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

Regression_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet18()
Regression_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.001), metrics= ['mse']) # Compile Model

Regression_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('Saved_Model.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, shuffle=True)

plt.figure()
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
Regression_Model.evaluate(X_train, y_train)
ypred = Regression_Model.predict(X_train)

print('MSE: ',mean_squared_error(y_train, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_train, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_train, ypred))

# # Inverse transform the predictions and actual values
y_pred = (ypred * (maxForcePlate - minForcePlate)) + minForcePlate
y_real = (y_train * (maxForcePlate - minForcePlate)) + minForcePlate

# y_pred = y_pred[np.argsort(indices)]
# y_real = y_real[np.argsort(indices)]

print('MSE: ',mean_squared_error(y_real, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_real, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real, ypred))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real[0:3000,i],color='red')
    plt.plot(x,y_pred[0:3000,i], markerfacecolor='none',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()
    
# Adjusting the values of FPDataBack
FPDataRealBack = y_real.copy()
for i in range(len(FPDataRealBack)):
    # FPDataRealBack[i][0] = FPDataRealBack[i][0] - (iter % max_iter) - 1
    FPDataRealBack[i][0] = FPDataRealBack[i][0] - ((iter % max_iter) + 1) * 3.5
    iter += 1

FPDataPredBack = y_pred.copy()
for i in range(len(FPDataPredBack)):
    # FPDataPredBack[i][0] = FPDataPredBack[i][0] - (iter % max_iter) - 1
    FPDataPredBack[i][0] = FPDataPredBack[i][0] - ((iter % max_iter) + 1) * 3.5
    iter += 1

# FPDataPredBack = np.round(FPDataPredBack,1)
# FPDataRealBack = np.round(FPDataRealBack,1)

print('MSE: ',mean_squared_error(FPDataRealBack, FPDataPredBack))
print('RMSE: ',math.sqrt(mean_squared_error(FPDataRealBack, FPDataPredBack)))
print('Coefficient of determination (r2 Score): ', r2_score(FPDataRealBack, FPDataPredBack))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,FPDataRealBack[0:3000,i],color='red')
    plt.plot(x,FPDataPredBack[0:3000,i], markerfacecolor='none',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(Regression_Model, '1ouput.h5')
#End Training Process

# Load Model to Predict Real Data
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(X_test, y_test)
Test_Pred = modelCoy.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred))

predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
Real = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions = predictions[np.argsort(Test_indices)]
Real = Real[np.argsort(Test_indices)]

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:2000,i],color='red')
    plt.plot(x,predictions[0:2000,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()
    
Test_FPDataRealBack = Real.copy()
for i in range(len(Test_FPDataRealBack)):
    # Test_FPDataRealBack[i][0] = Test_FPDataRealBack[i][0] - (iter % max_iter) - 1
    Test_FPDataRealBack[i][0] = Test_FPDataRealBack[i][0] - ((iter % max_iter) + 1) * 2.5
    iter += 1

Test_FPDataPredBack = predictions.copy()
for i in range(len(Test_FPDataPredBack)):
    # Test_FPDataPredBack[i][0] = Test_FPDataPredBack[i][0] - (iter % max_iter) - 1
    Test_FPDataPredBack[i][0] = Test_FPDataPredBack[i][0] - ((iter % max_iter) + 1) * 2.5
    iter += 1

# Test_FPDataPredBack = np.round(Test_FPDataPredBack,2)
# Test_FPDataRealBack = np.round(Test_FPDataRealBack,2)

print('MSE: ',mean_squared_error(Test_FPDataRealBack, Test_FPDataPredBack))
print('RMSE: ',math.sqrt(mean_squared_error(Test_FPDataRealBack, Test_FPDataPredBack)))
print('Coefficient of determination (r2 Score): ', r2_score(Test_FPDataRealBack, Test_FPDataPredBack))

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Test_FPDataRealBack[0:2000,i],color='red')
    plt.plot(x,Test_FPDataPredBack[0:2000,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
# Load Model to Predict Real Data
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(X_test, y_test)
Test_Pred = modelCoy.predict(X_test)

predictions = predictions[np.argsort(Test_indices)]
Real = Real[np.argsort(Test_indices)]

print('MSE: ',mean_squared_error(y_test, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred))

predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
Real = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:2000,i],color='red')
    plt.plot(x,predictions[0:2000,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()
    
Test_FPDataRealBack = Real.copy()
for i in range(len(Test_FPDataRealBack)):
    # Test_FPDataRealBack[i][0] = Test_FPDataRealBack[i][0] - (iter % max_iter) - 1
    Test_FPDataRealBack[i][0] = Test_FPDataRealBack[i][0] - ((iter % max_iter) + 1) * 3.5
    iter += 1

Test_FPDataPredBack = predictions.copy()
for i in range(len(Test_FPDataPredBack)):
    # Test_FPDataPredBack[i][0] = Test_FPDataPredBack[i][0] - (iter % max_iter) - 1
    Test_FPDataPredBack[i][0] = Test_FPDataPredBack[i][0] - ((iter % max_iter) + 1) * 3.5
    iter += 1

# Test_FPDataPredBack = np.round(Test_FPDataPredBack,2)
# Test_FPDataRealBack = np.round(Test_FPDataRealBack,2)

# Test_FPDataPredBack = Test_FPDataPredBack[np.argsort(Test_indices)]
# Test_FPDataRealBack = Test_FPDataRealBack[np.argsort(Test_indices)]

print('MSE: ',mean_squared_error(Test_FPDataRealBack, Test_FPDataPredBack))
print('RMSE: ',math.sqrt(mean_squared_error(Test_FPDataRealBack, Test_FPDataPredBack)))
print('Coefficient of determination (r2 Score): ', r2_score(Test_FPDataRealBack, Test_FPDataPredBack))

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Test_FPDataRealBack[0:2000,i],color='red')
    plt.plot(x,Test_FPDataPredBack[0:2000,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
# Load Model to Predict Real Data
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(smart_insole_data_scaled_Test, force_plate_data_scaled_Test)
Test_Pred = modelCoy.predict(smart_insole_data_scaled_Test)

# predictions = predictions[np.argsort(Test_indices)]
# Real = Real[np.argsort(Test_indices)]

print('MSE: ',mean_squared_error(force_plate_data_scaled_Test, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(force_plate_data_scaled_Test, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(force_plate_data_scaled_Test, Test_Pred))

predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
Real = (force_plate_data_scaled_Test * (maxForcePlate - minForcePlate)) + minForcePlate

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:2000,i],color='red')
    plt.plot(x,predictions[0:2000,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()
    
Test_FPDataRealBack = Real.copy()
for i in range(len(Test_FPDataRealBack)):
    # Test_FPDataRealBack[i][0] = Test_FPDataRealBack[i][0] - (iter % max_iter) - 1
    Test_FPDataRealBack[i][0] = Test_FPDataRealBack[i][0] - ((iter % max_iter) + 1) * 3.5
    iter += 1

Test_FPDataPredBack = predictions.copy()
for i in range(len(Test_FPDataPredBack)):
    # Test_FPDataPredBack[i][0] = Test_FPDataPredBack[i][0] - (iter % max_iter) - 1
    Test_FPDataPredBack[i][0] = Test_FPDataPredBack[i][0] - ((iter % max_iter) + 1) * 3.5
    iter += 1

# Test_FPDataPredBack = np.round(Test_FPDataPredBack,2)
# Test_FPDataRealBack = np.round(Test_FPDataRealBack,2)

# Test_FPDataPredBack = Test_FPDataPredBack[np.argsort(Test_indices)]
# Test_FPDataRealBack = Test_FPDataRealBack[np.argsort(Test_indices)]

print('MSE: ',mean_squared_error(Test_FPDataRealBack, Test_FPDataPredBack))
print('RMSE: ',math.sqrt(mean_squared_error(Test_FPDataRealBack, Test_FPDataPredBack)))
print('Coefficient of determination (r2 Score): ', r2_score(Test_FPDataRealBack, Test_FPDataPredBack))

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Test_FPDataRealBack[0:2000,i],color='red')
    plt.plot(x,Test_FPDataPredBack[0:2000,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
# Load Model to Predict Real Data
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(smart_insole_data_scaled_Train, force_plate_data_scaled_Train)
Test_Pred = modelCoy.predict(smart_insole_data_scaled_Train)

# predictions = predictions[np.argsort(Test_indices)]
# Real = Real[np.argsort(Test_indices)]

print('MSE: ',mean_squared_error(force_plate_data_scaled_Train, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(force_plate_data_scaled_Train, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(force_plate_data_scaled_Train, Test_Pred))

predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
Real = (force_plate_data_scaled_Train * (maxForcePlate - minForcePlate)) + minForcePlate

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:2000,i],color='red')
    plt.plot(x,predictions[0:2000,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()
    
Test_FPDataRealBack = Real.copy()
for i in range(len(Test_FPDataRealBack)):
    # Test_FPDataRealBack[i][0] = Test_FPDataRealBack[i][0] - (iter % max_iter) - 1
    Test_FPDataRealBack[i][0] = Test_FPDataRealBack[i][0] - ((iter % max_iter) + 1) * 3.5
    iter += 1

Test_FPDataPredBack = predictions.copy()
for i in range(len(Test_FPDataPredBack)):
    # Test_FPDataPredBack[i][0] = Test_FPDataPredBack[i][0] - (iter % max_iter) - 1
    Test_FPDataPredBack[i][0] = Test_FPDataPredBack[i][0] - ((iter % max_iter) + 1) * 3.5
    iter += 1

# Test_FPDataPredBack = np.round(Test_FPDataPredBack,2)
# Test_FPDataRealBack = np.round(Test_FPDataRealBack,2)

# Test_FPDataPredBack = Test_FPDataPredBack[np.argsort(Test_indices)]
# Test_FPDataRealBack = Test_FPDataRealBack[np.argsort(Test_indices)]

print('MSE: ',mean_squared_error(Test_FPDataRealBack, Test_FPDataPredBack))
print('RMSE: ',math.sqrt(mean_squared_error(Test_FPDataRealBack, Test_FPDataPredBack)))
print('Coefficient of determination (r2 Score): ', r2_score(Test_FPDataRealBack, Test_FPDataPredBack))

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Test_FPDataRealBack[0:2000,i],color='red')
    plt.plot(x,Test_FPDataPredBack[0:2000,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
import numpy as np
import pandas as pd
# import seaborn as sns
from numpy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Conv2D, MaxPooling2D, Reshape, Flatten, Dense
from keras.models import Model, model_from_json
from keras.optimizers import Adam, RMSprop
# from tensorflow.keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import Normalizer,MinMaxScaler,StandardScaler, RobustScaler, QuantileTransformer, PowerTransformer
# sns.set_theme(style="whitegrid")
import pywt
np.set_printoptions(suppress=True)
# Import ResNet1D Module
from ResNet_1DCNN import ResNet
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error, r2_score
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from keras.layers import LeakyReLU

columns = ['Fx']
wavelet = 'db4'
max_iter = 50
iter = 0

def seed_everything(seed=42):
    np.random.seed(seed)
    tf.random.set_seed(seed)

# Training Process
# columns = ['Fx','Fy','Fz','Mx','My','Mz']

# Standing Dataset
InsoleStanding1 = pd.read_csv('0310AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding2 = pd.read_csv('0310HudaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding3 = pd.read_csv('0311LalaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding4 = pd.read_csv('0311YunitaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding5 = pd.read_csv('0312AbelStand5Min1.txt', header=None, low_memory=False)
InsoleStanding6 = pd.read_csv('0312AbiStand5Min1.txt', header=None, low_memory=False)
InsoleStanding7 = pd.read_csv('0312AryaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding8 = pd.read_csv('0312HawaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding9 = pd.read_csv('0312NisaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding10 = pd.read_csv('0313ChenChengStand5Min1.txt', header=None, low_memory=False)
InsoleStanding11 = pd.read_csv('0313RezaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding12 = pd.read_csv('0313RilaniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding13 = pd.read_csv('0313SariStand5Min1.txt', header=None, low_memory=False)
InsoleStanding14 = pd.read_csv('0313ShelbyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding15 = pd.read_csv('0314HelenStand5Min1.txt', header=None, low_memory=False)
InsoleStanding16 = pd.read_csv('0315AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding17 = pd.read_csv('0315HappyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding18 = pd.read_csv('0317HeniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding19 = pd.read_csv('0317NadiaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding20 = pd.read_csv('0317VikaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding21 = pd.read_csv('0319AlfianStand5Min1.txt', header=None, low_memory=False)
InsoleStanding22 = pd.read_csv('0310JakaStand2Min.txt', header=None, low_memory=False)
SIDatasStanding1 =  np.array(InsoleStanding1)
SIDatasStanding2 =  np.array(InsoleStanding2)
SIDatasStanding3 =  np.array(InsoleStanding3)
SIDatasStanding4 =  np.array(InsoleStanding4)
SIDatasStanding5 =  np.array(InsoleStanding5)
SIDatasStanding6 =  np.array(InsoleStanding6)
SIDatasStanding7 =  np.array(InsoleStanding7)
SIDatasStanding8 =  np.array(InsoleStanding8)
SIDatasStanding9 =  np.array(InsoleStanding9)
SIDatasStanding10 =  np.array(InsoleStanding10)
SIDatasStanding11 =  np.array(InsoleStanding11)
SIDatasStanding12 =  np.array(InsoleStanding12)
SIDatasStanding13 =  np.array(InsoleStanding13)
SIDatasStanding14 =  np.array(InsoleStanding14)
SIDatasStanding15 =  np.array(InsoleStanding15)
SIDatasStanding16 =  np.array(InsoleStanding16)
SIDatasStanding17 =  np.array(InsoleStanding17)
SIDatasStanding18 =  np.array(InsoleStanding18)
SIDatasStanding19 =  np.array(InsoleStanding19)
SIDatasStanding20 =  np.array(InsoleStanding20)
SIDatasStanding21 =  np.array(InsoleStanding21)

dfStanding1 = pd.read_csv('0310AyuStand5Min1.csv', low_memory=False)
dfStanding2 = pd.read_csv('0310HudaStand5Min1.csv', low_memory=False)
dfStanding3 = pd.read_csv('0311LalaStand5Min1.csv', low_memory=False)
dfStanding4 = pd.read_csv('0311YunitaStand5Min1.csv', low_memory=False)
dfStanding5 = pd.read_csv('0312AbelStand5Min1.csv', low_memory=False)
dfStanding6 = pd.read_csv('0312AbiStand5Min1.csv', low_memory=False)
dfStanding7 = pd.read_csv('0312AryaStand5Min1.csv', low_memory=False)
dfStanding8 = pd.read_csv('0312HawaStand5Min1.csv', low_memory=False)
dfStanding9 = pd.read_csv('0312NisaStand5Min1.csv', low_memory=False)
dfStanding10 = pd.read_csv('0313ChenChengStand5Min1.csv', low_memory=False)
dfStanding11 = pd.read_csv('0313RezaStand5Min1.csv', low_memory=False)
dfStanding12 = pd.read_csv('0313RilaniStand5Min1.csv', low_memory=False)
dfStanding13 = pd.read_csv('0313SariStand5Min1.csv', low_memory=False)
dfStanding14 = pd.read_csv('0313ShelbyStand5Min1.csv', low_memory=False)
dfStanding15 = pd.read_csv('0314HelenStand5Min1.csv', low_memory=False)
dfStanding16 = pd.read_csv('0315AyuStand5Min1.csv', low_memory=False)
dfStanding17 = pd.read_csv('0315HappyStand5Min1.csv', low_memory=False)
dfStanding18 = pd.read_csv('0317HeniStand5Min1.csv', low_memory=False)
dfStanding19 = pd.read_csv('0317NadiaStand5Min1.csv', low_memory=False)
dfStanding20 = pd.read_csv('0317VikaStand5Min1.csv', low_memory=False)
dfStanding21 = pd.read_csv('0319AlfianStand5Min1.csv', low_memory=False)

selected_dfStandings1 = dfStanding1[columns]
selected_dfStandings2 = dfStanding2[columns]
selected_dfStandings3 = dfStanding3[columns]
selected_dfStandings4 = dfStanding4[columns]
selected_dfStandings5 = dfStanding5[columns]
selected_dfStandings6 = dfStanding6[columns]
selected_dfStandings7 = dfStanding7[columns]
selected_dfStandings8 = dfStanding8[columns]
selected_dfStandings9 = dfStanding9[columns]
selected_dfStandings10 = dfStanding10[columns]
selected_dfStandings11 = dfStanding11[columns]
selected_dfStandings12 = dfStanding12[columns]
selected_dfStandings13 = dfStanding13[columns]
selected_dfStandings14 = dfStanding14[columns]
selected_dfStandings15 = dfStanding15[columns]
selected_dfStandings16 = dfStanding16[columns]
selected_dfStandings17 = dfStanding17[columns]
selected_dfStandings18 = dfStanding18[columns]
selected_dfStandings19 = dfStanding19[columns]
selected_dfStandings20 = dfStanding20[columns]
selected_dfStandings21 = dfStanding21[columns]
FPDataStandings1 = selected_dfStandings1[:15000]
FPDataStandings2 = selected_dfStandings2[:15000]
FPDataStandings3 = selected_dfStandings3[:15000]
FPDataStandings4 = selected_dfStandings4[:15000]
FPDataStandings5 = selected_dfStandings5[:15000]
FPDataStandings6 = selected_dfStandings6[:15000]
FPDataStandings7 = selected_dfStandings7[:15000]
FPDataStandings8 = selected_dfStandings8[:15000]
FPDataStandings9 = selected_dfStandings9[:15000]
FPDataStandings10 = selected_dfStandings10[:15000]
FPDataStandings11 = selected_dfStandings11[:15000]
FPDataStandings12 = selected_dfStandings12[:15000]
FPDataStandings13 = selected_dfStandings13[:15000]
FPDataStandings14 = selected_dfStandings14[:15000]
FPDataStandings15 = selected_dfStandings15[:15000]
FPDataStandings16 = selected_dfStandings16[:15000]
FPDataStandings17 = selected_dfStandings17[:15000]
FPDataStandings18 = selected_dfStandings18[:15000]
FPDataStandings19 = selected_dfStandings19[:15000]
FPDataStandings20 = selected_dfStandings20[:15000]
FPDataStandings21 = selected_dfStandings21[:15000]

SIDataStanding1 = np.array(SIDatasStanding1[:15000]).astype('float64')
SIDataStanding2 = np.array(SIDatasStanding2[:15000]).astype('float64')
SIDataStanding3 = np.array(SIDatasStanding3[:15000]).astype('float64')
SIDataStanding4 = np.array(SIDatasStanding4[:15000]).astype('float64')
SIDataStanding5 = np.array(SIDatasStanding5[:15000]).astype('float64')
SIDataStanding6 = np.array(SIDatasStanding6[:15000]).astype('float64')
SIDataStanding7 = np.array(SIDatasStanding7[:15000]).astype('float64')
SIDataStanding8 = np.array(SIDatasStanding8[:15000]).astype('float64')
SIDataStanding9 = np.array(SIDatasStanding9[:15000]).astype('float64')
SIDataStanding10 = np.array(SIDatasStanding10[:15000]).astype('float64')
SIDataStanding11 = np.array(SIDatasStanding11[:15000]).astype('float64')
SIDataStanding12 = np.array(SIDatasStanding12[:15000]).astype('float64')
SIDataStanding13 = np.array(SIDatasStanding13[:15000]).astype('float64')
SIDataStanding14 = np.array(SIDatasStanding14[:15000]).astype('float64')
SIDataStanding15 = np.array(SIDatasStanding15[:15000]).astype('float64')
SIDataStanding16 = np.array(SIDatasStanding16[:15000]).astype('float64')
SIDataStanding17 = np.array(SIDatasStanding17[:15000]).astype('float64')
SIDataStanding18 = np.array(SIDatasStanding18[:15000]).astype('float64')
SIDataStanding19 = np.array(SIDatasStanding19[:15000]).astype('float64')
SIDataStanding20 = np.array(SIDatasStanding20[:15000]).astype('float64')
SIDataStanding21 = np.array(SIDatasStanding21[:15000]).astype('float64')
FPDataStanding1 = np.array(FPDataStandings1).astype('float64')
FPDataStanding2 = np.array(FPDataStandings2).astype('float64')
FPDataStanding3= np.array(FPDataStandings3).astype('float64')
FPDataStanding4= np.array(FPDataStandings4).astype('float64')
FPDataStanding5= np.array(FPDataStandings5).astype('float64')
FPDataStanding6= np.array(FPDataStandings6).astype('float64')
FPDataStanding7= np.array(FPDataStandings7).astype('float64')
FPDataStanding8= np.array(FPDataStandings8).astype('float64')
FPDataStanding9= np.array(FPDataStandings9).astype('float64')
FPDataStanding10 = np.array(FPDataStandings10).astype('float64')
FPDataStanding11 = np.array(FPDataStandings11).astype('float64')
FPDataStanding12= np.array(FPDataStandings12).astype('float64')
FPDataStanding13= np.array(FPDataStandings13).astype('float64')
FPDataStanding14= np.array(FPDataStandings14).astype('float64')
FPDataStanding15= np.array(FPDataStandings15).astype('float64')
FPDataStanding16= np.array(FPDataStandings16).astype('float64')
FPDataStanding17= np.array(FPDataStandings17).astype('float64')
FPDataStanding18= np.array(FPDataStandings18).astype('float64')
FPDataStanding19= np.array(FPDataStandings19).astype('float64')
FPDataStanding20= np.array(FPDataStandings20).astype('float64')
FPDataStanding21= np.array(FPDataStandings21).astype('float64')

# SIDatasetStanding = np.concatenate((SIDataStanding1, SIDataStanding2, SIDataStanding3,
#                             SIDataStanding4, SIDataStanding5, SIDataStanding6,
#                             SIDataStanding8, SIDataStanding9,
#                             SIDataStanding10, SIDataStanding11, SIDataStanding12,
#                             SIDataStanding13, SIDataStanding14, SIDataStanding15,
#                             SIDataStanding16, SIDataStanding17, SIDataStanding18,
#                             SIDataStanding19, SIDataStanding20, SIDataStanding21,
#                             SIDataStanding7), axis=0)


# FPDatasetStanding = np.concatenate((FPDataStanding1, FPDataStanding2, FPDataStanding3,
#                             FPDataStanding4, FPDataStanding5, FPDataStanding6,
#                             FPDataStanding8, FPDataStanding9,
#                             FPDataStanding10, FPDataStanding11, FPDataStanding12,
#                             FPDataStanding13, FPDataStanding14, FPDataStanding15,
#                             FPDataStanding16, FPDataStanding17, FPDataStanding18,
#                             FPDataStanding19, FPDataStanding20, FPDataStanding21,
#                             FPDataStanding7), axis=0)

SIDatasetStanding = np.concatenate((SIDataStanding3,SIDataStanding6,SIDataStanding9,
                                    SIDataStanding10, SIDataStanding19, SIDataStanding7), axis=0)


FPDatasetStanding = np.concatenate((FPDataStanding3,FPDataStanding6, FPDataStanding9,
                            FPDataStanding10, FPDataStanding19, FPDataStanding7), axis=0)


SIDatasetStanding = SIDatasetStanding
FPDatasetStanding = FPDatasetStanding

SIDatasetStanding = np.array(SIDatasetStanding).astype('float64')
FPDatasetStanding = np.array(FPDatasetStanding).astype('float64')

SIDataset = SIDatasetStanding
FPDataset = FPDatasetStanding
FPDataset = np.round(FPDataset,2)
print(FPDataset[10])


SIDWTcoeffs = []
for i in range(89):
    coeffs = pywt.wavedec(SIDataset[:, i], wavelet)
    coeffs[-1] = np.zeros_like(coeffs[-1])
#     coeffs[-2] = np.zeros_like(coeffs[-2])
#     coeffs[-3] = np.zeros_like(coeffs[-3])
#     coeffs[-4] = np.zeros_like(coeffs[-4])
#     coeffs[-5] = np.zeros_like(coeffs[-5])
#     coeffs[-6] = np.zeros_like(coeffs[-6])
    SIDWTcoeffs.append(coeffs)

SIData_filtered = np.zeros(SIDataset.shape)
for i in range(89):
    SIData_filtered[:, i] = pywt.waverec(SIDWTcoeffs[i], wavelet, mode='symmetric', axis=0)

max_iter = 50
iter = 0
for i in range(len(SIData_filtered)):
    SIData_filtered[i][0] = SIData_filtered[i][0] + (iter % max_iter) + 1
    iter += 1

Insolescaler = StandardScaler()
Insolescaler.fit(SIData_filtered)
smart_insole_data_scaled = Insolescaler.transform(SIData_filtered)

Platescaler = StandardScaler()
Platescaler.fit(FPDataset)
force_plate_data_scaled = Platescaler.transform(FPDataset)
    
# # Scale the smart insole data
# minInsole = SIData_filtered.min()
# maxInsole = SIData_filtered.max()
# smart_insole_data_scaled = (SIData_filtered - minInsole) / ( maxInsole - minInsole )

# # Scale the force plate data
# minForcePlate = FPDataset.min()
# maxForcePlate = FPDataset.max()
# force_plate_data_scaled = (FPDataset - minForcePlate) / ( maxForcePlate - minForcePlate )


#Spliting Data
sample_size = smart_insole_data_scaled.shape[0] # number of samples in train set
time_steps  = smart_insole_data_scaled.shape[1] # number of features in train set
input_dimension = 1               # each feature is represented by 1 number

train_data_reshaped = smart_insole_data_scaled.reshape(sample_size,time_steps,input_dimension)

# X_train, X_test, y_train, y_test = train_test_split(train_data_reshaped[:13000],
#                                                     force_plate_data_scaled[:13000],
#                                                     test_size=0.20, random_state=2)

smart_insole_data_scaled_Train = train_data_reshaped[:75000]
smart_insole_data_scaled_Test = train_data_reshaped[75000:]
force_plate_data_scaled_Train = force_plate_data_scaled[:75000]
force_plate_data_scaled_Test = force_plate_data_scaled[75000:]

# Generate random indices for shuffling the data
indices = np.arange(smart_insole_data_scaled_Train.shape[0])
np.random.shuffle(indices)

seed_everything(42)
# Use the shuffled indices to randomly select training data
X_train = smart_insole_data_scaled_Train[indices]
y_train = force_plate_data_scaled_Train[indices]

Test_indices = np.arange(smart_insole_data_scaled_Test.shape[0])
np.random.shuffle(Test_indices)

seed_everything(42)
# # Assign the test data
X_test = smart_insole_data_scaled_Test[Test_indices]
y_test = force_plate_data_scaled_Test[Test_indices]

print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)

n_timesteps = X_train.shape[1] #13
n_features  = X_train.shape[2] #1 

# model = Sequential()
# model.add(Conv1D(32, 3, activation='tanh', input_shape=(n_timesteps, n_features)))
# model.add(MaxPooling1D(2))
# model.add(Conv1D(64, 3, activation='tanh'))
# model.add(MaxPooling1D(2))
# model.add(Flatten())
# model.add(Dense(64, activation='tanh'))
# model.add(Dense(1, activation='linear'))

model = Sequential()

model.add(Conv1D(32, 7, activation='tanh', input_shape=(n_timesteps, n_features)))
model.add(MaxPooling1D(2))

model.add(Conv1D(64, 7, activation='tanh'))
model.add(MaxPooling1D(2))

model.add(Conv1D(128, 7, activation='tanh'))
model.add(MaxPooling1D(2))

model.add(Conv1D(256, 7, activation='tanh'))
model.add(MaxPooling1D(2))

model.add(Flatten())

model.add(Dense(128, activation='tanh'))
model.add(Dense(64, activation='tanh'))

model.add(Dense(1, activation='linear'))

Regression_Model = model
Regression_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

Regression_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('Saved_Model.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
history = Regression_Model.fit(X_train, y_train, epochs=2000, batch_size=64, verbose=1, shuffle=True)

plt.figure()
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
Regression_Model.evaluate(X_train, y_train)
ypred = Regression_Model.predict(X_train)

print('MSE: ',mean_squared_error(y_train, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_train, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_train, ypred))

# # Inverse transform the predictions and actual values
y_pred = (ypred * (maxForcePlate - minForcePlate)) + minForcePlate
y_real = (y_train * (maxForcePlate - minForcePlate)) + minForcePlate

# y_pred = y_pred[np.argsort(indices)]
# y_real = y_real[np.argsort(indices)]

print('MSE: ',mean_squared_error(y_real, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_real, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real, ypred))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real[0:3000,i],color='red')
    plt.plot(x,y_pred[0:3000,i], markerfacecolor='none',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(Regression_Model, '1ouput.h5')
#End Training Process

# Load Model to Predict Real Data
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(X_test, y_test)
Test_Pred = modelCoy.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred))

# predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
# Real = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions = Platescaler.inverse_transform(Test_Pred)
Real = Platescaler.inverse_transform(y_test)

predictions = predictions[np.argsort(Test_indices)]
Real = Real[np.argsort(Test_indices)]

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:2000,i],color='red')
    plt.plot(x,predictions[0:2000,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
SIDataStanding3[:10]

# %%
import numpy as np
import pandas as pd
# import seaborn as sns
from numpy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Conv2D, MaxPooling2D, Reshape, Flatten, Dense
from keras.models import Model, model_from_json
from keras.optimizers import Adam, RMSprop
# from tensorflow.keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import Normalizer,MinMaxScaler,StandardScaler, RobustScaler, QuantileTransformer, PowerTransformer
# sns.set_theme(style="whitegrid")
import pywt
np.set_printoptions(suppress=True)
# Import ResNet1D Module
# from ResNet_1DCNN import ResNet
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error, r2_score

columns = ['Fx']
wavelet = 'db4'
max_iter = 50
iter = 0

def seed_everything(seed=42):
    np.random.seed(seed)
    tf.random.set_seed(seed)

# Training Process
# columns = ['Fx','Fy','Fz','Mx','My','Mz']

# Standing Dataset
Insole = pd.read_csv('0310AyuStand5Min1.txt', header=None, low_memory=False)
SIData =  np.asarray(Insole)

df = pd.read_csv('0310AyuStand5Min1.csv', low_memory=False)
columns = ['Fx']
selected_df = df[columns]
FPDatas = selected_df[:]

SmartInsole = np.array(SIData[:]).astype('float32')
FPData = np.array(FPDatas).astype('float32')

SIDataset = SmartInsole
FPDataset = FPData


SIDWTcoeffs = []
for i in range(89):
    coeffs = pywt.wavedec(SIDataset[:, i], wavelet)
    coeffs[-1] = np.zeros_like(coeffs[-1])
#     coeffs[-2] = np.zeros_like(coeffs[-2])
#     coeffs[-3] = np.zeros_like(coeffs[-3])
#     coeffs[-4] = np.zeros_like(coeffs[-4])
#     coeffs[-5] = np.zeros_like(coeffs[-5])
#     coeffs[-6] = np.zeros_like(coeffs[-6])
    SIDWTcoeffs.append(coeffs)

SIData_filtered = np.zeros(SIDataset.shape)
for i in range(89):
    SIData_filtered[:, i] = pywt.waverec(SIDWTcoeffs[i], wavelet, mode='symmetric', axis=0)

# SIids = [0,10,11,12,22,41,42,48,49,50,59,63,74,75,76,77,78]

# SIselection=[]

# for i in range(len(SIData_filtered)):
#   SIselection.append(SIData_filtered[i][SIids])

# SIselection = np.array(SIselection)

# from sklearn.decomposition import PCA
# from sklearn.model_selection import KFold
# from numpy import zeros, newaxis
# from sklearn.feature_selection import f_regression, mutual_info_regression, mutual_info_classif
# from sklearn.feature_selection import SelectKBest
# from sklearn.feature_selection import f_regression

# SIDataPCA = SIData_filtered
# print(SIDataPCA.shape)
# pca = PCA(n_components=0.98)
# pca.fit(SIDataPCA)
# SIdata_pca = pca.transform(SIDataPCA)

# print(SIdata_pca.shape, FPDataset.shape)
# # define feature selection
# fs = SelectKBest(score_func=f_regression, k=5)
# # apply feature selection
# X_selected = fs.fit_transform(SIdata_pca, FPDataset)
# print(X_selected.shape)


max_iter = 50
iter = 0
for i in range(len(SIData_filtered)):
    SIData_filtered[i][0] = SIData_filtered[i][0] + (iter % max_iter) + 1
    iter += 1


# label = pd.read_csv('label.txt', header=None, low_memory=False)
# labelData = np.array(label)
# Label = np.array(labelData[:15000]).astype('float32')

# label_data = np.tile(Label, (X_selected.shape[0] // Label.shape[0], 1))
# print(label_data[15000:15010])

# SIlabeled = np.concatenate((label_data, X_selected), axis=1)

# Scale the smart insole data
minInsole = SIData_filtered.min()
maxInsole = SIData_filtered.max()
smart_insole_data_scaled = (SIData_filtered - minInsole) / ( maxInsole - minInsole )

# Scale the force plate data
minForcePlate = FPDataset.min()
maxForcePlate = FPDataset.max()
force_plate_data_scaled = (FPDataset - minForcePlate) / ( maxForcePlate - minForcePlate )


#Spliting Data
sample_size = smart_insole_data_scaled.shape[0] # number of samples in train set
time_steps  = smart_insole_data_scaled.shape[1] # number of features in train set
input_dimension = 1               # each feature is represented by 1 number

train_data_reshaped = smart_insole_data_scaled.reshape(sample_size,time_steps,input_dimension)

# X_train, X_test, y_train, y_test = train_test_split(train_data_reshaped[:13000],
#                                                     force_plate_data_scaled[:13000],
#                                                     test_size=0.20, random_state=2)

smart_insole_data_scaled_Train = train_data_reshaped[:13000]
smart_insole_data_scaled_Test = train_data_reshaped[13000:]
force_plate_data_scaled_Train = force_plate_data_scaled[:13000]
force_plate_data_scaled_Test = force_plate_data_scaled[13000:]

# Generate random indices for shuffling the data
indices = np.arange(smart_insole_data_scaled_Train.shape[0])
np.random.shuffle(indices)

seed_everything(42)
# Use the shuffled indices to randomly select training data
X_train = smart_insole_data_scaled_Train[indices]
y_train = force_plate_data_scaled_Train[indices]

Test_indices = np.arange(smart_insole_data_scaled_Test.shape[0])
np.random.shuffle(Test_indices)

seed_everything(42)
# # Assign the test data
X_test = smart_insole_data_scaled_Test[Test_indices]
y_test = force_plate_data_scaled_Test[Test_indices]

print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)

def tcn_regression(input_shape):
    # Input layer
    inputs = Input(shape=input_shape)
    
    # Convolutional blocks
    x = Conv1D(filters=64, kernel_size=3, padding='causal')(inputs)
    x = Activation('relu')(x)
    x = BatchNormalization()(x)
    
    x = Conv1D(filters=64, kernel_size=3, padding='causal')(x)
    x = Activation('relu')(x)
    x = BatchNormalization()(x)
    
    x = MaxPooling1D(pool_size=2)(x)
    
    x = Conv1D(filters=128, kernel_size=3, padding='causal')(x)
    x = Activation('relu')(x)
    x = BatchNormalization()(x)
    
    x = Conv1D(filters=128, kernel_size=3, padding='causal')(x)
    x = Activation('relu')(x)
    x = BatchNormalization()(x)
    
    x = MaxPooling1D(pool_size=2)(x)
    
    x = Conv1D(filters=256, kernel_size=3, padding='causal')(x)
    x = Activation('relu')(x)
    x = BatchNormalization()(x)
    
    x = Conv1D(filters=256, kernel_size=3, padding='causal')(x)
    x = Activation('relu')(x)
    x = BatchNormalization()(x)
    
    x = MaxPooling1D(pool_size=2)(x)
    
    # Flatten layer
    x = Flatten()(x)
    
    # Dense layers
    x = Dense(256)(x)
    x = Activation('relu')(x)
    x = BatchNormalization()(x)
    
    x = Dense(128)(x)
    x = Activation('relu')(x)
    x = BatchNormalization()(x)
    
    # Output layer
    outputs = Dense(1,activation='linear')(x)  # Regression output
    
    
    # Create the model
    model = Model(inputs=inputs, outputs=outputs)
    
    return model

# Example usage
input_shape = (SIData.shape[1], 1)
num_filters = 64
kernel_size = 3
num_layers = 4
dilation_rate = 2

model = tcn_regression(input_shape)

Regression_Model = model
Regression_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

Regression_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('Saved_Model.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, shuffle=True)

plt.figure()
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
Regression_Model.evaluate(X_train, y_train)
ypred = Regression_Model.predict(X_train)

print('MSE: ',mean_squared_error(y_train, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_train, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_train, ypred))

# # Inverse transform the predictions and actual values
y_pred = (ypred * (maxForcePlate - minForcePlate)) + minForcePlate
y_real = (y_train * (maxForcePlate - minForcePlate)) + minForcePlate

# y_pred = y_pred[np.argsort(indices)]
# y_real = y_real[np.argsort(indices)]

print('MSE: ',mean_squared_error(y_real, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_real, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real, ypred))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real[0:3000,i],color='red')
    plt.plot(x,y_pred[0:3000,i], markerfacecolor='none',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(Regression_Model, '1ouput.h5')
#End Training Process

# Load Model to Predict Real Data
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(X_test, y_test)
Test_Pred = modelCoy.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred))

predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
Real = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions = predictions[np.argsort(Test_indices)]
Real = Real[np.argsort(Test_indices)]

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:2000,i],color='red')
    plt.plot(x,predictions[0:2000,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
pip install keras-transformer

# %%
pip install tensorflow keras

# %%
import numpy as np
import pandas as pd
# import seaborn as sns
from numpy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Conv2D, MaxPooling2D, Reshape, Flatten, Dense
from keras.models import Model, model_from_json
from keras.optimizers import Adam, RMSprop
# from tensorflow.keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import Normalizer,MinMaxScaler,StandardScaler, RobustScaler, QuantileTransformer, PowerTransformer
# sns.set_theme(style="whitegrid")
import pywt
np.set_printoptions(suppress=True)
# Import ResNet1D Module
# from ResNet_1DCNN import ResNet
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error, r2_score
from keras_transformer import get_custom_objects, get_encoder_component
from keras_transformer import get_encoders, TransformerModel

columns = ['Fx']
wavelet = 'db4'
max_iter = 50
iter = 0

def seed_everything(seed=42):
    np.random.seed(seed)
    tf.random.set_seed(seed)

# Training Process
# columns = ['Fx','Fy','Fz','Mx','My','Mz']

# Standing Dataset
Insole = pd.read_csv('0310AyuStand5Min1.txt', header=None, low_memory=False)
SIData =  np.asarray(Insole)

df = pd.read_csv('0310AyuStand5Min1.csv', low_memory=False)
columns = ['Fx']
selected_df = df[columns]
FPDatas = selected_df[:]

SmartInsole = np.array(SIData[:]).astype('float32')
FPData = np.array(FPDatas).astype('float32')

SIDataset = SmartInsole
FPDataset = FPData


SIDWTcoeffs = []
for i in range(89):
    coeffs = pywt.wavedec(SIDataset[:, i], wavelet)
    coeffs[-1] = np.zeros_like(coeffs[-1])
#     coeffs[-2] = np.zeros_like(coeffs[-2])
#     coeffs[-3] = np.zeros_like(coeffs[-3])
#     coeffs[-4] = np.zeros_like(coeffs[-4])
#     coeffs[-5] = np.zeros_like(coeffs[-5])
#     coeffs[-6] = np.zeros_like(coeffs[-6])
    SIDWTcoeffs.append(coeffs)

SIData_filtered = np.zeros(SIDataset.shape)
for i in range(89):
    SIData_filtered[:, i] = pywt.waverec(SIDWTcoeffs[i], wavelet, mode='symmetric', axis=0)

# SIids = [0,10,11,12,22,41,42,48,49,50,59,63,74,75,76,77,78]

# SIselection=[]

# for i in range(len(SIData_filtered)):
#   SIselection.append(SIData_filtered[i][SIids])

# SIselection = np.array(SIselection)

# from sklearn.decomposition import PCA
# from sklearn.model_selection import KFold
# from numpy import zeros, newaxis
# from sklearn.feature_selection import f_regression, mutual_info_regression, mutual_info_classif
# from sklearn.feature_selection import SelectKBest
# from sklearn.feature_selection import f_regression

# SIDataPCA = SIData_filtered
# print(SIDataPCA.shape)
# pca = PCA(n_components=0.98)
# pca.fit(SIDataPCA)
# SIdata_pca = pca.transform(SIDataPCA)

# print(SIdata_pca.shape, FPDataset.shape)
# # define feature selection
# fs = SelectKBest(score_func=f_regression, k=5)
# # apply feature selection
# X_selected = fs.fit_transform(SIdata_pca, FPDataset)
# print(X_selected.shape)


max_iter = 50
iter = 0
for i in range(len(SIData_filtered)):
    SIData_filtered[i][0] = SIData_filtered[i][0] + (iter % max_iter) + 1
    iter += 1


# label = pd.read_csv('label.txt', header=None, low_memory=False)
# labelData = np.array(label)
# Label = np.array(labelData[:15000]).astype('float32')

# label_data = np.tile(Label, (X_selected.shape[0] // Label.shape[0], 1))
# print(label_data[15000:15010])

# SIlabeled = np.concatenate((label_data, X_selected), axis=1)

# Scale the smart insole data
minInsole = SIData_filtered.min()
maxInsole = SIData_filtered.max()
smart_insole_data_scaled = (SIData_filtered - minInsole) / ( maxInsole - minInsole )

# Scale the force plate data
minForcePlate = FPDataset.min()
maxForcePlate = FPDataset.max()
force_plate_data_scaled = (FPDataset - minForcePlate) / ( maxForcePlate - minForcePlate )


#Spliting Data
sample_size = smart_insole_data_scaled.shape[0] # number of samples in train set
time_steps  = smart_insole_data_scaled.shape[1] # number of features in train set
input_dimension = 1               # each feature is represented by 1 number

train_data_reshaped = smart_insole_data_scaled.reshape(sample_size,time_steps,input_dimension)

# X_train, X_test, y_train, y_test = train_test_split(train_data_reshaped[:13000],
#                                                     force_plate_data_scaled[:13000],
#                                                     test_size=0.20, random_state=2)

smart_insole_data_scaled_Train = train_data_reshaped[:13000]
smart_insole_data_scaled_Test = train_data_reshaped[13000:]
force_plate_data_scaled_Train = force_plate_data_scaled[:13000]
force_plate_data_scaled_Test = force_plate_data_scaled[13000:]

# Generate random indices for shuffling the data
indices = np.arange(smart_insole_data_scaled_Train.shape[0])
np.random.shuffle(indices)

seed_everything(42)
# Use the shuffled indices to randomly select training data
X_train = smart_insole_data_scaled_Train[indices]
y_train = force_plate_data_scaled_Train[indices]

Test_indices = np.arange(smart_insole_data_scaled_Test.shape[0])
np.random.shuffle(Test_indices)

seed_everything(42)
# # Assign the test data
X_test = smart_insole_data_scaled_Test[Test_indices]
y_test = force_plate_data_scaled_Test[Test_indices]

print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)

input_shape = 89

# Define the Transformer-based regression model
def transformer_regression(input_shape):
    inputs = Input(shape=input_shape)
    transformer = tf.keras.layers.Transformer(num_layers=4, d_model=32, num_heads=4, dropout=0.1)
    transformer_output = transformer(inputs)
    outputs = Dense(1)(transformer_output)
    model = Model(inputs=inputs, outputs=outputs)
    return model

# Create the model
model = transformer_regression(input_shape)
Regression_Model = model
Regression_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

Regression_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('Saved_Model.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, shuffle=True)

plt.figure()
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
Regression_Model.evaluate(X_train, y_train)
ypred = Regression_Model.predict(X_train)

print('MSE: ',mean_squared_error(y_train, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_train, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_train, ypred))

# # Inverse transform the predictions and actual values
y_pred = (ypred * (maxForcePlate - minForcePlate)) + minForcePlate
y_real = (y_train * (maxForcePlate - minForcePlate)) + minForcePlate

# y_pred = y_pred[np.argsort(indices)]
# y_real = y_real[np.argsort(indices)]

print('MSE: ',mean_squared_error(y_real, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_real, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real, ypred))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real[0:3000,i],color='red')
    plt.plot(x,y_pred[0:3000,i], markerfacecolor='none',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(Regression_Model, '1ouput.h5')
#End Training Process

# Load Model to Predict Real Data
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(X_test, y_test)
Test_Pred = modelCoy.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred))

predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
Real = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions = predictions[np.argsort(Test_indices)]
Real = Real[np.argsort(Test_indices)]

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:2000,i],color='red')
    plt.plot(x,predictions[0:2000,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(X_test, y_test)
Test_Pred = modelCoy.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred))

# predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
# Real = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions = Platescaler.inverse_transform(Test_Pred)
Real = Platescaler.inverse_transform(y_test)

predictions = predictions[np.argsort(Test_indices)]
Real = Real[np.argsort(Test_indices)]

x=[]
x = np.arange(0,2000)*40/2000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:2000,i],color='red')
    plt.plot(x,predictions[0:2000,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
predictions[:10]

# %%
Real[:10]

# %%
from scipy.spatial.distance import euclidean
from scipy.signal import correlate
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd

columns = ['Fx']

InsoleStanding1 = pd.read_csv('0310AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding2 = pd.read_csv('0310HudaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding3 = pd.read_csv('0311LalaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding4 = pd.read_csv('0311YunitaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding5 = pd.read_csv('0312AbelStand5Min1.txt', header=None, low_memory=False)
InsoleStanding6 = pd.read_csv('0312AbiStand5Min1.txt', header=None, low_memory=False)
InsoleStanding7 = pd.read_csv('0312AryaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding8 = pd.read_csv('0312HawaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding9 = pd.read_csv('0312NisaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding10 = pd.read_csv('0313ChenChengStand5Min1.txt', header=None, low_memory=False)
InsoleStanding11 = pd.read_csv('0313RezaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding12 = pd.read_csv('0313RilaniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding13 = pd.read_csv('0313SariStand5Min1.txt', header=None, low_memory=False)
InsoleStanding14 = pd.read_csv('0313ShelbyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding15 = pd.read_csv('0314HelenStand5Min1.txt', header=None, low_memory=False)
InsoleStanding16 = pd.read_csv('0315AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding17 = pd.read_csv('0315HappyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding18 = pd.read_csv('0317HeniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding19 = pd.read_csv('0317NadiaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding20 = pd.read_csv('0317VikaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding21 = pd.read_csv('0319AlfianStand5Min1.txt', header=None, low_memory=False)
InsoleStanding22 = pd.read_csv('0310JakaStand2Min.txt', header=None, low_memory=False)
SIDatasStanding1 =  np.array(InsoleStanding1)
SIDatasStanding2 =  np.array(InsoleStanding2)
SIDatasStanding3 =  np.array(InsoleStanding3)
SIDatasStanding4 =  np.array(InsoleStanding4)
SIDatasStanding5 =  np.array(InsoleStanding5)
SIDatasStanding6 =  np.array(InsoleStanding6)
SIDatasStanding7 =  np.array(InsoleStanding7)
SIDatasStanding8 =  np.array(InsoleStanding8)
SIDatasStanding9 =  np.array(InsoleStanding9)
SIDatasStanding10 =  np.array(InsoleStanding10)
SIDatasStanding11 =  np.array(InsoleStanding11)
SIDatasStanding12 =  np.array(InsoleStanding12)
SIDatasStanding13 =  np.array(InsoleStanding13)
SIDatasStanding14 =  np.array(InsoleStanding14)
SIDatasStanding15 =  np.array(InsoleStanding15)
SIDatasStanding16 =  np.array(InsoleStanding16)
SIDatasStanding17 =  np.array(InsoleStanding17)
SIDatasStanding18 =  np.array(InsoleStanding18)
SIDatasStanding19 =  np.array(InsoleStanding19)
SIDatasStanding20 =  np.array(InsoleStanding20)
SIDatasStanding21 =  np.array(InsoleStanding21)

dfStanding1 = pd.read_csv('0310AyuStand5Min1.csv', low_memory=False)
dfStanding2 = pd.read_csv('0310HudaStand5Min1.csv', low_memory=False)
dfStanding3 = pd.read_csv('0311LalaStand5Min1.csv', low_memory=False)
dfStanding4 = pd.read_csv('0311YunitaStand5Min1.csv', low_memory=False)
dfStanding5 = pd.read_csv('0312AbelStand5Min1.csv', low_memory=False)
dfStanding6 = pd.read_csv('0312AbiStand5Min1.csv', low_memory=False)
dfStanding7 = pd.read_csv('0312AryaStand5Min1.csv', low_memory=False)
dfStanding8 = pd.read_csv('0312HawaStand5Min1.csv', low_memory=False)
dfStanding9 = pd.read_csv('0312NisaStand5Min1.csv', low_memory=False)
dfStanding10 = pd.read_csv('0313ChenChengStand5Min1.csv', low_memory=False)
dfStanding11 = pd.read_csv('0313RezaStand5Min1.csv', low_memory=False)
dfStanding12 = pd.read_csv('0313RilaniStand5Min1.csv', low_memory=False)
dfStanding13 = pd.read_csv('0313SariStand5Min1.csv', low_memory=False)
dfStanding14 = pd.read_csv('0313ShelbyStand5Min1.csv', low_memory=False)
dfStanding15 = pd.read_csv('0314HelenStand5Min1.csv', low_memory=False)
dfStanding16 = pd.read_csv('0315AyuStand5Min1.csv', low_memory=False)
dfStanding17 = pd.read_csv('0315HappyStand5Min1.csv', low_memory=False)
dfStanding18 = pd.read_csv('0317HeniStand5Min1.csv', low_memory=False)
dfStanding19 = pd.read_csv('0317NadiaStand5Min1.csv', low_memory=False)
dfStanding20 = pd.read_csv('0317VikaStand5Min1.csv', low_memory=False)
dfStanding21 = pd.read_csv('0319AlfianStand5Min1.csv', low_memory=False)

selected_dfStandings1 = dfStanding1[columns]
selected_dfStandings2 = dfStanding2[columns]
selected_dfStandings3 = dfStanding3[columns]
selected_dfStandings4 = dfStanding4[columns]
selected_dfStandings5 = dfStanding5[columns]
selected_dfStandings6 = dfStanding6[columns]
selected_dfStandings7 = dfStanding7[columns]
selected_dfStandings8 = dfStanding8[columns]
selected_dfStandings9 = dfStanding9[columns]
selected_dfStandings10 = dfStanding10[columns]
selected_dfStandings11 = dfStanding11[columns]
selected_dfStandings12 = dfStanding12[columns]
selected_dfStandings13 = dfStanding13[columns]
selected_dfStandings14 = dfStanding14[columns]
selected_dfStandings15 = dfStanding15[columns]
selected_dfStandings16 = dfStanding16[columns]
selected_dfStandings17 = dfStanding17[columns]
selected_dfStandings18 = dfStanding18[columns]
selected_dfStandings19 = dfStanding19[columns]
selected_dfStandings20 = dfStanding20[columns]
selected_dfStandings21 = dfStanding21[columns]
FPDataStandings1 = selected_dfStandings1[:500]
FPDataStandings2 = selected_dfStandings2[:500]
FPDataStandings3 = selected_dfStandings3[:500]
FPDataStandings4 = selected_dfStandings4[:500]
FPDataStandings5 = selected_dfStandings5[:500]
FPDataStandings6 = selected_dfStandings6[:500]
FPDataStandings7 = selected_dfStandings7[:500]
FPDataStandings8 = selected_dfStandings8[:500]
FPDataStandings9 = selected_dfStandings9[:500]
FPDataStandings10 = selected_dfStandings10[:500]
FPDataStandings11 = selected_dfStandings11[:500]
FPDataStandings12 = selected_dfStandings12[:500]
FPDataStandings13 = selected_dfStandings13[:500]
FPDataStandings14 = selected_dfStandings14[:500]
FPDataStandings15 = selected_dfStandings15[:500]
FPDataStandings16 = selected_dfStandings16[:500]
FPDataStandings17 = selected_dfStandings17[:500]
FPDataStandings18 = selected_dfStandings18[:500]
FPDataStandings19 = selected_dfStandings19[:500]
FPDataStandings20 = selected_dfStandings20[:500]
FPDataStandings21 = selected_dfStandings21[:500]

SIDataStanding1 = np.array(SIDatasStanding1[:500]).astype('float64')
SIDataStanding2 = np.array(SIDatasStanding2[:500]).astype('float64')
SIDataStanding3 = np.array(SIDatasStanding3[:500]).astype('float64')
SIDataStanding4 = np.array(SIDatasStanding4[:500]).astype('float64')
SIDataStanding5 = np.array(SIDatasStanding5[:500]).astype('float64')
SIDataStanding6 = np.array(SIDatasStanding6[:500]).astype('float64')
SIDataStanding7 = np.array(SIDatasStanding7[:500]).astype('float64')
SIDataStanding8 = np.array(SIDatasStanding8[:500]).astype('float64')
SIDataStanding9 = np.array(SIDatasStanding9[:500]).astype('float64')
SIDataStanding10 = np.array(SIDatasStanding10[:500]).astype('float64')
SIDataStanding11 = np.array(SIDatasStanding11[:500]).astype('float64')
SIDataStanding12 = np.array(SIDatasStanding12[:500]).astype('float64')
SIDataStanding13 = np.array(SIDatasStanding13[:500]).astype('float64')
SIDataStanding14 = np.array(SIDatasStanding14[:500]).astype('float64')
SIDataStanding15 = np.array(SIDatasStanding15[:500]).astype('float64')
SIDataStanding16 = np.array(SIDatasStanding16[:500]).astype('float64')
SIDataStanding17 = np.array(SIDatasStanding17[:500]).astype('float64')
SIDataStanding18 = np.array(SIDatasStanding18[:500]).astype('float64')
SIDataStanding19 = np.array(SIDatasStanding19[:500]).astype('float64')
SIDataStanding20 = np.array(SIDatasStanding20[:500]).astype('float64')
SIDataStanding21 = np.array(SIDatasStanding21[:500]).astype('float64')
FPDataStanding1 = np.array(FPDataStandings1).astype('float64')
FPDataStanding2 = np.array(FPDataStandings2).astype('float64')
FPDataStanding3= np.array(FPDataStandings3).astype('float64')
FPDataStanding4= np.array(FPDataStandings4).astype('float64')
FPDataStanding5= np.array(FPDataStandings5).astype('float64')
FPDataStanding6= np.array(FPDataStandings6).astype('float64')
FPDataStanding7= np.array(FPDataStandings7).astype('float64')
FPDataStanding8= np.array(FPDataStandings8).astype('float64')
FPDataStanding9= np.array(FPDataStandings9).astype('float64')
FPDataStanding10 = np.array(FPDataStandings10).astype('float64')
FPDataStanding11 = np.array(FPDataStandings11).astype('float64')
FPDataStanding12= np.array(FPDataStandings12).astype('float64')
FPDataStanding13= np.array(FPDataStandings13).astype('float64')
FPDataStanding14= np.array(FPDataStandings14).astype('float64')
FPDataStanding15= np.array(FPDataStandings15).astype('float64')
FPDataStanding16= np.array(FPDataStandings16).astype('float64')
FPDataStanding17= np.array(FPDataStandings17).astype('float64')
FPDataStanding18= np.array(FPDataStandings18).astype('float64')
FPDataStanding19= np.array(FPDataStandings19).astype('float64')
FPDataStanding20= np.array(FPDataStandings20).astype('float64')
FPDataStanding21= np.array(FPDataStandings21).astype('float64')


# Combine the 21 datasets into one
data = np.concatenate((FPDataStanding1, FPDataStanding2, FPDataStanding3, FPDataStanding4, FPDataStanding5, FPDataStanding6, FPDataStanding7, FPDataStanding8,
                       FPDataStanding9, FPDataStanding10, FPDataStanding11, FPDataStanding12, FPDataStanding13, FPDataStanding14, FPDataStanding15,
                       FPDataStanding16, FPDataStanding17, FPDataStanding18, FPDataStanding19, FPDataStanding20, FPDataStanding21), axis=0)

# Reshape the data to be 1-D arrays
data_flat = [ts.flatten() for ts in data]

# Compute pairwise DTW distances between time series
distances = np.zeros((len(data_flat), len(data_flat)))
for i in range(len(data_flat)):
    for j in range(i + 1, len(data_flat)):
        dist = np.inf
        for shift in range(len(data_flat[i])):
            aligned_data = np.roll(data_flat[j], shift)
            curr_dist = np.sqrt(np.sum(np.square(data_flat[i] - aligned_data)))
            if curr_dist < dist:
                dist = curr_dist
        distances[i, j] = dist
        distances[j, i] = dist

# Perform K-means clustering with 2 clusters
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(distances)

# Get the cluster labels
labels = kmeans.labels_

# Group the data based on the cluster labels
group_1_indices = np.where(labels == 0)[0]
group_2_indices = np.where(labels == 1)[0]
group_3_indices = np.where(labels == 2)[0]

# Determine which original data each group belongs to
group_1_data = []
group_2_data = []
group_3_data = []
group_1_origins = []
group_2_origins = []
group_3_origins = []

for index in group_1_indices:
    if index < len(FPDataStanding1):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding1")
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding2")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding3")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding4")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding5")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding7")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding8")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding9")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding10")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding11")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding12")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding13")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding14")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding15")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding16")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding17")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding18")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding19")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding20")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding21")

for index in group_2_indices:
    if index < len(FPDataStanding1):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding1")
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding2")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding3")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding4")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding5")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding6")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding7")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding8")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding9")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding10")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding11")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding12")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding13")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding14")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding15")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding16")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding17")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) +len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding18")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding19")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding20")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding21")


for index in group_3_indices:
    if index < len(FPDataStanding1):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding1")
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding2")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding3")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding4")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding5")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding6")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding7")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding8")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding9")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding10")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding11")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding12")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding13")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding14")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding15")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding16")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding17")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) +len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding18")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding19")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding20")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding21")


# Print the grouped data
print("Group 1:")
print("Data:")
for d in group_1_data:
    print(d)
print("Origins:")
for origin in group_1_origins:
    print(origin)

print("Group 2:")
print("Data:")
for d in group_2_data:
    print(d)
print("Origins:")
for origin in group_2_origins:
    print(origin)

print("Group 3:")
print("Data:")
for d in group_3_data:
    print(d)
print("Origins:")
for origin in group_3_origins:
    print(origin)

# %%
# Print the grouped data
print("Group 1:")
# print("Data:")
# for d in group_1_data:
# #     print(d)
print("Origins:")
for origin in group_1_origins:
    print(origin)

print("Group 2:")
# print("Data:")
# for d in group_2_data:
#     print(d)
print("Origins:")
for origin in group_2_origins:
    print(origin)

print("Group 3:")
# print("Data:")
# for d in group_3_data:
#     print(d)
print("Origins:")
for origin in group_3_origins:
    print(origin)

# %%
import numpy as np
from scipy.spatial.distance import euclidean
from scipy.signal import correlate
from sklearn.cluster import KMeans

FPDataStanding1 = np.array([
    [6.59875],
    [6.76239],
    [6.45033],
    [5.79133],
    [5.56692],
    [-5.57529],
    [5.67805],
    [5.87954],
    [5.93947],
    [5.80316],
])

FPDataStanding2 = np.array([
    [39.3875],
    [39.3033],
    [39.233],
    [38.8577],
    [39.1549],
    [39.52],
    [40.4228],
    [40.4586],
    [40.3507],
    [40.7479],
])

FPDataStanding3 = np.array([
    [5.35265],
    [4.7069],
    [4.94478],
    [5.63455],
    [5.99171],
    [5.25056],
    [5.16239],
    [5.42854],
    [6.04217],
    [6.1847],
])

FPData_4 = np.array([
    [13.5343],
    [13.6674],
    [13.1456],
    [12.9966],
    [12.1601],
    [13.1042],
    [13.3396],
    [13.2633],
    [14.0001],
    [14.0524],
])

# Combine the four datasets into one
data = np.concatenate((FPDataStanding1, FPDataStanding2, FPDataStanding3, FPData_4), axis=0)

# Reshape the data to be 1-D arrays
data_flat = [ts.flatten() for ts in data]

# Compute pairwise DTW distances between time series
distances = np.zeros((len(data_flat), len(data_flat)))
for i in range(len(data_flat)):
    for j in range(i+1, len(data_flat)):
        dist = np.inf
        for shift in range(len(data_flat[i])):
            aligned_data = np.roll(data_flat[j], shift)
            curr_dist = np.sqrt(np.sum(np.square(data_flat[i] - aligned_data)))
            if curr_dist < dist:
                dist = curr_dist
        distances[i, j] = dist
        distances[j, i] = dist

# Perform K-means clustering with 3 clusters
kmeans = KMeans(n_clusters=3)
kmeans.fit(distances)

# Get the cluster labels
labels = kmeans.labels_

# Group the data based on the cluster labels
group_1 = data[labels == 0]
group_2 = data[labels == 1]
group_3 = data[labels == 2]

# Print the grouped data
print("Group 1:")
print(group_1)
print("Group 2:")
print(group_2)
print("Group 3:")
print(group_3)

# %%
import numpy as np
from scipy.spatial.distance import euclidean
from scipy.signal import correlate
from sklearn.cluster import KMeans

# Define the FPDataStanding datasets
FPDataStanding1 = np.array([
    [6.59875],
    [6.76239],
    [6.45033],
    [5.79133],
    [5.56692],
    [-5.57529],
    [5.67805],
    [5.87954],
    [5.93947],
    [5.80316],
])

FPDataStanding2 = np.array([
    [39.3875],
    [39.3033],
    [39.233],
    [38.8577],
    [39.1549],
    [39.52],
    [40.4228],
    [40.4586],
    [40.3507],
    [40.7479],
])

FPDataStanding3 = np.array([
    [5.35265],
    [4.7069],
    [4.94478],
    [5.63455],
    [5.99171],
    [5.25056],
    [5.16239],
    [5.42854],
    [6.04217],
    [6.1847],
])

FPDataStanding4 = np.array([
    [13.5343],
    [13.6674],
    [13.1456],
    [12.9966],
    [12.1601],
    [13.1042],
    [13.3396],
    [13.2633],
    [14.0001],
    [14.0524],
])

# Define the SIDataStanding datasets
SIDataStanding1 = np.array([
    [1, 78.0, 55.0, 0.0, 0.0, 88.0],
    [2, 78.0, 55.0, 0.0, 0.0, 88.0],
    [3, 53.0, 30.0, 0.0, 0.0, 75.0],
    [4, 53.0, 30.0, 0.0, 0.0, 75.0],
    [5, 53.0, 30.0, 0.0, 0.0, 75.0],
    [6, 33.0, 70.0, 0.0, 0.0, 90.0],
    [7, 33.0, 70.0, 0.0, 0.0, 90.0],
    [8, 33.0, 70.0, 0.0, 0.0, 90.0],
    [9, 33.0, 70.0, 0.0, 0.0, 90.0],
    [10, 33.0, 70.0, 0.0, 0.0, 90.0],
])

SIDataStanding2 = np.array([
    [1, 120.0, 44.0, 0.0, 1.0, 88.0],
    [2, 120.0, 44.0, 0.0, 1.0, 88.0],
    [3, 120.0, 44.0, 0.0, 1.0, 75.0],
    [4, 120.0, 44.0, 0.0, 1.0, 75.0],
    [5, 120.0, 44.0, 0.0, 1.0, 75.0],
    [6, 120.0, 44.0, 0.0, 1.0, 90.0],
    [7, 120.0, 44.0, 0.0, 1.0, 90.0],
    [8, 120.0, 44.0, 0.0, 1.0, 90.0],
    [9, 120.0, 44.0, 0.0, 1.0, 90.0],
    [10, 120.0, 44.0, 0.0, 1.0, 90.0],
])

SIDataStanding3 = np.array([
    [1, 34.0, 55.0, 0.0, 0.0, 88.0],
    [2, 34.0, 55.0, 0.0, 0.0, 88.0],
    [3, 34.0, 30.0, 0.0, 0.0, 75.0],
    [4, 34.0, 30.0, 0.0, 0.0, 75.0],
    [5, 34.0, 30.0, 0.0, 0.0, 75.0],
    [6, 34.0, 70.0, 0.0, 0.0, 90.0],
    [7, 34.0, 70.0, 0.0, 0.0, 90.0],
    [8, 34.0, 70.0, 0.0, 0.0, 90.0],
    [9, 34.0, 70.0, 0.0, 0.0, 90.0],
    [10, 34.0, 70.0, 0.0, 0.0, 90.0],
])

SIDataStanding4 = np.array([
    [1, 78.0, 67.0, 0.0, 0.0, 88.0],
    [2, 78.0, 67.0, 0.0, 0.0, 88.0],
    [3, 53.0, 67.0, 0.0, 0.0, 75.0],
    [4, 53.0, 67.0, 0.0, 0.0, 75.0],
    [5, 53.0, 67.0, 0.0, 0.0, 75.0],
    [6, 33.0, 67.0, 0.0, 0.0, 90.0],
    [7, 33.0, 67.0, 0.0, 0.0, 90.0],
    [8, 33.0, 67.0, 0.0, 0.0, 90.0],
    [9, 33.0, 67.0, 0.0, 0.0, 90.0],
    [10, 33.0, 67.0, 0.0, 0.0, 90.0],
])

# Combine the four datasets into one
data = np.concatenate((FPDataStanding1, FPDataStanding2, FPDataStanding3, FPDataStanding4), axis=0)

# Reshape the data to be 1-D arrays
data_flat = [ts.flatten() for ts in data]

# Compute pairwise DTW distances between time series
distances = np.zeros((len(data_flat), len(data_flat)))
for i in range(len(data_flat)):
    for j in range(i+1, len(data_flat)):
        dist = np.inf
        for shift in range(len(data_flat[i])):
            aligned_data = np.roll(data_flat[j], shift)
            curr_dist = np.sqrt(np.sum(np.square(data_flat[i] - aligned_data)))
            if curr_dist < dist:
                dist = curr_dist
        distances[i, j] = dist
        distances[j, i] = dist

# Perform K-means clustering with 3 clusters
kmeans = KMeans(n_clusters=3)
kmeans.fit(distances)

# Get the cluster labels
labels = kmeans.labels_

# Group the data based on the cluster labels
group_1 = data[labels == 0]
group_2 = data[labels == 1]
group_3 = data[labels == 2]

# Define the number of samples in each SIDataStanding dataset
num_samples = 10

# Assign labels to SIDataStanding groups based on FPDataStanding grouping
SIData_group_1 = np.concatenate((SIDataStanding1[labels[:num_samples] == 0], SIDataStanding2[labels[num_samples:2*num_samples] == 0],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 0], SIDataStanding4[labels[3*num_samples:] == 0]), axis=0)
SIData_group_2 = np.concatenate((SIDataStanding1[labels[:num_samples] == 1], SIDataStanding2[labels[num_samples:2*num_samples] == 1],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 1], SIDataStanding4[labels[3*num_samples:] == 1]), axis=0)
SIData_group_3 = np.concatenate((SIDataStanding1[labels[:num_samples] == 2], SIDataStanding2[labels[num_samples:2*num_samples] == 2],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 2], SIDataStanding4[labels[3*num_samples:] == 2]), axis=0)
# Print the grouped data
print("Group 1 (FPDataStanding):")
print(group_1)
print("Group 1 (SIDataStanding):")
print(SIData_group_1)
print("\n")
print("Group 2 (FPDataStanding):")
print(group_2)
print("Group 2 (SIDataStanding):")
print(SIData_group_2)
print("\n")
print("Group 3 (FPDataStanding):")
print(group_3)
print("Group 3 (SIDataStanding):")
print(SIData_group_3)

# %%
from scipy.spatial.distance import euclidean
from scipy.signal import correlate
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd

columns = ['Fx']

InsoleStanding1 = pd.read_csv('0310AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding2 = pd.read_csv('0310HudaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding3 = pd.read_csv('0311LalaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding4 = pd.read_csv('0311YunitaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding5 = pd.read_csv('0312AbelStand5Min1.txt', header=None, low_memory=False)
InsoleStanding6 = pd.read_csv('0312AbiStand5Min1.txt', header=None, low_memory=False)
InsoleStanding7 = pd.read_csv('0312AryaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding8 = pd.read_csv('0312HawaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding9 = pd.read_csv('0312NisaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding10 = pd.read_csv('0313ChenChengStand5Min1.txt', header=None, low_memory=False)
InsoleStanding11 = pd.read_csv('0313RezaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding12 = pd.read_csv('0313RilaniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding13 = pd.read_csv('0313SariStand5Min1.txt', header=None, low_memory=False)
InsoleStanding14 = pd.read_csv('0313ShelbyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding15 = pd.read_csv('0314HelenStand5Min1.txt', header=None, low_memory=False)
InsoleStanding16 = pd.read_csv('0315AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding17 = pd.read_csv('0315HappyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding18 = pd.read_csv('0317HeniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding19 = pd.read_csv('0317NadiaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding20 = pd.read_csv('0317VikaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding21 = pd.read_csv('0319AlfianStand5Min1.txt', header=None, low_memory=False)
InsoleStanding22 = pd.read_csv('0310JakaStand2Min.txt', header=None, low_memory=False)
SIDatasStanding1 =  np.array(InsoleStanding1)
SIDatasStanding2 =  np.array(InsoleStanding2)
SIDatasStanding3 =  np.array(InsoleStanding3)
SIDatasStanding4 =  np.array(InsoleStanding4)
SIDatasStanding5 =  np.array(InsoleStanding5)
SIDatasStanding6 =  np.array(InsoleStanding6)
SIDatasStanding7 =  np.array(InsoleStanding7)
SIDatasStanding8 =  np.array(InsoleStanding8)
SIDatasStanding9 =  np.array(InsoleStanding9)
SIDatasStanding10 =  np.array(InsoleStanding10)
SIDatasStanding11 =  np.array(InsoleStanding11)
SIDatasStanding12 =  np.array(InsoleStanding12)
SIDatasStanding13 =  np.array(InsoleStanding13)
SIDatasStanding14 =  np.array(InsoleStanding14)
SIDatasStanding15 =  np.array(InsoleStanding15)
SIDatasStanding16 =  np.array(InsoleStanding16)
SIDatasStanding17 =  np.array(InsoleStanding17)
SIDatasStanding18 =  np.array(InsoleStanding18)
SIDatasStanding19 =  np.array(InsoleStanding19)
SIDatasStanding20 =  np.array(InsoleStanding20)
SIDatasStanding21 =  np.array(InsoleStanding21)

dfStanding1 = pd.read_csv('0310AyuStand5Min1.csv', low_memory=False)
dfStanding2 = pd.read_csv('0310HudaStand5Min1.csv', low_memory=False)
dfStanding3 = pd.read_csv('0311LalaStand5Min1.csv', low_memory=False)
dfStanding4 = pd.read_csv('0311YunitaStand5Min1.csv', low_memory=False)
dfStanding5 = pd.read_csv('0312AbelStand5Min1.csv', low_memory=False)
dfStanding6 = pd.read_csv('0312AbiStand5Min1.csv', low_memory=False)
dfStanding7 = pd.read_csv('0312AryaStand5Min1.csv', low_memory=False)
dfStanding8 = pd.read_csv('0312HawaStand5Min1.csv', low_memory=False)
dfStanding9 = pd.read_csv('0312NisaStand5Min1.csv', low_memory=False)
dfStanding10 = pd.read_csv('0313ChenChengStand5Min1.csv', low_memory=False)
dfStanding11 = pd.read_csv('0313RezaStand5Min1.csv', low_memory=False)
dfStanding12 = pd.read_csv('0313RilaniStand5Min1.csv', low_memory=False)
dfStanding13 = pd.read_csv('0313SariStand5Min1.csv', low_memory=False)
dfStanding14 = pd.read_csv('0313ShelbyStand5Min1.csv', low_memory=False)
dfStanding15 = pd.read_csv('0314HelenStand5Min1.csv', low_memory=False)
dfStanding16 = pd.read_csv('0315AyuStand5Min1.csv', low_memory=False)
dfStanding17 = pd.read_csv('0315HappyStand5Min1.csv', low_memory=False)
dfStanding18 = pd.read_csv('0317HeniStand5Min1.csv', low_memory=False)
dfStanding19 = pd.read_csv('0317NadiaStand5Min1.csv', low_memory=False)
dfStanding20 = pd.read_csv('0317VikaStand5Min1.csv', low_memory=False)
dfStanding21 = pd.read_csv('0319AlfianStand5Min1.csv', low_memory=False)

selected_dfStandings1 = dfStanding1[columns]
selected_dfStandings2 = dfStanding2[columns]
selected_dfStandings3 = dfStanding3[columns]
selected_dfStandings4 = dfStanding4[columns]
selected_dfStandings5 = dfStanding5[columns]
selected_dfStandings6 = dfStanding6[columns]
selected_dfStandings7 = dfStanding7[columns]
selected_dfStandings8 = dfStanding8[columns]
selected_dfStandings9 = dfStanding9[columns]
selected_dfStandings10 = dfStanding10[columns]
selected_dfStandings11 = dfStanding11[columns]
selected_dfStandings12 = dfStanding12[columns]
selected_dfStandings13 = dfStanding13[columns]
selected_dfStandings14 = dfStanding14[columns]
selected_dfStandings15 = dfStanding15[columns]
selected_dfStandings16 = dfStanding16[columns]
selected_dfStandings17 = dfStanding17[columns]
selected_dfStandings18 = dfStanding18[columns]
selected_dfStandings19 = dfStanding19[columns]
selected_dfStandings20 = dfStanding20[columns]
selected_dfStandings21 = dfStanding21[columns]
FPDataStandings1 = selected_dfStandings1[:500]
FPDataStandings2 = selected_dfStandings2[:500]
FPDataStandings3 = selected_dfStandings3[:500]
FPDataStandings4 = selected_dfStandings4[:500]
FPDataStandings5 = selected_dfStandings5[:500]
FPDataStandings6 = selected_dfStandings6[:500]
FPDataStandings7 = selected_dfStandings7[:500]
FPDataStandings8 = selected_dfStandings8[:500]
FPDataStandings9 = selected_dfStandings9[:500]
FPDataStandings10 = selected_dfStandings10[:500]
FPDataStandings11 = selected_dfStandings11[:500]
FPDataStandings12 = selected_dfStandings12[:500]
FPDataStandings13 = selected_dfStandings13[:500]
FPDataStandings14 = selected_dfStandings14[:500]
FPDataStandings15 = selected_dfStandings15[:500]
FPDataStandings16 = selected_dfStandings16[:500]
FPDataStandings17 = selected_dfStandings17[:500]
FPDataStandings18 = selected_dfStandings18[:500]
FPDataStandings19 = selected_dfStandings19[:500]
FPDataStandings20 = selected_dfStandings20[:500]
FPDataStandings21 = selected_dfStandings21[:500]

SIDataStanding1 = np.array(SIDatasStanding1[:500]).astype('float64')
SIDataStanding2 = np.array(SIDatasStanding2[:500]).astype('float64')
SIDataStanding3 = np.array(SIDatasStanding3[:500]).astype('float64')
SIDataStanding4 = np.array(SIDatasStanding4[:500]).astype('float64')
SIDataStanding5 = np.array(SIDatasStanding5[:500]).astype('float64')
SIDataStanding6 = np.array(SIDatasStanding6[:500]).astype('float64')
SIDataStanding7 = np.array(SIDatasStanding7[:500]).astype('float64')
SIDataStanding8 = np.array(SIDatasStanding8[:500]).astype('float64')
SIDataStanding9 = np.array(SIDatasStanding9[:500]).astype('float64')
SIDataStanding10 = np.array(SIDatasStanding10[:500]).astype('float64')
SIDataStanding11 = np.array(SIDatasStanding11[:500]).astype('float64')
SIDataStanding12 = np.array(SIDatasStanding12[:500]).astype('float64')
SIDataStanding13 = np.array(SIDatasStanding13[:500]).astype('float64')
SIDataStanding14 = np.array(SIDatasStanding14[:500]).astype('float64')
SIDataStanding15 = np.array(SIDatasStanding15[:500]).astype('float64')
SIDataStanding16 = np.array(SIDatasStanding16[:500]).astype('float64')
SIDataStanding17 = np.array(SIDatasStanding17[:500]).astype('float64')
SIDataStanding18 = np.array(SIDatasStanding18[:500]).astype('float64')
SIDataStanding19 = np.array(SIDatasStanding19[:500]).astype('float64')
SIDataStanding20 = np.array(SIDatasStanding20[:500]).astype('float64')
SIDataStanding21 = np.array(SIDatasStanding21[:500]).astype('float64')
FPDataStanding1 = np.array(FPDataStandings1).astype('float64')
FPDataStanding2 = np.array(FPDataStandings2).astype('float64')
FPDataStanding3= np.array(FPDataStandings3).astype('float64')
FPDataStanding4= np.array(FPDataStandings4).astype('float64')
FPDataStanding5= np.array(FPDataStandings5).astype('float64')
FPDataStanding6= np.array(FPDataStandings6).astype('float64')
FPDataStanding7= np.array(FPDataStandings7).astype('float64')
FPDataStanding8= np.array(FPDataStandings8).astype('float64')
FPDataStanding9= np.array(FPDataStandings9).astype('float64')
FPDataStanding10 = np.array(FPDataStandings10).astype('float64')
FPDataStanding11 = np.array(FPDataStandings11).astype('float64')
FPDataStanding12= np.array(FPDataStandings12).astype('float64')
FPDataStanding13= np.array(FPDataStandings13).astype('float64')
FPDataStanding14= np.array(FPDataStandings14).astype('float64')
FPDataStanding15= np.array(FPDataStandings15).astype('float64')
FPDataStanding16= np.array(FPDataStandings16).astype('float64')
FPDataStanding17= np.array(FPDataStandings17).astype('float64')
FPDataStanding18= np.array(FPDataStandings18).astype('float64')
FPDataStanding19= np.array(FPDataStandings19).astype('float64')
FPDataStanding20= np.array(FPDataStandings20).astype('float64')
FPDataStanding21= np.array(FPDataStandings21).astype('float64')


# Combine the 21 datasets into one
data = np.concatenate((FPDataStanding1, FPDataStanding2, FPDataStanding3, FPDataStanding4, FPDataStanding5, FPDataStanding6, FPDataStanding7, FPDataStanding8,
                       FPDataStanding9, FPDataStanding10, FPDataStanding11, FPDataStanding12, FPDataStanding13, FPDataStanding14, FPDataStanding15,
                       FPDataStanding16, FPDataStanding17, FPDataStanding18, FPDataStanding19, FPDataStanding20, FPDataStanding21), axis=0)

# Reshape the data to be 1-D arrays
data_flat = [ts.flatten() for ts in data]

# Compute pairwise DTW distances between time series
distances = np.zeros((len(data_flat), len(data_flat)))
for i in range(len(data_flat)):
    for j in range(i + 1, len(data_flat)):
        dist = np.inf
        for shift in range(len(data_flat[i])):
            aligned_data = np.roll(data_flat[j], shift)
            curr_dist = np.sqrt(np.sum(np.square(data_flat[i] - aligned_data)))
            if curr_dist < dist:
                dist = curr_dist
        distances[i, j] = dist
        distances[j, i] = dist

# Perform K-means clustering with 2 clusters
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(distances)

# Get the cluster labels
labels = kmeans.labels_

# Group the data based on the cluster labels
group_1_indices = np.where(labels == 0)[0]
group_2_indices = np.where(labels == 1)[0]
group_3_indices = np.where(labels == 2)[0]

# Define the number of samples in each SIDataStanding dataset
num_samples = 10

# Assign labels to SIDataStanding groups based on FPDataStanding grouping
SIData_group_1 = np.concatenate((SIDataStanding1[labels[:num_samples] == 0], SIDataStanding2[labels[num_samples:2*num_samples] == 0],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 0], SIDataStanding4[labels[3*num_samples:] == 0]), axis=0)
SIData_group_2 = np.concatenate((SIDataStanding1[labels[:num_samples] == 1], SIDataStanding2[labels[num_samples:2*num_samples] == 1],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 1], SIDataStanding4[labels[3*num_samples:] == 1]), axis=0)
SIData_group_3 = np.concatenate((SIDataStanding1[labels[:num_samples] == 2], SIDataStanding2[labels[num_samples:2*num_samples] == 2],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 2], SIDataStanding4[labels[3*num_samples:] == 2]), axis=0)


# Determine which original data each group belongs to
group_1_data = []
group_2_data = []
group_3_data = []
group_1_origins = []
group_2_origins = []
group_3_origins = []

for index in group_1_indices:
    if index < len(FPDataStanding1):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding1")
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding2")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding3")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding4")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding5")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding7")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding8")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding9")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding10")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding11")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding12")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding13")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding14")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding15")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding16")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding17")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding18")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding19")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding20")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding21")

for index in group_2_indices:
    if index < len(FPDataStanding1):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding1")
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding2")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding3")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding4")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding5")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding6")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding7")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding8")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding9")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding10")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding11")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding12")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding13")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding14")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding15")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding16")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding17")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) +len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding18")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding19")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding20")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding21")


for index in group_3_indices:
    if index < len(FPDataStanding1):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding1")
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding2")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding3")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding4")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding5")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding6")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding7")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding8")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding9")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding10")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding11")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding12")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding13")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding14")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding15")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding16")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding17")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) +len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding18")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding19")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding20")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding21")


# # Print the grouped data
# print("Group 1:")
# print("Data:")
# for d in group_1_data:
#     print(d)
# print("Origins:")
# for origin in group_1_origins:
#     print(origin)

# print("Group 2:")
# print("Data:")
# for d in group_2_data:
#     print(d)
# print("Origins:")
# for origin in group_2_origins:
#     print(origin)

# print("Group 3:")
# print("Data:")
# for d in group_3_data:
#     print(d)
# print("Origins:")
# for origin in group_3_origins:
#     print(origin)

# %%
SIDataStanding1 = np.array(SIDatasStanding1[:15000]).astype('float64')
SIDataStanding2 = np.array(SIDatasStanding2[:15000]).astype('float64')
SIDataStanding3 = np.array(SIDatasStanding3[:15000]).astype('float64')
SIDataStanding4 = np.array(SIDatasStanding4[:15000]).astype('float64')
SIDataStanding5 = np.array(SIDatasStanding5[:15000]).astype('float64')
SIDataStanding6 = np.array(SIDatasStanding6[:15000]).astype('float64')
SIDataStanding7 = np.array(SIDatasStanding7[:15000]).astype('float64')
SIDataStanding8 = np.array(SIDatasStanding8[:15000]).astype('float64')
SIDataStanding9 = np.array(SIDatasStanding9[:15000]).astype('float64')
SIDataStanding10 = np.array(SIDatasStanding10[:15000]).astype('float64')
SIDataStanding11 = np.array(SIDatasStanding11[:15000]).astype('float64')
SIDataStanding12 = np.array(SIDatasStanding12[:15000]).astype('float64')
SIDataStanding13 = np.array(SIDatasStanding13[:15000]).astype('float64')
SIDataStanding14 = np.array(SIDatasStanding14[:15000]).astype('float64')
SIDataStanding15 = np.array(SIDatasStanding15[:15000]).astype('float64')
SIDataStanding16 = np.array(SIDatasStanding16[:15000]).astype('float64')
SIDataStanding17 = np.array(SIDatasStanding17[:15000]).astype('float64')
SIDataStanding18 = np.array(SIDatasStanding18[:15000]).astype('float64')
SIDataStanding19 = np.array(SIDatasStanding19[:15000]).astype('float64')
SIDataStanding20 = np.array(SIDatasStanding20[:15000]).astype('float64')
SIDataStanding21 = np.array(SIDatasStanding21[:15000]).astype('float64')
FPDataStanding1 = np.array(FPDataStandings1).astype('float64')
FPDataStanding2 = np.array(FPDataStandings2).astype('float64')
FPDataStanding3= np.array(FPDataStandings3).astype('float64')
FPDataStanding4= np.array(FPDataStandings4).astype('float64')
FPDataStanding5= np.array(FPDataStandings5).astype('float64')
FPDataStanding6= np.array(FPDataStandings6).astype('float64')
FPDataStanding7= np.array(FPDataStandings7).astype('float64')
FPDataStanding8= np.array(FPDataStandings8).astype('float64')
FPDataStanding9= np.array(FPDataStandings9).astype('float64')
FPDataStanding10 = np.array(FPDataStandings10).astype('float64')
FPDataStanding11 = np.array(FPDataStandings11).astype('float64')
FPDataStanding12= np.array(FPDataStandings12).astype('float64')
FPDataStanding13= np.array(FPDataStandings13).astype('float64')
FPDataStanding14= np.array(FPDataStandings14).astype('float64')
FPDataStanding15= np.array(FPDataStandings15).astype('float64')
FPDataStanding16= np.array(FPDataStandings16).astype('float64')
FPDataStanding17= np.array(FPDataStandings17).astype('float64')
FPDataStanding18= np.array(FPDataStandings18).astype('float64')
FPDataStanding19= np.array(FPDataStandings19).astype('float64')
FPDataStanding20= np.array(FPDataStandings20).astype('float64')
FPDataStanding21= np.array(FPDataStandings21).astype('float64')

I want Predict FPDataStanding using SIDataStanding, there will be have 21 sata FPDataStanding and 21

# %%
from scipy.spatial.distance import euclidean
from scipy.signal import correlate
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd

columns = ['Fx']

InsoleStanding1 = pd.read_csv('0310AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding2 = pd.read_csv('0310HudaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding3 = pd.read_csv('0311LalaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding4 = pd.read_csv('0311YunitaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding5 = pd.read_csv('0312AbelStand5Min1.txt', header=None, low_memory=False)
InsoleStanding6 = pd.read_csv('0312AbiStand5Min1.txt', header=None, low_memory=False)
InsoleStanding7 = pd.read_csv('0312AryaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding8 = pd.read_csv('0312HawaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding9 = pd.read_csv('0312NisaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding10 = pd.read_csv('0313ChenChengStand5Min1.txt', header=None, low_memory=False)
InsoleStanding11 = pd.read_csv('0313RezaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding12 = pd.read_csv('0313RilaniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding13 = pd.read_csv('0313SariStand5Min1.txt', header=None, low_memory=False)
InsoleStanding14 = pd.read_csv('0313ShelbyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding15 = pd.read_csv('0314HelenStand5Min1.txt', header=None, low_memory=False)
InsoleStanding16 = pd.read_csv('0315AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding17 = pd.read_csv('0315HappyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding18 = pd.read_csv('0317HeniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding19 = pd.read_csv('0317NadiaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding20 = pd.read_csv('0317VikaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding21 = pd.read_csv('0319AlfianStand5Min1.txt', header=None, low_memory=False)
InsoleStanding22 = pd.read_csv('0310JakaStand2Min.txt', header=None, low_memory=False)
SIDatasStanding1 =  np.array(InsoleStanding1)
SIDatasStanding2 =  np.array(InsoleStanding2)
SIDatasStanding3 =  np.array(InsoleStanding3)
SIDatasStanding4 =  np.array(InsoleStanding4)
SIDatasStanding5 =  np.array(InsoleStanding5)
SIDatasStanding6 =  np.array(InsoleStanding6)
SIDatasStanding7 =  np.array(InsoleStanding7)
SIDatasStanding8 =  np.array(InsoleStanding8)
SIDatasStanding9 =  np.array(InsoleStanding9)
SIDatasStanding10 =  np.array(InsoleStanding10)
SIDatasStanding11 =  np.array(InsoleStanding11)
SIDatasStanding12 =  np.array(InsoleStanding12)
SIDatasStanding13 =  np.array(InsoleStanding13)
SIDatasStanding14 =  np.array(InsoleStanding14)
SIDatasStanding15 =  np.array(InsoleStanding15)
SIDatasStanding16 =  np.array(InsoleStanding16)
SIDatasStanding17 =  np.array(InsoleStanding17)
SIDatasStanding18 =  np.array(InsoleStanding18)
SIDatasStanding19 =  np.array(InsoleStanding19)
SIDatasStanding20 =  np.array(InsoleStanding20)
SIDatasStanding21 =  np.array(InsoleStanding21)

dfStanding1 = pd.read_csv('0310AyuStand5Min1.csv', low_memory=False)
dfStanding2 = pd.read_csv('0310HudaStand5Min1.csv', low_memory=False)
dfStanding3 = pd.read_csv('0311LalaStand5Min1.csv', low_memory=False)
dfStanding4 = pd.read_csv('0311YunitaStand5Min1.csv', low_memory=False)
dfStanding5 = pd.read_csv('0312AbelStand5Min1.csv', low_memory=False)
dfStanding6 = pd.read_csv('0312AbiStand5Min1.csv', low_memory=False)
dfStanding7 = pd.read_csv('0312AryaStand5Min1.csv', low_memory=False)
dfStanding8 = pd.read_csv('0312HawaStand5Min1.csv', low_memory=False)
dfStanding9 = pd.read_csv('0312NisaStand5Min1.csv', low_memory=False)
dfStanding10 = pd.read_csv('0313ChenChengStand5Min1.csv', low_memory=False)
dfStanding11 = pd.read_csv('0313RezaStand5Min1.csv', low_memory=False)
dfStanding12 = pd.read_csv('0313RilaniStand5Min1.csv', low_memory=False)
dfStanding13 = pd.read_csv('0313SariStand5Min1.csv', low_memory=False)
dfStanding14 = pd.read_csv('0313ShelbyStand5Min1.csv', low_memory=False)
dfStanding15 = pd.read_csv('0314HelenStand5Min1.csv', low_memory=False)
dfStanding16 = pd.read_csv('0315AyuStand5Min1.csv', low_memory=False)
dfStanding17 = pd.read_csv('0315HappyStand5Min1.csv', low_memory=False)
dfStanding18 = pd.read_csv('0317HeniStand5Min1.csv', low_memory=False)
dfStanding19 = pd.read_csv('0317NadiaStand5Min1.csv', low_memory=False)
dfStanding20 = pd.read_csv('0317VikaStand5Min1.csv', low_memory=False)
dfStanding21 = pd.read_csv('0319AlfianStand5Min1.csv', low_memory=False)

selected_dfStandings1 = dfStanding1[columns]
selected_dfStandings2 = dfStanding2[columns]
selected_dfStandings3 = dfStanding3[columns]
selected_dfStandings4 = dfStanding4[columns]
selected_dfStandings5 = dfStanding5[columns]
selected_dfStandings6 = dfStanding6[columns]
selected_dfStandings7 = dfStanding7[columns]
selected_dfStandings8 = dfStanding8[columns]
selected_dfStandings9 = dfStanding9[columns]
selected_dfStandings10 = dfStanding10[columns]
selected_dfStandings11 = dfStanding11[columns]
selected_dfStandings12 = dfStanding12[columns]
selected_dfStandings13 = dfStanding13[columns]
selected_dfStandings14 = dfStanding14[columns]
selected_dfStandings15 = dfStanding15[columns]
selected_dfStandings16 = dfStanding16[columns]
selected_dfStandings17 = dfStanding17[columns]
selected_dfStandings18 = dfStanding18[columns]
selected_dfStandings19 = dfStanding19[columns]
selected_dfStandings20 = dfStanding20[columns]
selected_dfStandings21 = dfStanding21[columns]
FPDataStandings1 = selected_dfStandings1[:500]
FPDataStandings2 = selected_dfStandings2[:500]
FPDataStandings3 = selected_dfStandings3[:500]
FPDataStandings4 = selected_dfStandings4[:500]
FPDataStandings5 = selected_dfStandings5[:500]
FPDataStandings6 = selected_dfStandings6[:500]
FPDataStandings7 = selected_dfStandings7[:500]
FPDataStandings8 = selected_dfStandings8[:500]
FPDataStandings9 = selected_dfStandings9[:500]
FPDataStandings10 = selected_dfStandings10[:500]
FPDataStandings11 = selected_dfStandings11[:500]
FPDataStandings12 = selected_dfStandings12[:500]
FPDataStandings13 = selected_dfStandings13[:500]
FPDataStandings14 = selected_dfStandings14[:500]
FPDataStandings15 = selected_dfStandings15[:500]
FPDataStandings16 = selected_dfStandings16[:500]
FPDataStandings17 = selected_dfStandings17[:500]
FPDataStandings18 = selected_dfStandings18[:500]
FPDataStandings19 = selected_dfStandings19[:500]
FPDataStandings20 = selected_dfStandings20[:500]
FPDataStandings21 = selected_dfStandings21[:500]

SIDataStanding1 = np.array(SIDatasStanding1[:500]).astype('float64')
SIDataStanding2 = np.array(SIDatasStanding2[:500]).astype('float64')
SIDataStanding3 = np.array(SIDatasStanding3[:500]).astype('float64')
SIDataStanding4 = np.array(SIDatasStanding4[:500]).astype('float64')
SIDataStanding5 = np.array(SIDatasStanding5[:500]).astype('float64')
SIDataStanding6 = np.array(SIDatasStanding6[:500]).astype('float64')
SIDataStanding7 = np.array(SIDatasStanding7[:500]).astype('float64')
SIDataStanding8 = np.array(SIDatasStanding8[:500]).astype('float64')
SIDataStanding9 = np.array(SIDatasStanding9[:500]).astype('float64')
SIDataStanding10 = np.array(SIDatasStanding10[:500]).astype('float64')
SIDataStanding11 = np.array(SIDatasStanding11[:500]).astype('float64')
SIDataStanding12 = np.array(SIDatasStanding12[:500]).astype('float64')
SIDataStanding13 = np.array(SIDatasStanding13[:500]).astype('float64')
SIDataStanding14 = np.array(SIDatasStanding14[:500]).astype('float64')
SIDataStanding15 = np.array(SIDatasStanding15[:500]).astype('float64')
SIDataStanding16 = np.array(SIDatasStanding16[:500]).astype('float64')
SIDataStanding17 = np.array(SIDatasStanding17[:500]).astype('float64')
SIDataStanding18 = np.array(SIDatasStanding18[:500]).astype('float64')
SIDataStanding19 = np.array(SIDatasStanding19[:500]).astype('float64')
SIDataStanding20 = np.array(SIDatasStanding20[:500]).astype('float64')
SIDataStanding21 = np.array(SIDatasStanding21[:500]).astype('float64')
FPDataStanding1 = np.array(FPDataStandings1).astype('float64')
FPDataStanding2 = np.array(FPDataStandings2).astype('float64')
FPDataStanding3= np.array(FPDataStandings3).astype('float64')
FPDataStanding4= np.array(FPDataStandings4).astype('float64')
FPDataStanding5= np.array(FPDataStandings5).astype('float64')
FPDataStanding6= np.array(FPDataStandings6).astype('float64')
FPDataStanding7= np.array(FPDataStandings7).astype('float64')
FPDataStanding8= np.array(FPDataStandings8).astype('float64')
FPDataStanding9= np.array(FPDataStandings9).astype('float64')
FPDataStanding10 = np.array(FPDataStandings10).astype('float64')
FPDataStanding11 = np.array(FPDataStandings11).astype('float64')
FPDataStanding12= np.array(FPDataStandings12).astype('float64')
FPDataStanding13= np.array(FPDataStandings13).astype('float64')
FPDataStanding14= np.array(FPDataStandings14).astype('float64')
FPDataStanding15= np.array(FPDataStandings15).astype('float64')
FPDataStanding16= np.array(FPDataStandings16).astype('float64')
FPDataStanding17= np.array(FPDataStandings17).astype('float64')
FPDataStanding18= np.array(FPDataStandings18).astype('float64')
FPDataStanding19= np.array(FPDataStandings19).astype('float64')
FPDataStanding20= np.array(FPDataStandings20).astype('float64')
FPDataStanding21= np.array(FPDataStandings21).astype('float64')


# Combine the 21 datasets into one
data = np.concatenate((FPDataStanding1, FPDataStanding2, FPDataStanding3, FPDataStanding4, FPDataStanding5, FPDataStanding6, FPDataStanding7, FPDataStanding8,
                       FPDataStanding9, FPDataStanding10, FPDataStanding11, FPDataStanding12, FPDataStanding13, FPDataStanding14, FPDataStanding15,
                       FPDataStanding16, FPDataStanding17, FPDataStanding18, FPDataStanding19, FPDataStanding20, FPDataStanding21), axis=0)

# Reshape the data to be 1-D arrays
data_flat = [ts.flatten() for ts in data]

# Compute pairwise DTW distances between time series
distances = np.zeros((len(data_flat), len(data_flat)))
for i in range(len(data_flat)):
    for j in range(i + 1, len(data_flat)):
        dist = np.inf
        for shift in range(len(data_flat[i])):
            aligned_data = np.roll(data_flat[j], shift)
            curr_dist = np.sqrt(np.sum(np.square(data_flat[i] - aligned_data)))
            if curr_dist < dist:
                dist = curr_dist
        distances[i, j] = dist
        distances[j, i] = dist

# Perform K-means clustering with 2 clusters
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(distances)

# Get the cluster labels
labels = kmeans.labels_

# Group the data based on the cluster labels
group_1_indices = np.where(labels == 0)[0]
group_2_indices = np.where(labels == 1)[0]
group_3_indices = np.where(labels == 2)[0]

# Define the number of samples in each SIDataStanding dataset
num_samples = 10

# Assign labels to SIDataStanding groups based on FPDataStanding grouping
SIData_group_1 = np.concatenate((SIDataStanding1[labels[:num_samples] == 0], 
                                 SIDataStanding2[labels[num_samples:2*num_samples] == 0],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 0], 
                                 SIDataStanding4[labels[3*num_samples:4*num_samples] == 0], 
                                 SIDataStanding5[labels[4*num_samples:5*num_samples] == 0], 
                                 SIDataStanding6[labels[5*num_samples:6*num_samples] == 0], 
                                 SIDataStanding7[labels[6*num_samples:7*num_samples] == 0], 
                                 SIDataStanding8[labels[7*num_samples:8*num_samples] == 0], 
                                 SIDataStanding9[labels[8*num_samples:9*num_samples] == 0], 
                                 SIDataStanding10[labels[9*num_samples:10*num_samples] == 0], 
                                 SIDataStanding11[labels[10*num_samples:11*num_samples] == 0], 
                                 SIDataStanding12[labels[11*num_samples:12*num_samples] == 0], 
                                 SIDataStanding13[labels[12*num_samples:13*num_samples] == 0], 
                                 SIDataStanding14[labels[13*num_samples:14*num_samples] == 0], 
                                 SIDataStanding15[labels[14*num_samples:15*num_samples] == 0], 
                                 SIDataStanding16[labels[15*num_samples:16*num_samples] == 0], 
                                 SIDataStanding17[labels[16*num_samples:17*num_samples] == 0], 
                                 SIDataStanding18[labels[17*num_samples:18*num_samples] == 0], 
                                 SIDataStanding19[labels[18*num_samples:19*num_samples] == 0], 
                                 SIDataStanding20[labels[19*num_samples:20*num_samples] == 0], 
                                 SIDataStanding21[labels[20*num_samples:] == 0]), axis=0)

SIData_group_2 = np.concatenate((SIDataStanding1[labels[:num_samples] == 1], 
                                 SIDataStanding2[labels[num_samples:2*num_samples] == 1],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 1], 
                                 SIDataStanding4[labels[3*num_samples:4*num_samples] == 1], 
                                 SIDataStanding5[labels[4*num_samples:5*num_samples] == 1], 
                                 SIDataStanding6[labels[5*num_samples:6*num_samples] == 1], 
                                 SIDataStanding7[labels[6*num_samples:7*num_samples] == 1], 
                                 SIDataStanding8[labels[7*num_samples:8*num_samples] == 1], 
                                 SIDataStanding9[labels[8*num_samples:9*num_samples] == 1], 
                                 SIDataStanding10[labels[9*num_samples:10*num_samples] == 1], 
                                 SIDataStanding11[labels[10*num_samples:11*num_samples] == 1], 
                                 SIDataStanding12[labels[11*num_samples:12*num_samples] == 1], 
                                 SIDataStanding13[labels[12*num_samples:13*num_samples] == 1], 
                                 SIDataStanding14[labels[13*num_samples:14*num_samples] == 1], 
                                 SIDataStanding15[labels[14*num_samples:15*num_samples] == 1], 
                                 SIDataStanding16[labels[15*num_samples:16*num_samples] == 1], 
                                 SIDataStanding17[labels[16*num_samples:17*num_samples] == 1], 
                                 SIDataStanding18[labels[17*num_samples:18*num_samples] == 1], 
                                 SIDataStanding19[labels[18*num_samples:19*num_samples] == 1], 
                                 SIDataStanding20[labels[19*num_samples:20*num_samples] == 1], 
                                 SIDataStanding21[labels[20*num_samples:] == 1]), axis=0)

SIData_group_3 = np.concatenate((SIDataStanding1[labels[:num_samples] == 2], 
                                 SIDataStanding2[labels[num_samples:2*num_samples] == 2],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 2], 
                                 SIDataStanding4[labels[3*num_samples:4*num_samples] == 2], 
                                 SIDataStanding5[labels[4*num_samples:5*num_samples] == 2], 
                                 SIDataStanding6[labels[5*num_samples:6*num_samples] == 2], 
                                 SIDataStanding7[labels[6*num_samples:7*num_samples] == 2], 
                                 SIDataStanding8[labels[7*num_samples:8*num_samples] == 2], 
                                 SIDataStanding9[labels[8*num_samples:9*num_samples] == 2], 
                                 SIDataStanding10[labels[9*num_samples:10*num_samples] == 2], 
                                 SIDataStanding11[labels[10*num_samples:11*num_samples] == 2], 
                                 SIDataStanding12[labels[11*num_samples:12*num_samples] == 2], 
                                 SIDataStanding13[labels[12*num_samples:13*num_samples] == 2], 
                                 SIDataStanding14[labels[13*num_samples:14*num_samples] == 2], 
                                 SIDataStanding15[labels[14*num_samples:15*num_samples] == 2], 
                                 SIDataStanding16[labels[15*num_samples:16*num_samples] == 2], 
                                 SIDataStanding17[labels[16*num_samples:17*num_samples] == 2], 
                                 SIDataStanding18[labels[17*num_samples:18*num_samples] == 2], 
                                 SIDataStanding19[labels[18*num_samples:19*num_samples] == 2], 
                                 SIDataStanding20[labels[19*num_samples:20*num_samples] == 2], 
                                 SIDataStanding21[labels[20*num_samples:] == 2]), axis=0)


# Determine which original data each group belongs to
group_1_data = []
group_2_data = []
group_3_data = []
group_1_origins = []
group_2_origins = []
group_3_origins = []

for index in group_1_indices:
    if index < len(FPDataStanding1):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding1")
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding2")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding3")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding4")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding5")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding7")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding8")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding9")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding10")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding11")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding12")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding13")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding14")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding15")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding16")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding17")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding18")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding19")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding20")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding21")

for index in group_2_indices:
    if index < len(FPDataStanding1):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding1")
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding2")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding3")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding4")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding5")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding6")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding7")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding8")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding9")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding10")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding11")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding12")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding13")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding14")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding15")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding16")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding17")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) +len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding18")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding19")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding20")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding21")


for index in group_3_indices:
    if index < len(FPDataStanding1):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding1")
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding2")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding3")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding4")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding5")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding6")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding7")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding8")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding9")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding10")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding11")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding12")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding13")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding14")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding15")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding16")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding17")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) +len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding18")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding19")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding20")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding21")

# Print the grouped data
print("Group 1 (FPDataStanding):")
print(group_1_data)
print("Group 1 (SIDataStanding):")
print(SIData_group_1)
print("\n")
print("Group 2 (FPDataStanding):")
print(group_2_data)
print("Group 2 (SIDataStanding):")
print(SIData_group_2)
print("\n")
print("Group 3 (FPDataStanding):")
print(group_3_data)
print("Group 3 (SIDataStanding):")
print(SIData_group_3)



# # Print the grouped data
# print("Group 1:")
# print("Data:")
# for d in group_1_data:
#     print(d)
# print("Origins:")
# for origin in group_1_origins:
#     print(origin)

# print("Group 2:")
# print("Data:")
# for d in group_2_data:
#     print(d)
# print("Origins:")
# for origin in group_2_origins:
#     print(origin)

# print("Group 3:")
# print("Data:")
# for d in group_3_data:
#     print(d)
# print("Origins:")
# for origin in group_3_origins:
#     print(origin)

# %%
from scipy.spatial.distance import euclidean
from scipy.signal import correlate
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd

columns = ['Fx']

InsoleStanding1 = pd.read_csv('0310AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding2 = pd.read_csv('0310HudaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding3 = pd.read_csv('0311LalaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding4 = pd.read_csv('0311YunitaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding5 = pd.read_csv('0312AbelStand5Min1.txt', header=None, low_memory=False)
InsoleStanding6 = pd.read_csv('0312AbiStand5Min1.txt', header=None, low_memory=False)
InsoleStanding7 = pd.read_csv('0312AryaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding8 = pd.read_csv('0312HawaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding9 = pd.read_csv('0312NisaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding10 = pd.read_csv('0313ChenChengStand5Min1.txt', header=None, low_memory=False)
InsoleStanding11 = pd.read_csv('0313RezaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding12 = pd.read_csv('0313RilaniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding13 = pd.read_csv('0313SariStand5Min1.txt', header=None, low_memory=False)
InsoleStanding14 = pd.read_csv('0313ShelbyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding15 = pd.read_csv('0314HelenStand5Min1.txt', header=None, low_memory=False)
InsoleStanding16 = pd.read_csv('0315AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding17 = pd.read_csv('0315HappyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding18 = pd.read_csv('0317HeniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding19 = pd.read_csv('0317NadiaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding20 = pd.read_csv('0317VikaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding21 = pd.read_csv('0319AlfianStand5Min1.txt', header=None, low_memory=False)
InsoleStanding22 = pd.read_csv('0310JakaStand2Min.txt', header=None, low_memory=False)
SIDatasStanding1 =  np.array(InsoleStanding1)
SIDatasStanding2 =  np.array(InsoleStanding2)
SIDatasStanding3 =  np.array(InsoleStanding3)
SIDatasStanding4 =  np.array(InsoleStanding4)
SIDatasStanding5 =  np.array(InsoleStanding5)
SIDatasStanding6 =  np.array(InsoleStanding6)
SIDatasStanding7 =  np.array(InsoleStanding7)
SIDatasStanding8 =  np.array(InsoleStanding8)
SIDatasStanding9 =  np.array(InsoleStanding9)
SIDatasStanding10 =  np.array(InsoleStanding10)
SIDatasStanding11 =  np.array(InsoleStanding11)
SIDatasStanding12 =  np.array(InsoleStanding12)
SIDatasStanding13 =  np.array(InsoleStanding13)
SIDatasStanding14 =  np.array(InsoleStanding14)
SIDatasStanding15 =  np.array(InsoleStanding15)
SIDatasStanding16 =  np.array(InsoleStanding16)
SIDatasStanding17 =  np.array(InsoleStanding17)
SIDatasStanding18 =  np.array(InsoleStanding18)
SIDatasStanding19 =  np.array(InsoleStanding19)
SIDatasStanding20 =  np.array(InsoleStanding20)
SIDatasStanding21 =  np.array(InsoleStanding21)

dfStanding1 = pd.read_csv('0310AyuStand5Min1.csv', low_memory=False)
dfStanding2 = pd.read_csv('0310HudaStand5Min1.csv', low_memory=False)
dfStanding3 = pd.read_csv('0311LalaStand5Min1.csv', low_memory=False)
dfStanding4 = pd.read_csv('0311YunitaStand5Min1.csv', low_memory=False)
dfStanding5 = pd.read_csv('0312AbelStand5Min1.csv', low_memory=False)
dfStanding6 = pd.read_csv('0312AbiStand5Min1.csv', low_memory=False)
dfStanding7 = pd.read_csv('0312AryaStand5Min1.csv', low_memory=False)
dfStanding8 = pd.read_csv('0312HawaStand5Min1.csv', low_memory=False)
dfStanding9 = pd.read_csv('0312NisaStand5Min1.csv', low_memory=False)
dfStanding10 = pd.read_csv('0313ChenChengStand5Min1.csv', low_memory=False)
dfStanding11 = pd.read_csv('0313RezaStand5Min1.csv', low_memory=False)
dfStanding12 = pd.read_csv('0313RilaniStand5Min1.csv', low_memory=False)
dfStanding13 = pd.read_csv('0313SariStand5Min1.csv', low_memory=False)
dfStanding14 = pd.read_csv('0313ShelbyStand5Min1.csv', low_memory=False)
dfStanding15 = pd.read_csv('0314HelenStand5Min1.csv', low_memory=False)
dfStanding16 = pd.read_csv('0315AyuStand5Min1.csv', low_memory=False)
dfStanding17 = pd.read_csv('0315HappyStand5Min1.csv', low_memory=False)
dfStanding18 = pd.read_csv('0317HeniStand5Min1.csv', low_memory=False)
dfStanding19 = pd.read_csv('0317NadiaStand5Min1.csv', low_memory=False)
dfStanding20 = pd.read_csv('0317VikaStand5Min1.csv', low_memory=False)
dfStanding21 = pd.read_csv('0319AlfianStand5Min1.csv', low_memory=False)

selected_dfStandings1 = dfStanding1[columns]
selected_dfStandings2 = dfStanding2[columns]
selected_dfStandings3 = dfStanding3[columns]
selected_dfStandings4 = dfStanding4[columns]
selected_dfStandings5 = dfStanding5[columns]
selected_dfStandings6 = dfStanding6[columns]
selected_dfStandings7 = dfStanding7[columns]
selected_dfStandings8 = dfStanding8[columns]
selected_dfStandings9 = dfStanding9[columns]
selected_dfStandings10 = dfStanding10[columns]
selected_dfStandings11 = dfStanding11[columns]
selected_dfStandings12 = dfStanding12[columns]
selected_dfStandings13 = dfStanding13[columns]
selected_dfStandings14 = dfStanding14[columns]
selected_dfStandings15 = dfStanding15[columns]
selected_dfStandings16 = dfStanding16[columns]
selected_dfStandings17 = dfStanding17[columns]
selected_dfStandings18 = dfStanding18[columns]
selected_dfStandings19 = dfStanding19[columns]
selected_dfStandings20 = dfStanding20[columns]
selected_dfStandings21 = dfStanding21[columns]
FPDataStandings1 = selected_dfStandings1[:10]
FPDataStandings2 = selected_dfStandings2[:10]
FPDataStandings3 = selected_dfStandings3[:10]
FPDataStandings4 = selected_dfStandings4[:10]
FPDataStandings5 = selected_dfStandings5[:10]
FPDataStandings6 = selected_dfStandings6[:10]
FPDataStandings7 = selected_dfStandings7[:10]
FPDataStandings8 = selected_dfStandings8[:10]
FPDataStandings9 = selected_dfStandings9[:10]
FPDataStandings10 = selected_dfStandings10[:10]
FPDataStandings11 = selected_dfStandings11[:10]
FPDataStandings12 = selected_dfStandings12[:10]
FPDataStandings13 = selected_dfStandings13[:10]
FPDataStandings14 = selected_dfStandings14[:10]
FPDataStandings15 = selected_dfStandings15[:10]
FPDataStandings16 = selected_dfStandings16[:10]
FPDataStandings17 = selected_dfStandings17[:10]
FPDataStandings18 = selected_dfStandings18[:10]
FPDataStandings19 = selected_dfStandings19[:10]
FPDataStandings20 = selected_dfStandings20[:10]
FPDataStandings21 = selected_dfStandings21[:10]

SIDataStanding1 = np.array(SIDatasStanding1[:10]).astype('float64')
SIDataStanding2 = np.array(SIDatasStanding2[:10]).astype('float64')
SIDataStanding3 = np.array(SIDatasStanding3[:10]).astype('float64')
SIDataStanding4 = np.array(SIDatasStanding4[:10]).astype('float64')
SIDataStanding5 = np.array(SIDatasStanding5[:10]).astype('float64')
SIDataStanding6 = np.array(SIDatasStanding6[:10]).astype('float64')
SIDataStanding7 = np.array(SIDatasStanding7[:10]).astype('float64')
SIDataStanding8 = np.array(SIDatasStanding8[:10]).astype('float64')
SIDataStanding9 = np.array(SIDatasStanding9[:10]).astype('float64')
SIDataStanding10 = np.array(SIDatasStanding10[:10]).astype('float64')
SIDataStanding11 = np.array(SIDatasStanding11[:10]).astype('float64')
SIDataStanding12 = np.array(SIDatasStanding12[:10]).astype('float64')
SIDataStanding13 = np.array(SIDatasStanding13[:10]).astype('float64')
SIDataStanding14 = np.array(SIDatasStanding14[:10]).astype('float64')
SIDataStanding15 = np.array(SIDatasStanding15[:10]).astype('float64')
SIDataStanding16 = np.array(SIDatasStanding16[:10]).astype('float64')
SIDataStanding17 = np.array(SIDatasStanding17[:10]).astype('float64')
SIDataStanding18 = np.array(SIDatasStanding18[:10]).astype('float64')
SIDataStanding19 = np.array(SIDatasStanding19[:10]).astype('float64')
SIDataStanding20 = np.array(SIDatasStanding20[:10]).astype('float64')
SIDataStanding21 = np.array(SIDatasStanding21[:10]).astype('float64')
FPDataStanding1 = np.array(FPDataStandings1).astype('float64')
FPDataStanding2 = np.array(FPDataStandings2).astype('float64')
FPDataStanding3= np.array(FPDataStandings3).astype('float64')
FPDataStanding4= np.array(FPDataStandings4).astype('float64')
FPDataStanding5= np.array(FPDataStandings5).astype('float64')
FPDataStanding6= np.array(FPDataStandings6).astype('float64')
FPDataStanding7= np.array(FPDataStandings7).astype('float64')
FPDataStanding8= np.array(FPDataStandings8).astype('float64')
FPDataStanding9= np.array(FPDataStandings9).astype('float64')
FPDataStanding10 = np.array(FPDataStandings10).astype('float64')
FPDataStanding11 = np.array(FPDataStandings11).astype('float64')
FPDataStanding12= np.array(FPDataStandings12).astype('float64')
FPDataStanding13= np.array(FPDataStandings13).astype('float64')
FPDataStanding14= np.array(FPDataStandings14).astype('float64')
FPDataStanding15= np.array(FPDataStandings15).astype('float64')
FPDataStanding16= np.array(FPDataStandings16).astype('float64')
FPDataStanding17= np.array(FPDataStandings17).astype('float64')
FPDataStanding18= np.array(FPDataStandings18).astype('float64')
FPDataStanding19= np.array(FPDataStandings19).astype('float64')
FPDataStanding20= np.array(FPDataStandings20).astype('float64')
FPDataStanding21= np.array(FPDataStandings21).astype('float64')


# Combine the 21 datasets into one
data = np.concatenate((FPDataStanding1, FPDataStanding2, FPDataStanding3, FPDataStanding4, FPDataStanding5, FPDataStanding6, FPDataStanding7, FPDataStanding8,
                       FPDataStanding9, FPDataStanding10, FPDataStanding11, FPDataStanding12, FPDataStanding13, FPDataStanding14, FPDataStanding15,
                       FPDataStanding16, FPDataStanding17, FPDataStanding18, FPDataStanding19, FPDataStanding20, FPDataStanding21), axis=0)

# Reshape the data to be 1-D arrays
data_flat = [ts.flatten() for ts in data]

# Compute pairwise DTW distances between time series
distances = np.zeros((len(data_flat), len(data_flat)))
for i in range(len(data_flat)):
    for j in range(i + 1, len(data_flat)):
        dist = np.inf
        for shift in range(len(data_flat[i])):
            aligned_data = np.roll(data_flat[j], shift)
            curr_dist = np.sqrt(np.sum(np.square(data_flat[i] - aligned_data)))
            if curr_dist < dist:
                dist = curr_dist
        distances[i, j] = dist
        distances[j, i] = dist

# Perform K-means clustering with 2 clusters
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(distances)

# Get the cluster labels
labels = kmeans.labels_

# Group the data based on the cluster labels
group_1_indices = np.where(labels == 0)[0]
group_2_indices = np.where(labels == 1)[0]
group_3_indices = np.where(labels == 2)[0]

# Define the number of samples in each SIDataStanding dataset
num_samples = 10

# Assign labels to SIDataStanding groups based on FPDataStanding grouping
SIData_group_1 = np.concatenate((SIDataStanding1[labels[:num_samples] == 0], 
                                 SIDataStanding2[labels[num_samples:2*num_samples] == 0],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 0], 
                                 SIDataStanding4[labels[3*num_samples:4*num_samples] == 0], 
                                 SIDataStanding5[labels[4*num_samples:5*num_samples] == 0], 
                                 SIDataStanding6[labels[5*num_samples:6*num_samples] == 0], 
                                 SIDataStanding7[labels[6*num_samples:7*num_samples] == 0], 
                                 SIDataStanding8[labels[7*num_samples:8*num_samples] == 0], 
                                 SIDataStanding9[labels[8*num_samples:9*num_samples] == 0], 
                                 SIDataStanding10[labels[9*num_samples:10*num_samples] == 0], 
                                 SIDataStanding11[labels[10*num_samples:11*num_samples] == 0], 
                                 SIDataStanding12[labels[11*num_samples:12*num_samples] == 0], 
                                 SIDataStanding13[labels[12*num_samples:13*num_samples] == 0], 
                                 SIDataStanding14[labels[13*num_samples:14*num_samples] == 0], 
                                 SIDataStanding15[labels[14*num_samples:15*num_samples] == 0], 
                                 SIDataStanding16[labels[15*num_samples:16*num_samples] == 0], 
                                 SIDataStanding17[labels[16*num_samples:17*num_samples] == 0], 
                                 SIDataStanding18[labels[17*num_samples:18*num_samples] == 0], 
                                 SIDataStanding19[labels[18*num_samples:19*num_samples] == 0], 
                                 SIDataStanding20[labels[19*num_samples:20*num_samples] == 0], 
                                 SIDataStanding21[labels[20*num_samples:] == 0]), axis=0)

SIData_group_2 = np.concatenate((SIDataStanding1[labels[:num_samples] == 1], 
                                 SIDataStanding2[labels[num_samples:2*num_samples] == 1],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 1], 
                                 SIDataStanding4[labels[3*num_samples:4*num_samples] == 1], 
                                 SIDataStanding5[labels[4*num_samples:5*num_samples] == 1], 
                                 SIDataStanding6[labels[5*num_samples:6*num_samples] == 1], 
                                 SIDataStanding7[labels[6*num_samples:7*num_samples] == 1], 
                                 SIDataStanding8[labels[7*num_samples:8*num_samples] == 1], 
                                 SIDataStanding9[labels[8*num_samples:9*num_samples] == 1], 
                                 SIDataStanding10[labels[9*num_samples:10*num_samples] == 1], 
                                 SIDataStanding11[labels[10*num_samples:11*num_samples] == 1], 
                                 SIDataStanding12[labels[11*num_samples:12*num_samples] == 1], 
                                 SIDataStanding13[labels[12*num_samples:13*num_samples] == 1], 
                                 SIDataStanding14[labels[13*num_samples:14*num_samples] == 1], 
                                 SIDataStanding15[labels[14*num_samples:15*num_samples] == 1], 
                                 SIDataStanding16[labels[15*num_samples:16*num_samples] == 1], 
                                 SIDataStanding17[labels[16*num_samples:17*num_samples] == 1], 
                                 SIDataStanding18[labels[17*num_samples:18*num_samples] == 1], 
                                 SIDataStanding19[labels[18*num_samples:19*num_samples] == 1], 
                                 SIDataStanding20[labels[19*num_samples:20*num_samples] == 1], 
                                 SIDataStanding21[labels[20*num_samples:] == 1]), axis=0)

SIData_group_3 = np.concatenate((SIDataStanding1[labels[:num_samples] == 2], 
                                 SIDataStanding2[labels[num_samples:2*num_samples] == 2],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 2], 
                                 SIDataStanding4[labels[3*num_samples:4*num_samples] == 2], 
                                 SIDataStanding5[labels[4*num_samples:5*num_samples] == 2], 
                                 SIDataStanding6[labels[5*num_samples:6*num_samples] == 2], 
                                 SIDataStanding7[labels[6*num_samples:7*num_samples] == 2], 
                                 SIDataStanding8[labels[7*num_samples:8*num_samples] == 2], 
                                 SIDataStanding9[labels[8*num_samples:9*num_samples] == 2], 
                                 SIDataStanding10[labels[9*num_samples:10*num_samples] == 2], 
                                 SIDataStanding11[labels[10*num_samples:11*num_samples] == 2], 
                                 SIDataStanding12[labels[11*num_samples:12*num_samples] == 2], 
                                 SIDataStanding13[labels[12*num_samples:13*num_samples] == 2], 
                                 SIDataStanding14[labels[13*num_samples:14*num_samples] == 2], 
                                 SIDataStanding15[labels[14*num_samples:15*num_samples] == 2], 
                                 SIDataStanding16[labels[15*num_samples:16*num_samples] == 2], 
                                 SIDataStanding17[labels[16*num_samples:17*num_samples] == 2], 
                                 SIDataStanding18[labels[17*num_samples:18*num_samples] == 2], 
                                 SIDataStanding19[labels[18*num_samples:19*num_samples] == 2], 
                                 SIDataStanding20[labels[19*num_samples:20*num_samples] == 2], 
                                 SIDataStanding21[labels[20*num_samples:] == 2]), axis=0)


# Determine which original data each group belongs to
group_1_data = []
group_2_data = []
group_3_data = []
group_1_origins = []
group_2_origins = []
group_3_origins = []

for index in group_1_indices:
    if index < len(FPDataStanding1):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding1")
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding2")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding3")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding4")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding5")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding7")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding8")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding9")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding10")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding11")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding12")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding13")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding14")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding15")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding16")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding17")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding18")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding19")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding20")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding21")

for index in group_2_indices:
    if index < len(FPDataStanding1):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding1")
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding2")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding3")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding4")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding5")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding6")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding7")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding8")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding9")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding10")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding11")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding12")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding13")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding14")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding15")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding16")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding17")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) +len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding18")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding19")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding20")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding21")


for index in group_3_indices:
    if index < len(FPDataStanding1):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding1")
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding2")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding3")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding4")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding5")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding6")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding7")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding8")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding9")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding10")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding11")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding12")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding13")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding14")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding15")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding16")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding17")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) +len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding18")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding19")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding20")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding21")

# # Print the grouped data
# print("Group 1 (FPDataStanding):")
# print(group_1_data)
# print("Group 1 (SIDataStanding):")
# print(SIData_group_1)
# print("\n")
# print("Group 2 (FPDataStanding):")
# print(group_2_data)
# print("Group 2 (SIDataStanding):")
# print(SIData_group_2)
# print("\n")
# print("Group 3 (FPDataStanding):")
# print(group_3_data)
# print("Group 3 (SIDataStanding):")
# print(SIData_group_3)



# Print the grouped data
print("Group 1:")
print("Data:")
for d in group_1_data:
    print(d)
print("Origins:")
for origin in group_1_origins:
    print(origin)

print("Group 2:")
print("Data:")
for d in group_2_data:
    print(d)
print("Origins:")
for origin in group_2_origins:
    print(origin)

print("Group 3:")
print("Data:")
for d in group_3_data:
    print(d)
print("Origins:")
for origin in group_3_origins:
    print(origin)

# %%
group_3_data = np.array(group_3_data)
group_3_data

# %%
group_3_data = np.array(group_3_data)
group_3_data[80:81]

# %%
SIData_group_3 = np.array(SIData_group_3)
SIData_group_3[80:81]

# %%
FPDataStanding16[:1]

# %%
SIDataStanding16[:1]

# %%
from scipy.spatial.distance import euclidean
from scipy.signal import correlate
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd

columns = ['Fx']

InsoleStanding1 = pd.read_csv('0310AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding2 = pd.read_csv('0310HudaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding3 = pd.read_csv('0311LalaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding4 = pd.read_csv('0311YunitaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding5 = pd.read_csv('0312AbelStand5Min1.txt', header=None, low_memory=False)
InsoleStanding6 = pd.read_csv('0312AbiStand5Min1.txt', header=None, low_memory=False)
InsoleStanding7 = pd.read_csv('0312AryaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding8 = pd.read_csv('0312HawaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding9 = pd.read_csv('0312NisaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding10 = pd.read_csv('0313ChenChengStand5Min1.txt', header=None, low_memory=False)
InsoleStanding11 = pd.read_csv('0313RezaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding12 = pd.read_csv('0313RilaniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding13 = pd.read_csv('0313SariStand5Min1.txt', header=None, low_memory=False)
InsoleStanding14 = pd.read_csv('0313ShelbyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding15 = pd.read_csv('0314HelenStand5Min1.txt', header=None, low_memory=False)
InsoleStanding16 = pd.read_csv('0315AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding17 = pd.read_csv('0315HappyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding18 = pd.read_csv('0317HeniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding19 = pd.read_csv('0317NadiaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding20 = pd.read_csv('0317VikaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding21 = pd.read_csv('0319AlfianStand5Min1.txt', header=None, low_memory=False)
InsoleStanding22 = pd.read_csv('0310JakaStand2Min.txt', header=None, low_memory=False)
SIDatasStanding1 =  np.array(InsoleStanding1)
SIDatasStanding2 =  np.array(InsoleStanding2)
SIDatasStanding3 =  np.array(InsoleStanding3)
SIDatasStanding4 =  np.array(InsoleStanding4)
SIDatasStanding5 =  np.array(InsoleStanding5)
SIDatasStanding6 =  np.array(InsoleStanding6)
SIDatasStanding7 =  np.array(InsoleStanding7)
SIDatasStanding8 =  np.array(InsoleStanding8)
SIDatasStanding9 =  np.array(InsoleStanding9)
SIDatasStanding10 =  np.array(InsoleStanding10)
SIDatasStanding11 =  np.array(InsoleStanding11)
SIDatasStanding12 =  np.array(InsoleStanding12)
SIDatasStanding13 =  np.array(InsoleStanding13)
SIDatasStanding14 =  np.array(InsoleStanding14)
SIDatasStanding15 =  np.array(InsoleStanding15)
SIDatasStanding16 =  np.array(InsoleStanding16)
SIDatasStanding17 =  np.array(InsoleStanding17)
SIDatasStanding18 =  np.array(InsoleStanding18)
SIDatasStanding19 =  np.array(InsoleStanding19)
SIDatasStanding20 =  np.array(InsoleStanding20)
SIDatasStanding21 =  np.array(InsoleStanding21)

dfStanding1 = pd.read_csv('0310AyuStand5Min1.csv', low_memory=False)
dfStanding2 = pd.read_csv('0310HudaStand5Min1.csv', low_memory=False)
dfStanding3 = pd.read_csv('0311LalaStand5Min1.csv', low_memory=False)
dfStanding4 = pd.read_csv('0311YunitaStand5Min1.csv', low_memory=False)
dfStanding5 = pd.read_csv('0312AbelStand5Min1.csv', low_memory=False)
dfStanding6 = pd.read_csv('0312AbiStand5Min1.csv', low_memory=False)
dfStanding7 = pd.read_csv('0312AryaStand5Min1.csv', low_memory=False)
dfStanding8 = pd.read_csv('0312HawaStand5Min1.csv', low_memory=False)
dfStanding9 = pd.read_csv('0312NisaStand5Min1.csv', low_memory=False)
dfStanding10 = pd.read_csv('0313ChenChengStand5Min1.csv', low_memory=False)
dfStanding11 = pd.read_csv('0313RezaStand5Min1.csv', low_memory=False)
dfStanding12 = pd.read_csv('0313RilaniStand5Min1.csv', low_memory=False)
dfStanding13 = pd.read_csv('0313SariStand5Min1.csv', low_memory=False)
dfStanding14 = pd.read_csv('0313ShelbyStand5Min1.csv', low_memory=False)
dfStanding15 = pd.read_csv('0314HelenStand5Min1.csv', low_memory=False)
dfStanding16 = pd.read_csv('0315AyuStand5Min1.csv', low_memory=False)
dfStanding17 = pd.read_csv('0315HappyStand5Min1.csv', low_memory=False)
dfStanding18 = pd.read_csv('0317HeniStand5Min1.csv', low_memory=False)
dfStanding19 = pd.read_csv('0317NadiaStand5Min1.csv', low_memory=False)
dfStanding20 = pd.read_csv('0317VikaStand5Min1.csv', low_memory=False)
dfStanding21 = pd.read_csv('0319AlfianStand5Min1.csv', low_memory=False)

selected_dfStandings1 = dfStanding1[columns]
selected_dfStandings2 = dfStanding2[columns]
selected_dfStandings3 = dfStanding3[columns]
selected_dfStandings4 = dfStanding4[columns]
selected_dfStandings5 = dfStanding5[columns]
selected_dfStandings6 = dfStanding6[columns]
selected_dfStandings7 = dfStanding7[columns]
selected_dfStandings8 = dfStanding8[columns]
selected_dfStandings9 = dfStanding9[columns]
selected_dfStandings10 = dfStanding10[columns]
selected_dfStandings11 = dfStanding11[columns]
selected_dfStandings12 = dfStanding12[columns]
selected_dfStandings13 = dfStanding13[columns]
selected_dfStandings14 = dfStanding14[columns]
selected_dfStandings15 = dfStanding15[columns]
selected_dfStandings16 = dfStanding16[columns]
selected_dfStandings17 = dfStanding17[columns]
selected_dfStandings18 = dfStanding18[columns]
selected_dfStandings19 = dfStanding19[columns]
selected_dfStandings20 = dfStanding20[columns]
selected_dfStandings21 = dfStanding21[columns]
FPDataStandings1 = selected_dfStandings1[:1000]
FPDataStandings2 = selected_dfStandings2[:1000]
FPDataStandings3 = selected_dfStandings3[:1000]
FPDataStandings4 = selected_dfStandings4[:1000]
FPDataStandings5 = selected_dfStandings5[:1000]
FPDataStandings6 = selected_dfStandings6[:1000]
FPDataStandings7 = selected_dfStandings7[:1000]
FPDataStandings8 = selected_dfStandings8[:1000]
FPDataStandings9 = selected_dfStandings9[:1000]
FPDataStandings10 = selected_dfStandings10[:1000]
FPDataStandings11 = selected_dfStandings11[:1000]
FPDataStandings12 = selected_dfStandings12[:1000]
FPDataStandings13 = selected_dfStandings13[:1000]
FPDataStandings14 = selected_dfStandings14[:1000]
FPDataStandings15 = selected_dfStandings15[:1000]
FPDataStandings16 = selected_dfStandings16[:1000]
FPDataStandings17 = selected_dfStandings17[:1000]
FPDataStandings18 = selected_dfStandings18[:1000]
FPDataStandings19 = selected_dfStandings19[:1000]
FPDataStandings20 = selected_dfStandings20[:1000]
FPDataStandings21 = selected_dfStandings21[:1000]

SIDataStanding1 = np.array(SIDatasStanding1[:1000]).astype('float64')
SIDataStanding2 = np.array(SIDatasStanding2[:1000]).astype('float64')
SIDataStanding3 = np.array(SIDatasStanding3[:1000]).astype('float64')
SIDataStanding4 = np.array(SIDatasStanding4[:1000]).astype('float64')
SIDataStanding5 = np.array(SIDatasStanding5[:1000]).astype('float64')
SIDataStanding6 = np.array(SIDatasStanding6[:1000]).astype('float64')
SIDataStanding7 = np.array(SIDatasStanding7[:1000]).astype('float64')
SIDataStanding8 = np.array(SIDatasStanding8[:1000]).astype('float64')
SIDataStanding9 = np.array(SIDatasStanding9[:1000]).astype('float64')
SIDataStanding10 = np.array(SIDatasStanding10[:1000]).astype('float64')
SIDataStanding11 = np.array(SIDatasStanding11[:1000]).astype('float64')
SIDataStanding12 = np.array(SIDatasStanding12[:1000]).astype('float64')
SIDataStanding13 = np.array(SIDatasStanding13[:1000]).astype('float64')
SIDataStanding14 = np.array(SIDatasStanding14[:1000]).astype('float64')
SIDataStanding15 = np.array(SIDatasStanding15[:1000]).astype('float64')
SIDataStanding16 = np.array(SIDatasStanding16[:1000]).astype('float64')
SIDataStanding17 = np.array(SIDatasStanding17[:1000]).astype('float64')
SIDataStanding18 = np.array(SIDatasStanding18[:1000]).astype('float64')
SIDataStanding19 = np.array(SIDatasStanding19[:1000]).astype('float64')
SIDataStanding20 = np.array(SIDatasStanding20[:1000]).astype('float64')
SIDataStanding21 = np.array(SIDatasStanding21[:1000]).astype('float64')
FPDataStanding1 = np.array(FPDataStandings1).astype('float64')
FPDataStanding2 = np.array(FPDataStandings2).astype('float64')
FPDataStanding3= np.array(FPDataStandings3).astype('float64')
FPDataStanding4= np.array(FPDataStandings4).astype('float64')
FPDataStanding5= np.array(FPDataStandings5).astype('float64')
FPDataStanding6= np.array(FPDataStandings6).astype('float64')
FPDataStanding7= np.array(FPDataStandings7).astype('float64')
FPDataStanding8= np.array(FPDataStandings8).astype('float64')
FPDataStanding9= np.array(FPDataStandings9).astype('float64')
FPDataStanding10 = np.array(FPDataStandings10).astype('float64')
FPDataStanding11 = np.array(FPDataStandings11).astype('float64')
FPDataStanding12= np.array(FPDataStandings12).astype('float64')
FPDataStanding13= np.array(FPDataStandings13).astype('float64')
FPDataStanding14= np.array(FPDataStandings14).astype('float64')
FPDataStanding15= np.array(FPDataStandings15).astype('float64')
FPDataStanding16= np.array(FPDataStandings16).astype('float64')
FPDataStanding17= np.array(FPDataStandings17).astype('float64')
FPDataStanding18= np.array(FPDataStandings18).astype('float64')
FPDataStanding19= np.array(FPDataStandings19).astype('float64')
FPDataStanding20= np.array(FPDataStandings20).astype('float64')
FPDataStanding21= np.array(FPDataStandings21).astype('float64')


# Combine the 21 datasets into one
data = np.concatenate((FPDataStanding1, FPDataStanding2, FPDataStanding3, FPDataStanding4, FPDataStanding5, FPDataStanding6, FPDataStanding7, FPDataStanding8,
                       FPDataStanding9, FPDataStanding10, FPDataStanding11, FPDataStanding12, FPDataStanding13, FPDataStanding14, FPDataStanding15,
                       FPDataStanding16, FPDataStanding17, FPDataStanding18, FPDataStanding19, FPDataStanding20, FPDataStanding21), axis=0)

# Reshape the data to be 1-D arrays
data_flat = [ts.flatten() for ts in data]

# Compute pairwise DTW distances between time series
distances = np.zeros((len(data_flat), len(data_flat)))
for i in range(len(data_flat)):
    for j in range(i + 1, len(data_flat)):
        dist = np.inf
        for shift in range(len(data_flat[i])):
            aligned_data = np.roll(data_flat[j], shift)
            curr_dist = np.sqrt(np.sum(np.square(data_flat[i] - aligned_data)))
            if curr_dist < dist:
                dist = curr_dist
        distances[i, j] = dist
        distances[j, i] = dist

# Perform K-means clustering with 2 clusters
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(distances)

# Get the cluster labels
labels = kmeans.labels_

# Group the data based on the cluster labels
group_1_indices = np.where(labels == 0)[0]
group_2_indices = np.where(labels == 1)[0]
group_3_indices = np.where(labels == 2)[0]

# Define the number of samples in each SIDataStanding dataset
num_samples = 1000

# Assign labels to SIDataStanding groups based on FPDataStanding grouping
SIData_group_1 = np.concatenate((SIDataStanding1[labels[:num_samples] == 0], 
                                 SIDataStanding2[labels[num_samples:2*num_samples] == 0],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 0], 
                                 SIDataStanding4[labels[3*num_samples:4*num_samples] == 0], 
                                 SIDataStanding5[labels[4*num_samples:5*num_samples] == 0], 
                                 SIDataStanding6[labels[5*num_samples:6*num_samples] == 0], 
                                 SIDataStanding7[labels[6*num_samples:7*num_samples] == 0], 
                                 SIDataStanding8[labels[7*num_samples:8*num_samples] == 0], 
                                 SIDataStanding9[labels[8*num_samples:9*num_samples] == 0], 
                                 SIDataStanding10[labels[9*num_samples:10*num_samples] == 0], 
                                 SIDataStanding11[labels[10*num_samples:11*num_samples] == 0], 
                                 SIDataStanding12[labels[11*num_samples:12*num_samples] == 0], 
                                 SIDataStanding13[labels[12*num_samples:13*num_samples] == 0], 
                                 SIDataStanding14[labels[13*num_samples:14*num_samples] == 0], 
                                 SIDataStanding15[labels[14*num_samples:15*num_samples] == 0], 
                                 SIDataStanding16[labels[15*num_samples:16*num_samples] == 0], 
                                 SIDataStanding17[labels[16*num_samples:17*num_samples] == 0], 
                                 SIDataStanding18[labels[17*num_samples:18*num_samples] == 0], 
                                 SIDataStanding19[labels[18*num_samples:19*num_samples] == 0], 
                                 SIDataStanding20[labels[19*num_samples:20*num_samples] == 0], 
                                 SIDataStanding21[labels[20*num_samples:] == 0]), axis=0)

SIData_group_2 = np.concatenate((SIDataStanding1[labels[:num_samples] == 1], 
                                 SIDataStanding2[labels[num_samples:2*num_samples] == 1],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 1], 
                                 SIDataStanding4[labels[3*num_samples:4*num_samples] == 1], 
                                 SIDataStanding5[labels[4*num_samples:5*num_samples] == 1], 
                                 SIDataStanding6[labels[5*num_samples:6*num_samples] == 1], 
                                 SIDataStanding7[labels[6*num_samples:7*num_samples] == 1], 
                                 SIDataStanding8[labels[7*num_samples:8*num_samples] == 1], 
                                 SIDataStanding9[labels[8*num_samples:9*num_samples] == 1], 
                                 SIDataStanding10[labels[9*num_samples:10*num_samples] == 1], 
                                 SIDataStanding11[labels[10*num_samples:11*num_samples] == 1], 
                                 SIDataStanding12[labels[11*num_samples:12*num_samples] == 1], 
                                 SIDataStanding13[labels[12*num_samples:13*num_samples] == 1], 
                                 SIDataStanding14[labels[13*num_samples:14*num_samples] == 1], 
                                 SIDataStanding15[labels[14*num_samples:15*num_samples] == 1], 
                                 SIDataStanding16[labels[15*num_samples:16*num_samples] == 1], 
                                 SIDataStanding17[labels[16*num_samples:17*num_samples] == 1], 
                                 SIDataStanding18[labels[17*num_samples:18*num_samples] == 1], 
                                 SIDataStanding19[labels[18*num_samples:19*num_samples] == 1], 
                                 SIDataStanding20[labels[19*num_samples:20*num_samples] == 1], 
                                 SIDataStanding21[labels[20*num_samples:] == 1]), axis=0)

SIData_group_3 = np.concatenate((SIDataStanding1[labels[:num_samples] == 2], 
                                 SIDataStanding2[labels[num_samples:2*num_samples] == 2],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 2], 
                                 SIDataStanding4[labels[3*num_samples:4*num_samples] == 2], 
                                 SIDataStanding5[labels[4*num_samples:5*num_samples] == 2], 
                                 SIDataStanding6[labels[5*num_samples:6*num_samples] == 2], 
                                 SIDataStanding7[labels[6*num_samples:7*num_samples] == 2], 
                                 SIDataStanding8[labels[7*num_samples:8*num_samples] == 2], 
                                 SIDataStanding9[labels[8*num_samples:9*num_samples] == 2], 
                                 SIDataStanding10[labels[9*num_samples:10*num_samples] == 2], 
                                 SIDataStanding11[labels[10*num_samples:11*num_samples] == 2], 
                                 SIDataStanding12[labels[11*num_samples:12*num_samples] == 2], 
                                 SIDataStanding13[labels[12*num_samples:13*num_samples] == 2], 
                                 SIDataStanding14[labels[13*num_samples:14*num_samples] == 2], 
                                 SIDataStanding15[labels[14*num_samples:15*num_samples] == 2], 
                                 SIDataStanding16[labels[15*num_samples:16*num_samples] == 2], 
                                 SIDataStanding17[labels[16*num_samples:17*num_samples] == 2], 
                                 SIDataStanding18[labels[17*num_samples:18*num_samples] == 2], 
                                 SIDataStanding19[labels[18*num_samples:19*num_samples] == 2], 
                                 SIDataStanding20[labels[19*num_samples:20*num_samples] == 2], 
                                 SIDataStanding21[labels[20*num_samples:] == 2]), axis=0)


# Determine which original data each group belongs to
group_1_data = []
group_2_data = []
group_3_data = []
group_1_origins = []
group_2_origins = []
group_3_origins = []

for index in group_1_indices:
    if index < len(FPDataStanding1):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding1")
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding2")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding3")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding4")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding5")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding6")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding7")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding8")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding9")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding10")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding11")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding12")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding13")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding14")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding15")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding16")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding17")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding18")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding19")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding20")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_1_data.append(data[index])
        group_1_origins.append("FPDataStanding21")

for index in group_2_indices:
    if index < len(FPDataStanding1):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding1")
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding2")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding3")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding4")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding5")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding6")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding7")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding8")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding9")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding10")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding11")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding12")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding13")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding14")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding15")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding16")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding17")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) +len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding18")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding19")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding20")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_2_data.append(data[index])
        group_2_origins.append("FPDataStanding21")


for index in group_3_indices:
    if index < len(FPDataStanding1):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding1")
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding2")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding3")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding4")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding5")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding6")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding7")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding8")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding9")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding10")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding11")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding12")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding13")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding14")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding15")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding16")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding17")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) +len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding18")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding19")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding20")
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_3_data.append(data[index])
        group_3_origins.append("FPDataStanding21")

# # Print the grouped data
# print("Group 1 (FPDataStanding):")
# print(group_1_data)
# print("Group 1 (SIDataStanding):")
# print(SIData_group_1)
# print("\n")
# print("Group 2 (FPDataStanding):")
# print(group_2_data)
# print("Group 2 (SIDataStanding):")
# print(SIData_group_2)
# print("\n")
# print("Group 3 (FPDataStanding):")
# print(group_3_data)
# print("Group 3 (SIDataStanding):")
# print(SIData_group_3)



# Print the grouped data
print("Group 1:")
print("Data:")
for d in group_1_data:
    print(d)
print("Origins:")
for origin in group_1_origins:
    print(origin)

print("Group 2:")
print("Data:")
for d in group_2_data:
    print(d)
print("Origins:")
for origin in group_2_origins:
    print(origin)

print("Group 3:")
print("Data:")
for d in group_3_data:
    print(d)
print("Origins:")
for origin in group_3_origins:
    print(origin)

# %%
from scipy.spatial.distance import euclidean
from scipy.signal import correlate
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd

columns = ['Fx']

InsoleStanding1 = pd.read_csv('0310AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding2 = pd.read_csv('0310HudaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding3 = pd.read_csv('0311LalaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding4 = pd.read_csv('0311YunitaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding5 = pd.read_csv('0312AbelStand5Min1.txt', header=None, low_memory=False)
InsoleStanding6 = pd.read_csv('0312AbiStand5Min1.txt', header=None, low_memory=False)
InsoleStanding7 = pd.read_csv('0312AryaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding8 = pd.read_csv('0312HawaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding9 = pd.read_csv('0312NisaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding10 = pd.read_csv('0313ChenChengStand5Min1.txt', header=None, low_memory=False)
InsoleStanding11 = pd.read_csv('0313RezaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding12 = pd.read_csv('0313RilaniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding13 = pd.read_csv('0313SariStand5Min1.txt', header=None, low_memory=False)
InsoleStanding14 = pd.read_csv('0313ShelbyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding15 = pd.read_csv('0314HelenStand5Min1.txt', header=None, low_memory=False)
InsoleStanding16 = pd.read_csv('0315AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding17 = pd.read_csv('0315HappyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding18 = pd.read_csv('0317HeniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding19 = pd.read_csv('0317NadiaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding20 = pd.read_csv('0317VikaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding21 = pd.read_csv('0319AlfianStand5Min1.txt', header=None, low_memory=False)
InsoleStanding22 = pd.read_csv('0310JakaStand2Min.txt', header=None, low_memory=False)
SIDatasStanding1 =  np.array(InsoleStanding1)
SIDatasStanding2 =  np.array(InsoleStanding2)
SIDatasStanding3 =  np.array(InsoleStanding3)
SIDatasStanding4 =  np.array(InsoleStanding4)
SIDatasStanding5 =  np.array(InsoleStanding5)
SIDatasStanding6 =  np.array(InsoleStanding6)
SIDatasStanding7 =  np.array(InsoleStanding7)
SIDatasStanding8 =  np.array(InsoleStanding8)
SIDatasStanding9 =  np.array(InsoleStanding9)
SIDatasStanding10 =  np.array(InsoleStanding10)
SIDatasStanding11 =  np.array(InsoleStanding11)
SIDatasStanding12 =  np.array(InsoleStanding12)
SIDatasStanding13 =  np.array(InsoleStanding13)
SIDatasStanding14 =  np.array(InsoleStanding14)
SIDatasStanding15 =  np.array(InsoleStanding15)
SIDatasStanding16 =  np.array(InsoleStanding16)
SIDatasStanding17 =  np.array(InsoleStanding17)
SIDatasStanding18 =  np.array(InsoleStanding18)
SIDatasStanding19 =  np.array(InsoleStanding19)
SIDatasStanding20 =  np.array(InsoleStanding20)
SIDatasStanding21 =  np.array(InsoleStanding21)

dfStanding1 = pd.read_csv('0310AyuStand5Min1.csv', low_memory=False)
dfStanding2 = pd.read_csv('0310HudaStand5Min1.csv', low_memory=False)
dfStanding3 = pd.read_csv('0311LalaStand5Min1.csv', low_memory=False)
dfStanding4 = pd.read_csv('0311YunitaStand5Min1.csv', low_memory=False)
dfStanding5 = pd.read_csv('0312AbelStand5Min1.csv', low_memory=False)
dfStanding6 = pd.read_csv('0312AbiStand5Min1.csv', low_memory=False)
dfStanding7 = pd.read_csv('0312AryaStand5Min1.csv', low_memory=False)
dfStanding8 = pd.read_csv('0312HawaStand5Min1.csv', low_memory=False)
dfStanding9 = pd.read_csv('0312NisaStand5Min1.csv', low_memory=False)
dfStanding10 = pd.read_csv('0313ChenChengStand5Min1.csv', low_memory=False)
dfStanding11 = pd.read_csv('0313RezaStand5Min1.csv', low_memory=False)
dfStanding12 = pd.read_csv('0313RilaniStand5Min1.csv', low_memory=False)
dfStanding13 = pd.read_csv('0313SariStand5Min1.csv', low_memory=False)
dfStanding14 = pd.read_csv('0313ShelbyStand5Min1.csv', low_memory=False)
dfStanding15 = pd.read_csv('0314HelenStand5Min1.csv', low_memory=False)
dfStanding16 = pd.read_csv('0315AyuStand5Min1.csv', low_memory=False)
dfStanding17 = pd.read_csv('0315HappyStand5Min1.csv', low_memory=False)
dfStanding18 = pd.read_csv('0317HeniStand5Min1.csv', low_memory=False)
dfStanding19 = pd.read_csv('0317NadiaStand5Min1.csv', low_memory=False)
dfStanding20 = pd.read_csv('0317VikaStand5Min1.csv', low_memory=False)
dfStanding21 = pd.read_csv('0319AlfianStand5Min1.csv', low_memory=False)

selected_dfStandings1 = dfStanding1[columns]
selected_dfStandings2 = dfStanding2[columns]
selected_dfStandings3 = dfStanding3[columns]
selected_dfStandings4 = dfStanding4[columns]
selected_dfStandings5 = dfStanding5[columns]
selected_dfStandings6 = dfStanding6[columns]
selected_dfStandings7 = dfStanding7[columns]
selected_dfStandings8 = dfStanding8[columns]
selected_dfStandings9 = dfStanding9[columns]
selected_dfStandings10 = dfStanding10[columns]
selected_dfStandings11 = dfStanding11[columns]
selected_dfStandings12 = dfStanding12[columns]
selected_dfStandings13 = dfStanding13[columns]
selected_dfStandings14 = dfStanding14[columns]
selected_dfStandings15 = dfStanding15[columns]
selected_dfStandings16 = dfStanding16[columns]
selected_dfStandings17 = dfStanding17[columns]
selected_dfStandings18 = dfStanding18[columns]
selected_dfStandings19 = dfStanding19[columns]
selected_dfStandings20 = dfStanding20[columns]
selected_dfStandings21 = dfStanding21[columns]
FPDataStandings1 = selected_dfStandings1[:1000]
FPDataStandings2 = selected_dfStandings2[:1000]
FPDataStandings3 = selected_dfStandings3[:1000]
FPDataStandings4 = selected_dfStandings4[:1000]
FPDataStandings5 = selected_dfStandings5[:1000]
FPDataStandings6 = selected_dfStandings6[:1000]
FPDataStandings7 = selected_dfStandings7[:1000]
FPDataStandings8 = selected_dfStandings8[:1000]
FPDataStandings9 = selected_dfStandings9[:1000]
FPDataStandings10 = selected_dfStandings10[:1000]
FPDataStandings11 = selected_dfStandings11[:1000]
FPDataStandings12 = selected_dfStandings12[:1000]
FPDataStandings13 = selected_dfStandings13[:1000]
FPDataStandings14 = selected_dfStandings14[:1000]
FPDataStandings15 = selected_dfStandings15[:1000]
FPDataStandings16 = selected_dfStandings16[:1000]
FPDataStandings17 = selected_dfStandings17[:1000]
FPDataStandings18 = selected_dfStandings18[:1000]
FPDataStandings19 = selected_dfStandings19[:1000]
FPDataStandings20 = selected_dfStandings20[:1000]
FPDataStandings21 = selected_dfStandings21[:1000]

SIDataStanding1 = np.array(SIDatasStanding1[:1000]).astype('float64')
SIDataStanding2 = np.array(SIDatasStanding2[:1000]).astype('float64')
SIDataStanding3 = np.array(SIDatasStanding3[:1000]).astype('float64')
SIDataStanding4 = np.array(SIDatasStanding4[:1000]).astype('float64')
SIDataStanding5 = np.array(SIDatasStanding5[:1000]).astype('float64')
SIDataStanding6 = np.array(SIDatasStanding6[:1000]).astype('float64')
SIDataStanding7 = np.array(SIDatasStanding7[:1000]).astype('float64')
SIDataStanding8 = np.array(SIDatasStanding8[:1000]).astype('float64')
SIDataStanding9 = np.array(SIDatasStanding9[:1000]).astype('float64')
SIDataStanding10 = np.array(SIDatasStanding10[:1000]).astype('float64')
SIDataStanding11 = np.array(SIDatasStanding11[:1000]).astype('float64')
SIDataStanding12 = np.array(SIDatasStanding12[:1000]).astype('float64')
SIDataStanding13 = np.array(SIDatasStanding13[:1000]).astype('float64')
SIDataStanding14 = np.array(SIDatasStanding14[:1000]).astype('float64')
SIDataStanding15 = np.array(SIDatasStanding15[:1000]).astype('float64')
SIDataStanding16 = np.array(SIDatasStanding16[:1000]).astype('float64')
SIDataStanding17 = np.array(SIDatasStanding17[:1000]).astype('float64')
SIDataStanding18 = np.array(SIDatasStanding18[:1000]).astype('float64')
SIDataStanding19 = np.array(SIDatasStanding19[:1000]).astype('float64')
SIDataStanding20 = np.array(SIDatasStanding20[:1000]).astype('float64')
SIDataStanding21 = np.array(SIDatasStanding21[:1000]).astype('float64')
FPDataStanding1 = np.array(FPDataStandings1).astype('float64')
FPDataStanding2 = np.array(FPDataStandings2).astype('float64')
FPDataStanding3= np.array(FPDataStandings3).astype('float64')
FPDataStanding4= np.array(FPDataStandings4).astype('float64')
FPDataStanding5= np.array(FPDataStandings5).astype('float64')
FPDataStanding6= np.array(FPDataStandings6).astype('float64')
FPDataStanding7= np.array(FPDataStandings7).astype('float64')
FPDataStanding8= np.array(FPDataStandings8).astype('float64')
FPDataStanding9= np.array(FPDataStandings9).astype('float64')
FPDataStanding10 = np.array(FPDataStandings10).astype('float64')
FPDataStanding11 = np.array(FPDataStandings11).astype('float64')
FPDataStanding12= np.array(FPDataStandings12).astype('float64')
FPDataStanding13= np.array(FPDataStandings13).astype('float64')
FPDataStanding14= np.array(FPDataStandings14).astype('float64')
FPDataStanding15= np.array(FPDataStandings15).astype('float64')
FPDataStanding16= np.array(FPDataStandings16).astype('float64')
FPDataStanding17= np.array(FPDataStandings17).astype('float64')
FPDataStanding18= np.array(FPDataStandings18).astype('float64')
FPDataStanding19= np.array(FPDataStandings19).astype('float64')
FPDataStanding20= np.array(FPDataStandings20).astype('float64')
FPDataStanding21= np.array(FPDataStandings21).astype('float64')


# Combine the 21 datasets into one
data = np.concatenate((FPDataStanding1, FPDataStanding2, FPDataStanding3, FPDataStanding4, FPDataStanding5, FPDataStanding6, FPDataStanding7, FPDataStanding8,
                       FPDataStanding9, FPDataStanding10, FPDataStanding11, FPDataStanding12, FPDataStanding13, FPDataStanding14, FPDataStanding15,
                       FPDataStanding16, FPDataStanding17, FPDataStanding18, FPDataStanding19, FPDataStanding20, FPDataStanding21), axis=0)

# Reshape the data to be 1-D arrays
data_flat = [ts.flatten() for ts in data]

# Compute pairwise DTW distances between time series
# distances = np.zeros((len(data_flat), len(data_flat)))
# for i in range(len(data_flat)):
#     for j in range(i + 1, len(data_flat)):
#         dist = np.inf
#         for shift in range(len(data_flat[i])):
#             aligned_data = np.roll(data_flat[j], shift)
#             curr_dist = np.sqrt(np.sum(np.square(data_flat[i] - aligned_data)))
#             if curr_dist < dist:
#                 dist = curr_dist
#         distances[i, j] = dist
#         distances[j, i] = dist

# Compute pairwise Euclidean distances between time series
# distances = np.zeros((len(data), len(data)))
# for i in range(len(data)):
#     for j in range(i+1, len(data)):
#         dist = np.linalg.norm(data[i] - data[j])
#         distances[i, j] = dist
#         distances[j, i] = dist

# # Compute pairwise correlation coefficients between time series
distances = np.zeros((len(data), len(data)))
for i in range(len(data)):
    for j in range(i+1, len(data)):
        dist = np.corrcoef(data[i], data[j])[0, 1]
        distances[i, j] = dist
        distances[j, i] = dist
        
# # Compute pairwise DTW distances between time series
# distances = np.zeros((len(data), len(data)))
# for i in range(len(data)):
#     for j in range(i+1, len(data)):
#         _, dist = fastdtw(data[i], data[j])
#         distances[i, j] = dist
#         distances[j, i] = dist

# # Define the LCSS similarity function
# def lcss_similarity(ts1, ts2, epsilon, window):
#     m, n = len(ts1), len(ts2)
#     dp = np.zeros((m+1, n+1))

#     for i in range(1, m+1):
#         for j in range(1, n+1):
#             if abs(ts1[i-1] - ts2[j-1]) <= epsilon:
#                 dp[i][j] = dp[i-1][j-1] + 1
#             else:
#                 dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    
#     return dp[m][n] >= window

# # Compute pairwise LCSS distances between time series
# epsilon = 0.5  # Similarity threshold
# window = 6    # Minimum common subsequence length

# distances = np.zeros((len(data), len(data)))
# for i in range(len(data)):
#     for j in range(i+1, len(data)):
#         if lcss_similarity(data[i], data[j], epsilon, window):
#             dist = 0
#         else:
#             dist = np.inf
#         distances[i, j] = dist
#         distances[j, i] = dist

# Compute pairwise cross-correlation between time series
# distances = np.zeros((len(data), len(data)))
# for i in range(len(data)):
#     for j in range(i+1, len(data)):
#         dist = np.max(np.abs(correlate(data[i], data[j], mode='full')))
#         distances[i, j] = dist
#         distances[j, i] = dist



# Perform K-means clustering with 2 clusters
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(distances)

# Get the cluster labels
labels = kmeans.labels_

# Group the data based on the cluster labels
group_1_indices = np.where(labels == 0)[0]
group_2_indices = np.where(labels == 1)[0]
group_3_indices = np.where(labels == 2)[0]

# Define the number of samples in each SIDataStanding dataset
num_samples = 1000

# Assign labels to SIDataStanding groups based on FPDataStanding grouping
SIData_group_1 = np.concatenate((SIDataStanding1[labels[:num_samples] == 0], 
                                 SIDataStanding2[labels[num_samples:2*num_samples] == 0],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 0], 
                                 SIDataStanding4[labels[3*num_samples:4*num_samples] == 0], 
                                 SIDataStanding5[labels[4*num_samples:5*num_samples] == 0], 
                                 SIDataStanding6[labels[5*num_samples:6*num_samples] == 0], 
                                 SIDataStanding7[labels[6*num_samples:7*num_samples] == 0], 
                                 SIDataStanding8[labels[7*num_samples:8*num_samples] == 0], 
                                 SIDataStanding9[labels[8*num_samples:9*num_samples] == 0], 
                                 SIDataStanding10[labels[9*num_samples:10*num_samples] == 0], 
                                 SIDataStanding11[labels[10*num_samples:11*num_samples] == 0], 
                                 SIDataStanding12[labels[11*num_samples:12*num_samples] == 0], 
                                 SIDataStanding13[labels[12*num_samples:13*num_samples] == 0], 
                                 SIDataStanding14[labels[13*num_samples:14*num_samples] == 0], 
                                 SIDataStanding15[labels[14*num_samples:15*num_samples] == 0], 
                                 SIDataStanding16[labels[15*num_samples:16*num_samples] == 0], 
                                 SIDataStanding17[labels[16*num_samples:17*num_samples] == 0], 
                                 SIDataStanding18[labels[17*num_samples:18*num_samples] == 0], 
                                 SIDataStanding19[labels[18*num_samples:19*num_samples] == 0], 
                                 SIDataStanding20[labels[19*num_samples:20*num_samples] == 0], 
                                 SIDataStanding21[labels[20*num_samples:] == 0]), axis=0)

SIData_group_2 = np.concatenate((SIDataStanding1[labels[:num_samples] == 1], 
                                 SIDataStanding2[labels[num_samples:2*num_samples] == 1],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 1], 
                                 SIDataStanding4[labels[3*num_samples:4*num_samples] == 1], 
                                 SIDataStanding5[labels[4*num_samples:5*num_samples] == 1], 
                                 SIDataStanding6[labels[5*num_samples:6*num_samples] == 1], 
                                 SIDataStanding7[labels[6*num_samples:7*num_samples] == 1], 
                                 SIDataStanding8[labels[7*num_samples:8*num_samples] == 1], 
                                 SIDataStanding9[labels[8*num_samples:9*num_samples] == 1], 
                                 SIDataStanding10[labels[9*num_samples:10*num_samples] == 1], 
                                 SIDataStanding11[labels[10*num_samples:11*num_samples] == 1], 
                                 SIDataStanding12[labels[11*num_samples:12*num_samples] == 1], 
                                 SIDataStanding13[labels[12*num_samples:13*num_samples] == 1], 
                                 SIDataStanding14[labels[13*num_samples:14*num_samples] == 1], 
                                 SIDataStanding15[labels[14*num_samples:15*num_samples] == 1], 
                                 SIDataStanding16[labels[15*num_samples:16*num_samples] == 1], 
                                 SIDataStanding17[labels[16*num_samples:17*num_samples] == 1], 
                                 SIDataStanding18[labels[17*num_samples:18*num_samples] == 1], 
                                 SIDataStanding19[labels[18*num_samples:19*num_samples] == 1], 
                                 SIDataStanding20[labels[19*num_samples:20*num_samples] == 1], 
                                 SIDataStanding21[labels[20*num_samples:] == 1]), axis=0)

SIData_group_3 = np.concatenate((SIDataStanding1[labels[:num_samples] == 2], 
                                 SIDataStanding2[labels[num_samples:2*num_samples] == 2],
                                 SIDataStanding3[labels[2*num_samples:3*num_samples] == 2], 
                                 SIDataStanding4[labels[3*num_samples:4*num_samples] == 2], 
                                 SIDataStanding5[labels[4*num_samples:5*num_samples] == 2], 
                                 SIDataStanding6[labels[5*num_samples:6*num_samples] == 2], 
                                 SIDataStanding7[labels[6*num_samples:7*num_samples] == 2], 
                                 SIDataStanding8[labels[7*num_samples:8*num_samples] == 2], 
                                 SIDataStanding9[labels[8*num_samples:9*num_samples] == 2], 
                                 SIDataStanding10[labels[9*num_samples:10*num_samples] == 2], 
                                 SIDataStanding11[labels[10*num_samples:11*num_samples] == 2], 
                                 SIDataStanding12[labels[11*num_samples:12*num_samples] == 2], 
                                 SIDataStanding13[labels[12*num_samples:13*num_samples] == 2], 
                                 SIDataStanding14[labels[13*num_samples:14*num_samples] == 2], 
                                 SIDataStanding15[labels[14*num_samples:15*num_samples] == 2], 
                                 SIDataStanding16[labels[15*num_samples:16*num_samples] == 2], 
                                 SIDataStanding17[labels[16*num_samples:17*num_samples] == 2], 
                                 SIDataStanding18[labels[17*num_samples:18*num_samples] == 2], 
                                 SIDataStanding19[labels[18*num_samples:19*num_samples] == 2], 
                                 SIDataStanding20[labels[19*num_samples:20*num_samples] == 2], 
                                 SIDataStanding21[labels[20*num_samples:] == 2]), axis=0)


# Determine which original data each group belongs to
group_1_data = []
group_1_origins = []
group_1_origin_sizes = {}
group_2_data = []
group_2_origins = []
group_2_origin_sizes = {}
group_3_data = []
group_3_origins = []
group_3_origin_sizes = {}

for index in group_1_indices:
    if index < len(FPDataStanding1):
        group_1_data.append(data[index])
        origin = "FPDataStanding1"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_1_data.append(data[index])
        origin = "FPDataStanding2"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_1_data.append(data[index])
        origin = "FPDataStanding3"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_1_data.append(data[index])
        origin = "FPDataStanding4"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_1_data.append(data[index])
        origin = "FPDataStanding5"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6):
        group_1_data.append(data[index])
        origin = "FPDataStanding6"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_1_data.append(data[index])
        origin = "FPDataStanding7"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_1_data.append(data[index])
        origin = "FPDataStanding8"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_1_data.append(data[index])
        origin = "FPDataStanding9"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_1_data.append(data[index])
        origin = "FPDataStanding10"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_1_data.append(data[index])
        gorigin = "FPDataStanding11"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_1_data.append(data[index])
        origin = "FPDataStanding12"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_1_data.append(data[index])
        origin = "FPDataStanding13"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_1_data.append(data[index])
        origin = "FPDataStanding14"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_1_data.append(data[index])
        origin = "FPDataStanding15"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_1_data.append(data[index])
        origin = "FPDataStanding16"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_1_data.append(data[index])
        origin = "FPDataStanding17"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_1_data.append(data[index])
        origin = "FPDataStanding18"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_1_data.append(data[index])
        origin = "FPDataStanding19"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_1_data.append(data[index])
        origin = "FPDataStanding20"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_1_data.append(data[index])
        origin = "FPDataStanding21"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1

for index in group_2_indices:
    if index < len(FPDataStanding1):
        group_2_data.append(data[index])
        origin = "FPDataStanding1"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_2_data.append(data[index])
        origin = "FPDataStanding2"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_2_data.append(data[index])
        origin = "FPDataStanding3"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_2_data.append(data[index])
        origin = "FPDataStanding4"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_2_data.append(data[index])
        origin = "FPDataStanding5"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6):
        group_2_data.append(data[index])
        origin = "FPDataStanding6"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_2_data.append(data[index])
        origin = "FPDataStanding7"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_2_data.append(data[index])
        origin = "FPDataStanding8"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_2_data.append(data[index])
        origin = "FPDataStanding9"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_2_data.append(data[index])
        origin = "FPDataStanding10"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_2_data.append(data[index])
        origin = "FPDataStanding11"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_2_data.append(data[index])
        origin = "FPDataStanding12"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_2_data.append(data[index])
        origin = "FPDataStanding13"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_2_data.append(data[index])
        origin = "FPDataStanding14"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_2_data.append(data[index])
        origin = "FPDataStanding15"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_2_data.append(data[index])
        origin = "FPDataStanding16"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_2_data.append(data[index])
        origin = "FPDataStanding17"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) +len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_2_data.append(data[index])
        origin = "FPDataStanding18"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_2_data.append(data[index])
        origin = "FPDataStanding19"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_2_data.append(data[index])
        origin = "FPDataStanding20"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_2_data.append(data[index])
        origin = "FPDataStanding21"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1


for index in group_3_indices:
    if index < len(FPDataStanding1):
        group_3_data.append(data[index])
        gorigin = "FPDataStanding1"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2):
        group_3_data.append(data[index])
        origin = "FPDataStanding2"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3):
        group_3_data.append(data[index])
        origin = "FPDataStanding3"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4):
        group_3_data.append(data[index])
        origin = "FPDataStanding4"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5):
        group_3_data.append(data[index])
        origin = "FPDataStanding5"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6):
        group_3_data.append(data[index])
        origin = "FPDataStanding6"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7):
        group_3_data.append(data[index])
        origin = "FPDataStanding7"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8):
        group_3_data.append(data[index])
        origin = "FPDataStanding8"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9):
        group_3_data.append(data[index])
        origin = "FPDataStanding9"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10):
        group_3_data.append(data[index])
        origin = "FPDataStanding10"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11):
        group_3_data.append(data[index])
        origin = "FPDataStanding11"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12):
        group_3_data.append(data[index])
        origin = "FPDataStanding12"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13):
        group_3_data.append(data[index])
        origin = "FPDataStanding13"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14):
        group_3_data.append(data[index])
        origin = "FPDataStanding14"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15):
        group_3_data.append(data[index])
        origin = "FPDataStanding15"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16):
        group_3_data.append(data[index])
        origin = "FPDataStanding16"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17):
        group_3_data.append(data[index])
        gorigin = "FPDataStanding17"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) +len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18):
        group_3_data.append(data[index])
        origin = "FPDataStanding18"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19):
        group_3_data.append(data[index])
        origin = "FPDataStanding19"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20):
        group_3_data.append(data[index])
        origin = "FPDataStanding20"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1) + len(FPDataStanding2) + len(FPDataStanding3) + len(FPDataStanding4) + len(FPDataStanding5) + len(FPDataStanding6) + len(FPDataStanding7) + len(FPDataStanding8) + len(FPDataStanding9) + len(FPDataStanding10) + len(FPDataStanding11) + len(FPDataStanding12) + len(FPDataStanding13) + len(FPDataStanding14) + len(FPDataStanding15) + len(FPDataStanding16) + len(FPDataStanding17) + len(FPDataStanding18) + len(FPDataStanding19) + len(FPDataStanding20) + len(FPDataStanding21):
        group_3_data.append(data[index])
        origin = "FPDataStanding21"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1

# %%
# # Print the grouped data
# print("Group 1:")
# print("Data:")
# for d in group_1_data:
#     print(d)
# print("Origins:")
# for origin in group_1_origins:
#     print(origin)

# print("Group 2:")
# print("Data:")
# for d in group_2_data:
#     print(d)
# print("Origins:")
# for origin in group_2_origins:
#     print(origin)

# print("Group 3:")
# print("Data:")
# for d in group_3_data:
#     print(d)
# print("Origins:")
# for origin in group_3_origins:
#     print(origin)

# %%
print("Group 1 Origin Sizes:")
for origin, size in group_1_origin_sizes.items():
    print(f"{origin}: {size}")

print("Group 2 Origin Sizes:")
for origin, size in group_2_origin_sizes.items():
    print(f"{origin}: {size}")

print("Group 3 Origin Sizes:")
for origin, size in group_3_origin_sizes.items():
    print(f"{origin}: {size}")

# %%
print("Kelar")

# %%
group_1_data=np.array(group_1_data)
group_1_data.shape

# %%
SIData_group_1=np.array(SIData_group_1)
SIData_group_1.shape

# %%
group_2_data=np.array(group_2_data)
group_2_data.shape

# %%
SIData_group_2=np.array(SIData_group_2)
SIData_group_2.shape

# %%
group_3_data=np.array(group_3_data)
group_3_data.shape

# %%
SIData_group_3=np.array(SIData_group_3)
SIData_group_3.shape

# %%
SIDataset = SIData_group_1
FPDataset = group_1_data
print(SIDataset.shape)
print(FPDataset.shape)

# %%
SIDataset1 = SIDataset[:3092]
FPDataset1 = FPDataset[:3092]

SIDataset2 = SIDataset[3092:4092]
FPDataset2 = FPDataset[3092:4092]

SIDataset3 = SIDataset[4092:]
FPDataset3 = FPDataset[4092:]

SIDatasetNew = np.concatenate((SIDataset1,SIDataset3,SIDataset2), axis=0)
FPDatasetNew = np.concatenate((FPDataset1,FPDataset3,FPDataset2), axis=0)
print(SIDatasetNew.shape)
print(FPDatasetNew.shape)

# %%
import numpy as np
import pandas as pd
# import seaborn as sns
from numpy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Conv2D, MaxPooling2D, Reshape, Flatten, Dense
from keras.models import Model, model_from_json
from keras.optimizers import Adam, RMSprop
# from tensorflow.keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import Normalizer,MinMaxScaler,StandardScaler, RobustScaler, QuantileTransformer, PowerTransformer
# sns.set_theme(style="whitegrid")
import pywt
np.set_printoptions(suppress=True)
# Import ResNet1D Module
from ResNet_1DCNN import ResNet
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error, r2_score

wavelet = 'db4'
max_iter = 50
iter = 0

def seed_everything(seed=42):
    np.random.seed(seed)
    tf.random.set_seed(seed)


# SIDWTcoeffs = []
# for i in range(89):
#     coeffs = pywt.wavedec(SIDatasetNew[:, i], wavelet)
#     coeffs[-1] = np.zeros_like(coeffs[-1])
# #     coeffs[-2] = np.zeros_like(coeffs[-2])
# #     coeffs[-3] = np.zeros_like(coeffs[-3])
# #     coeffs[-4] = np.zeros_like(coeffs[-4])
# #     coeffs[-5] = np.zeros_like(coeffs[-5])
# #     coeffs[-6] = np.zeros_like(coeffs[-6])
#     SIDWTcoeffs.append(coeffs)

# SIData_filtered = np.zeros(SIDatasetNew.shape)
# for i in range(89):
#     SIData_filtered[:, i] = pywt.waverec(SIDWTcoeffs[i], wavelet, mode='symmetric', axis=0)

mean = 0
stddev = 0.1
noise = np.random.normal(mean, stddev, SIDatasetNew.shape)
SIDatasetNew += noise


max_iter = 50
iter = 0
for i in range(len(SIDatasetNew)):
    SIDatasetNew[i][0] = SIDatasetNew[i][0] + (iter % max_iter) + 1
    iter += 1

# Scale the smart insole data
minInsole = SIDatasetNew.min()
maxInsole = SIDatasetNew.max()
smart_insole_data_scaled = (SIDatasetNew - minInsole) / ( maxInsole - minInsole )

# Scale the force plate data
minForcePlate = FPDatasetNew.min()
maxForcePlate = FPDatasetNew.max()
force_plate_data_scaled = (FPDatasetNew - minForcePlate) / ( maxForcePlate - minForcePlate )


#Spliting Data
sample_size = smart_insole_data_scaled.shape[0] # number of samples in train set
time_steps  = smart_insole_data_scaled.shape[1] # number of features in train set
input_dimension = 1               # each feature is represented by 1 number

train_data_reshaped = smart_insole_data_scaled.reshape(sample_size,time_steps,input_dimension)

# X_train, X_test, y_train, y_test = train_test_split(train_data_reshaped[:13000],
#                                                     force_plate_data_scaled[:13000],
#                                                     test_size=0.20, random_state=2)

smart_insole_data_scaled_Train = train_data_reshaped[:8206]
smart_insole_data_scaled_Test = train_data_reshaped[8206:]
force_plate_data_scaled_Train = force_plate_data_scaled[:8206]
force_plate_data_scaled_Test = force_plate_data_scaled[8206:]

# Generate random indices for shuffling the data
indices = np.arange(smart_insole_data_scaled_Train.shape[0])
np.random.shuffle(indices)

seed_everything(42)
# Use the shuffled indices to randomly select training data
X_train = smart_insole_data_scaled_Train[indices]
y_train = force_plate_data_scaled_Train[indices]

Test_indices = np.arange(smart_insole_data_scaled_Test.shape[0])
np.random.shuffle(Test_indices)

seed_everything(42)
# # Assign the test data
X_test = smart_insole_data_scaled_Test[Test_indices]
y_test = force_plate_data_scaled_Test[Test_indices]

print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)

"Configurations for ResNet in Regression Mode"
length = X_train.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

Regression_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet18()
Regression_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

Regression_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('Saved_Model.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, shuffle=True)

plt.figure()
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
Regression_Model.evaluate(X_train, y_train)
ypred = Regression_Model.predict(X_train)

print('MSE: ',mean_squared_error(y_train, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_train, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_train, ypred))

# # Inverse transform the predictions and actual values
y_pred = (ypred * (maxForcePlate - minForcePlate)) + minForcePlate
y_real = (y_train * (maxForcePlate - minForcePlate)) + minForcePlate

# y_pred = y_pred[np.argsort(indices)]
# y_real = y_real[np.argsort(indices)]

print('MSE: ',mean_squared_error(y_real, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_real, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real, ypred))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real[0:3000,i],color='red')
    plt.plot(x,y_pred[0:3000,i], markerfacecolor='none',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(Regression_Model, '1ouput.h5')
#End Training Process

# Load Model to Predict Real Data
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(X_test, y_test)
Test_Pred = modelCoy.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred))

predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
Real = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions = predictions[np.argsort(Test_indices)]
Real = Real[np.argsort(Test_indices)]

x=[]
x = np.arange(0,1000)*10/1000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:1000,i],color='red')
    plt.plot(x,predictions[0:1000,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
9206+7806+3988

# %%
#Sownsmapling+grouping

# %%
from scipy.spatial.distance import euclidean
from scipy.signal import correlate
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd

columns = ['Fx']

InsoleStanding1 = pd.read_csv('0310AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding2 = pd.read_csv('0310HudaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding3 = pd.read_csv('0311LalaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding4 = pd.read_csv('0311YunitaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding5 = pd.read_csv('0312AbelStand5Min1.txt', header=None, low_memory=False)
InsoleStanding6 = pd.read_csv('0312AbiStand5Min1.txt', header=None, low_memory=False)
InsoleStanding7 = pd.read_csv('0312AryaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding8 = pd.read_csv('0312HawaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding9 = pd.read_csv('0312NisaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding10 = pd.read_csv('0313ChenChengStand5Min1.txt', header=None, low_memory=False)
InsoleStanding11 = pd.read_csv('0313RezaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding12 = pd.read_csv('0313RilaniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding13 = pd.read_csv('0313SariStand5Min1.txt', header=None, low_memory=False)
InsoleStanding14 = pd.read_csv('0313ShelbyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding15 = pd.read_csv('0314HelenStand5Min1.txt', header=None, low_memory=False)
InsoleStanding16 = pd.read_csv('0315AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding17 = pd.read_csv('0315HappyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding18 = pd.read_csv('0317HeniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding19 = pd.read_csv('0317NadiaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding20 = pd.read_csv('0317VikaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding21 = pd.read_csv('0319AlfianStand5Min1.txt', header=None, low_memory=False)
InsoleStanding22 = pd.read_csv('0310JakaStand2Min.txt', header=None, low_memory=False)
SIDatasStanding1 =  np.array(InsoleStanding1)
SIDatasStanding2 =  np.array(InsoleStanding2)
SIDatasStanding3 =  np.array(InsoleStanding3)
SIDatasStanding4 =  np.array(InsoleStanding4)
SIDatasStanding5 =  np.array(InsoleStanding5)
SIDatasStanding6 =  np.array(InsoleStanding6)
SIDatasStanding7 =  np.array(InsoleStanding7)
SIDatasStanding8 =  np.array(InsoleStanding8)
SIDatasStanding9 =  np.array(InsoleStanding9)
SIDatasStanding10 =  np.array(InsoleStanding10)
SIDatasStanding11 =  np.array(InsoleStanding11)
SIDatasStanding12 =  np.array(InsoleStanding12)
SIDatasStanding13 =  np.array(InsoleStanding13)
SIDatasStanding14 =  np.array(InsoleStanding14)
SIDatasStanding15 =  np.array(InsoleStanding15)
SIDatasStanding16 =  np.array(InsoleStanding16)
SIDatasStanding17 =  np.array(InsoleStanding17)
SIDatasStanding18 =  np.array(InsoleStanding18)
SIDatasStanding19 =  np.array(InsoleStanding19)
SIDatasStanding20 =  np.array(InsoleStanding20)
SIDatasStanding21 =  np.array(InsoleStanding21)

dfStanding1 = pd.read_csv('0310AyuStand5Min1.csv', low_memory=False)
dfStanding2 = pd.read_csv('0310HudaStand5Min1.csv', low_memory=False)
dfStanding3 = pd.read_csv('0311LalaStand5Min1.csv', low_memory=False)
dfStanding4 = pd.read_csv('0311YunitaStand5Min1.csv', low_memory=False)
dfStanding5 = pd.read_csv('0312AbelStand5Min1.csv', low_memory=False)
dfStanding6 = pd.read_csv('0312AbiStand5Min1.csv', low_memory=False)
dfStanding7 = pd.read_csv('0312AryaStand5Min1.csv', low_memory=False)
dfStanding8 = pd.read_csv('0312HawaStand5Min1.csv', low_memory=False)
dfStanding9 = pd.read_csv('0312NisaStand5Min1.csv', low_memory=False)
dfStanding10 = pd.read_csv('0313ChenChengStand5Min1.csv', low_memory=False)
dfStanding11 = pd.read_csv('0313RezaStand5Min1.csv', low_memory=False)
dfStanding12 = pd.read_csv('0313RilaniStand5Min1.csv', low_memory=False)
dfStanding13 = pd.read_csv('0313SariStand5Min1.csv', low_memory=False)
dfStanding14 = pd.read_csv('0313ShelbyStand5Min1.csv', low_memory=False)
dfStanding15 = pd.read_csv('0314HelenStand5Min1.csv', low_memory=False)
dfStanding16 = pd.read_csv('0315AyuStand5Min1.csv', low_memory=False)
dfStanding17 = pd.read_csv('0315HappyStand5Min1.csv', low_memory=False)
dfStanding18 = pd.read_csv('0317HeniStand5Min1.csv', low_memory=False)
dfStanding19 = pd.read_csv('0317NadiaStand5Min1.csv', low_memory=False)
dfStanding20 = pd.read_csv('0317VikaStand5Min1.csv', low_memory=False)
dfStanding21 = pd.read_csv('0319AlfianStand5Min1.csv', low_memory=False)

selected_dfStandings1 = dfStanding1[columns]
selected_dfStandings2 = dfStanding2[columns]
selected_dfStandings3 = dfStanding3[columns]
selected_dfStandings4 = dfStanding4[columns]
selected_dfStandings5 = dfStanding5[columns]
selected_dfStandings6 = dfStanding6[columns]
selected_dfStandings7 = dfStanding7[columns]
selected_dfStandings8 = dfStanding8[columns]
selected_dfStandings9 = dfStanding9[columns]
selected_dfStandings10 = dfStanding10[columns]
selected_dfStandings11 = dfStanding11[columns]
selected_dfStandings12 = dfStanding12[columns]
selected_dfStandings13 = dfStanding13[columns]
selected_dfStandings14 = dfStanding14[columns]
selected_dfStandings15 = dfStanding15[columns]
selected_dfStandings16 = dfStanding16[columns]
selected_dfStandings17 = dfStanding17[columns]
selected_dfStandings18 = dfStanding18[columns]
selected_dfStandings19 = dfStanding19[columns]
selected_dfStandings20 = dfStanding20[columns]
selected_dfStandings21 = dfStanding21[columns]
FPDataStandings1 = selected_dfStandings1[:15000]
FPDataStandings2 = selected_dfStandings2[:15000]
FPDataStandings3 = selected_dfStandings3[:15000]
FPDataStandings4 = selected_dfStandings4[:15000]
FPDataStandings5 = selected_dfStandings5[:15000]
FPDataStandings6 = selected_dfStandings6[:15000]
FPDataStandings7 = selected_dfStandings7[:15000]
FPDataStandings8 = selected_dfStandings8[:15000]
FPDataStandings9 = selected_dfStandings9[:15000]
FPDataStandings10 = selected_dfStandings10[:15000]
FPDataStandings11 = selected_dfStandings11[:15000]
FPDataStandings12 = selected_dfStandings12[:15000]
FPDataStandings13 = selected_dfStandings13[:15000]
FPDataStandings14 = selected_dfStandings14[:15000]
FPDataStandings15 = selected_dfStandings15[:15000]
FPDataStandings16 = selected_dfStandings16[:15000]
FPDataStandings17 = selected_dfStandings17[:15000]
FPDataStandings18 = selected_dfStandings18[:15000]
FPDataStandings19 = selected_dfStandings19[:15000]
FPDataStandings20 = selected_dfStandings20[:15000]
FPDataStandings21 = selected_dfStandings21[:15000]

SIDataStanding1 = np.array(SIDatasStanding1[:15000]).astype('float64')
SIDataStanding2 = np.array(SIDatasStanding2[:15000]).astype('float64')
SIDataStanding3 = np.array(SIDatasStanding3[:15000]).astype('float64')
SIDataStanding4 = np.array(SIDatasStanding4[:15000]).astype('float64')
SIDataStanding5 = np.array(SIDatasStanding5[:15000]).astype('float64')
SIDataStanding6 = np.array(SIDatasStanding6[:15000]).astype('float64')
SIDataStanding7 = np.array(SIDatasStanding7[:15000]).astype('float64')
SIDataStanding8 = np.array(SIDatasStanding8[:15000]).astype('float64')
SIDataStanding9 = np.array(SIDatasStanding9[:15000]).astype('float64')
SIDataStanding10 = np.array(SIDatasStanding10[:15000]).astype('float64')
SIDataStanding11 = np.array(SIDatasStanding11[:15000]).astype('float64')
SIDataStanding12 = np.array(SIDatasStanding12[:15000]).astype('float64')
SIDataStanding13 = np.array(SIDatasStanding13[:15000]).astype('float64')
SIDataStanding14 = np.array(SIDatasStanding14[:15000]).astype('float64')
SIDataStanding15 = np.array(SIDatasStanding15[:15000]).astype('float64')
SIDataStanding16 = np.array(SIDatasStanding16[:15000]).astype('float64')
SIDataStanding17 = np.array(SIDatasStanding17[:15000]).astype('float64')
SIDataStanding18 = np.array(SIDatasStanding18[:15000]).astype('float64')
SIDataStanding19 = np.array(SIDatasStanding19[:15000]).astype('float64')
SIDataStanding20 = np.array(SIDatasStanding20[:15000]).astype('float64')
SIDataStanding21 = np.array(SIDatasStanding21[:15000]).astype('float64')
FPDataStanding1 = np.array(FPDataStandings1).astype('float64')
FPDataStanding2 = np.array(FPDataStandings2).astype('float64')
FPDataStanding3= np.array(FPDataStandings3).astype('float64')
FPDataStanding4= np.array(FPDataStandings4).astype('float64')
FPDataStanding5= np.array(FPDataStandings5).astype('float64')
FPDataStanding6= np.array(FPDataStandings6).astype('float64')
FPDataStanding7= np.array(FPDataStandings7).astype('float64')
FPDataStanding8= np.array(FPDataStandings8).astype('float64')
FPDataStanding9= np.array(FPDataStandings9).astype('float64')
FPDataStanding10 = np.array(FPDataStandings10).astype('float64')
FPDataStanding11 = np.array(FPDataStandings11).astype('float64')
FPDataStanding12= np.array(FPDataStandings12).astype('float64')
FPDataStanding13= np.array(FPDataStandings13).astype('float64')
FPDataStanding14= np.array(FPDataStandings14).astype('float64')
FPDataStanding15= np.array(FPDataStandings15).astype('float64')
FPDataStanding16= np.array(FPDataStandings16).astype('float64')
FPDataStanding17= np.array(FPDataStandings17).astype('float64')
FPDataStanding18= np.array(FPDataStandings18).astype('float64')
FPDataStanding19= np.array(FPDataStandings19).astype('float64')
FPDataStanding20= np.array(FPDataStandings20).astype('float64')
FPDataStanding21= np.array(FPDataStandings21).astype('float64')

FPDataStanding1 = FPDataStanding1.reshape(1500,10,1)
FPDataStanding2 = FPDataStanding2.reshape(1500,10,1)
FPDataStanding3 = FPDataStanding3.reshape(1500,10,1)
FPDataStanding4 = FPDataStanding4.reshape(1500,10,1)
FPDataStanding5 = FPDataStanding5.reshape(1500,10,1)
FPDataStanding6 = FPDataStanding6.reshape(1500,10,1)
FPDataStanding7 = FPDataStanding7.reshape(1500,10,1)
FPDataStanding8 = FPDataStanding8.reshape(1500,10,1)
FPDataStanding9 = FPDataStanding9.reshape(1500,10,1)
FPDataStanding10 = FPDataStanding10.reshape(1500,10,1)
FPDataStanding11 = FPDataStanding11.reshape(1500,10,1)
FPDataStanding12 = FPDataStanding12.reshape(1500,10,1)
FPDataStanding13 = FPDataStanding13.reshape(1500,10,1)
FPDataStanding14 = FPDataStanding14.reshape(1500,10,1)
FPDataStanding15 = FPDataStanding15.reshape(1500,10,1)
FPDataStanding16 = FPDataStanding16.reshape(1500,10,1)
FPDataStanding17 = FPDataStanding17.reshape(1500,10,1)
FPDataStanding18 = FPDataStanding18.reshape(1500,10,1)
FPDataStanding19 = FPDataStanding19.reshape(1500,10,1)
FPDataStanding20 = FPDataStanding20.reshape(1500,10,1)
FPDataStanding21 = FPDataStanding21.reshape(1500,10,1)

FPDataStanding1Avg = np.average(FPDataStanding1, axis=1)
FPDataStanding2Avg = np.average(FPDataStanding2, axis=1)
FPDataStanding3Avg = np.average(FPDataStanding3, axis=1)
FPDataStanding4Avg = np.average(FPDataStanding4, axis=1)
FPDataStanding5Avg = np.average(FPDataStanding5, axis=1)
FPDataStanding6Avg = np.average(FPDataStanding6, axis=1)
FPDataStanding7Avg = np.average(FPDataStanding7, axis=1)
FPDataStanding8Avg = np.average(FPDataStanding8, axis=1)
FPDataStanding9Avg = np.average(FPDataStanding9, axis=1)
FPDataStanding10Avg = np.average(FPDataStanding10, axis=1)
FPDataStanding11Avg = np.average(FPDataStanding11, axis=1)
FPDataStanding12Avg = np.average(FPDataStanding12, axis=1)
FPDataStanding13Avg = np.average(FPDataStanding13, axis=1)
FPDataStanding14Avg = np.average(FPDataStanding14, axis=1)
FPDataStanding15Avg = np.average(FPDataStanding15, axis=1)
FPDataStanding16Avg = np.average(FPDataStanding16, axis=1)
FPDataStanding17Avg = np.average(FPDataStanding17, axis=1)
FPDataStanding18Avg = np.average(FPDataStanding18, axis=1)
FPDataStanding19Avg = np.average(FPDataStanding19, axis=1)
FPDataStanding20Avg = np.average(FPDataStanding20, axis=1)
FPDataStanding21Avg = np.average(FPDataStanding21, axis=1)

downsampled_SIDataStanding1 = SIDataStanding1[::10]
downsampled_SIDataStanding2 = SIDataStanding2[::10]
downsampled_SIDataStanding3 = SIDataStanding3[::10]
downsampled_SIDataStanding4 = SIDataStanding4[::10]
downsampled_SIDataStanding5 = SIDataStanding5[::10]
downsampled_SIDataStanding6 = SIDataStanding6[::10]
downsampled_SIDataStanding7 = SIDataStanding7[::10]
downsampled_SIDataStanding8 = SIDataStanding8[::10]
downsampled_SIDataStanding9 = SIDataStanding9[::10]
downsampled_SIDataStanding10 = SIDataStanding10[::10]
downsampled_SIDataStanding11 = SIDataStanding11[::10]
downsampled_SIDataStanding12 = SIDataStanding12[::10]
downsampled_SIDataStanding13 = SIDataStanding13[::10]
downsampled_SIDataStanding14 = SIDataStanding14[::10]
downsampled_SIDataStanding15 = SIDataStanding15[::10]
downsampled_SIDataStanding16 = SIDataStanding16[::10]
downsampled_SIDataStanding17 = SIDataStanding17[::10]
downsampled_SIDataStanding18 = SIDataStanding18[::10]
downsampled_SIDataStanding19 = SIDataStanding19[::10]
downsampled_SIDataStanding20 = SIDataStanding20[::10]
downsampled_SIDataStanding21 = SIDataStanding21[::10]


# Combine the 21 datasets into one
data = np.concatenate((FPDataStanding1Avg, FPDataStanding2Avg, FPDataStanding3Avg, FPDataStanding4Avg, FPDataStanding5Avg, FPDataStanding6Avg, FPDataStanding7Avg, 
                       FPDataStanding8Avg, FPDataStanding9Avg, FPDataStanding10Avg, FPDataStanding11Avg, FPDataStanding12Avg, FPDataStanding13Avg, FPDataStanding14Avg, 
                       FPDataStanding15Avg, FPDataStanding16Avg, FPDataStanding17Avg, FPDataStanding18Avg, FPDataStanding19Avg, FPDataStanding20Avg, FPDataStanding21Avg), axis=0)

# Reshape the data to be 1-D arrays
data_flat = [ts.flatten() for ts in data]

# Compute pairwise DTW distances between time series
distances = np.zeros((len(data_flat), len(data_flat)))
for i in range(len(data_flat)):
    for j in range(i + 1, len(data_flat)):
        dist = np.inf
        for shift in range(len(data_flat[i])):
            aligned_data = np.roll(data_flat[j], shift)
            curr_dist = np.sqrt(np.sum(np.square(data_flat[i] - aligned_data)))
            if curr_dist < dist:
                dist = curr_dist
        distances[i, j] = dist
        distances[j, i] = dist

# Compute pairwise Euclidean distances between time series
# distances = np.zeros((len(data), len(data)))
# for i in range(len(data)):
#     for j in range(i+1, len(data)):
#         dist = np.linalg.norm(data[i] - data[j])
#         distances[i, j] = dist
#         distances[j, i] = dist

# # Compute pairwise correlation coefficients between time series
# distances = np.zeros((len(data), len(data)))
# for i in range(len(data)):
#     for j in range(i+1, len(data)):
#         dist = np.corrcoef(data[i], data[j])[0, 1]
#         distances[i, j] = dist
#         distances[j, i] = dist
        
# # Compute pairwise DTW distances between time series
# distances = np.zeros((len(data), len(data)))
# for i in range(len(data)):
#     for j in range(i+1, len(data)):
#         _, dist = fastdtw(data[i], data[j])
#         distances[i, j] = dist
#         distances[j, i] = dist

# # Define the LCSS similarity function
# def lcss_similarity(ts1, ts2, epsilon, window):
#     m, n = len(ts1), len(ts2)
#     dp = np.zeros((m+1, n+1))

#     for i in range(1, m+1):
#         for j in range(1, n+1):
#             if abs(ts1[i-1] - ts2[j-1]) <= epsilon:
#                 dp[i][j] = dp[i-1][j-1] + 1
#             else:
#                 dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    
#     return dp[m][n] >= window

# # Compute pairwise LCSS distances between time series
# epsilon = 0.5  # Similarity threshold
# window = 6    # Minimum common subsequence length

# distances = np.zeros((len(data), len(data)))
# for i in range(len(data)):
#     for j in range(i+1, len(data)):
#         if lcss_similarity(data[i], data[j], epsilon, window):
#             dist = 0
#         else:
#             dist = np.inf
#         distances[i, j] = dist
#         distances[j, i] = dist

# Compute pairwise cross-correlation between time series
# distances = np.zeros((len(data), len(data)))
# for i in range(len(data)):
#     for j in range(i+1, len(data)):
#         dist = np.max(np.abs(correlate(data[i], data[j], mode='full')))
#         distances[i, j] = dist
#         distances[j, i] = dist



# Perform K-means clustering with 2 clusters
# kmeans = KMeans(n_clusters=3)
# kmeans.fit(distances)

# Define the model
agg_clustering = AgglomerativeClustering(n_clusters=3)
# Fit and predict 
agg_clustering.fit_predict(distances)

# Get the cluster labels
labels = agg_clustering.labels_

# Group the data based on the cluster labels
group_1_indices = np.where(labels == 0)[0]
group_2_indices = np.where(labels == 1)[0]
group_3_indices = np.where(labels == 2)[0]

# Define the number of samples in each SIDataStanding dataset
num_samples = 1500

# Assign labels to SIDataStanding groups based on FPDataStanding grouping
SIData_group_1 = np.concatenate((downsampled_SIDataStanding1[labels[:num_samples] == 0], 
                                 downsampled_SIDataStanding2[labels[num_samples:2*num_samples] == 0],
                                 downsampled_SIDataStanding3[labels[2*num_samples:3*num_samples] == 0], 
                                 downsampled_SIDataStanding4[labels[3*num_samples:4*num_samples] == 0], 
                                 downsampled_SIDataStanding5[labels[4*num_samples:5*num_samples] == 0], 
                                 downsampled_SIDataStanding6[labels[5*num_samples:6*num_samples] == 0], 
                                 downsampled_SIDataStanding7[labels[6*num_samples:7*num_samples] == 0], 
                                 downsampled_SIDataStanding8[labels[7*num_samples:8*num_samples] == 0], 
                                 downsampled_SIDataStanding9[labels[8*num_samples:9*num_samples] == 0], 
                                 downsampled_SIDataStanding10[labels[9*num_samples:10*num_samples] == 0], 
                                 downsampled_SIDataStanding11[labels[10*num_samples:11*num_samples] == 0], 
                                 downsampled_SIDataStanding12[labels[11*num_samples:12*num_samples] == 0], 
                                 downsampled_SIDataStanding13[labels[12*num_samples:13*num_samples] == 0], 
                                 downsampled_SIDataStanding14[labels[13*num_samples:14*num_samples] == 0], 
                                 downsampled_SIDataStanding15[labels[14*num_samples:15*num_samples] == 0], 
                                 downsampled_SIDataStanding16[labels[15*num_samples:16*num_samples] == 0], 
                                 downsampled_SIDataStanding17[labels[16*num_samples:17*num_samples] == 0], 
                                 downsampled_SIDataStanding18[labels[17*num_samples:18*num_samples] == 0], 
                                 downsampled_SIDataStanding19[labels[18*num_samples:19*num_samples] == 0], 
                                 downsampled_SIDataStanding20[labels[19*num_samples:20*num_samples] == 0], 
                                 downsampled_SIDataStanding21[labels[20*num_samples:] == 0]), axis=0)

SIData_group_2 = np.concatenate((downsampled_SIDataStanding1[labels[:num_samples] == 1], 
                                 downsampled_SIDataStanding2[labels[num_samples:2*num_samples] == 1],
                                 downsampled_SIDataStanding3[labels[2*num_samples:3*num_samples] == 1], 
                                 downsampled_SIDataStanding4[labels[3*num_samples:4*num_samples] == 1], 
                                 downsampled_SIDataStanding5[labels[4*num_samples:5*num_samples] == 1], 
                                 downsampled_SIDataStanding6[labels[5*num_samples:6*num_samples] == 1], 
                                 downsampled_SIDataStanding7[labels[6*num_samples:7*num_samples] == 1], 
                                 downsampled_SIDataStanding8[labels[7*num_samples:8*num_samples] == 1], 
                                 downsampled_SIDataStanding9[labels[8*num_samples:9*num_samples] == 1], 
                                 downsampled_SIDataStanding10[labels[9*num_samples:10*num_samples] == 1], 
                                 downsampled_SIDataStanding11[labels[10*num_samples:11*num_samples] == 1], 
                                 downsampled_SIDataStanding12[labels[11*num_samples:12*num_samples] == 1], 
                                 downsampled_SIDataStanding13[labels[12*num_samples:13*num_samples] == 1], 
                                 downsampled_SIDataStanding14[labels[13*num_samples:14*num_samples] == 1], 
                                 downsampled_SIDataStanding15[labels[14*num_samples:15*num_samples] == 1], 
                                 downsampled_SIDataStanding16[labels[15*num_samples:16*num_samples] == 1], 
                                 downsampled_SIDataStanding17[labels[16*num_samples:17*num_samples] == 1], 
                                 downsampled_SIDataStanding18[labels[17*num_samples:18*num_samples] == 1], 
                                 downsampled_SIDataStanding19[labels[18*num_samples:19*num_samples] == 1], 
                                 downsampled_SIDataStanding20[labels[19*num_samples:20*num_samples] == 1], 
                                 downsampled_SIDataStanding21[labels[20*num_samples:] == 1]), axis=0)


SIData_group_3 = np.concatenate((downsampled_SIDataStanding1[labels[:num_samples] == 2], 
                                 downsampled_SIDataStanding2[labels[num_samples:2*num_samples] == 2],
                                 downsampled_SIDataStanding3[labels[2*num_samples:3*num_samples] == 2], 
                                 downsampled_SIDataStanding4[labels[3*num_samples:4*num_samples] == 2], 
                                 downsampled_SIDataStanding5[labels[4*num_samples:5*num_samples] == 2], 
                                 downsampled_SIDataStanding6[labels[5*num_samples:6*num_samples] == 2], 
                                 downsampled_SIDataStanding7[labels[6*num_samples:7*num_samples] == 2], 
                                 downsampled_SIDataStanding8[labels[7*num_samples:8*num_samples] == 2], 
                                 downsampled_SIDataStanding9[labels[8*num_samples:9*num_samples] == 2], 
                                 downsampled_SIDataStanding10[labels[9*num_samples:10*num_samples] == 2], 
                                 downsampled_SIDataStanding11[labels[10*num_samples:11*num_samples] == 2], 
                                 downsampled_SIDataStanding12[labels[11*num_samples:12*num_samples] == 2], 
                                 downsampled_SIDataStanding13[labels[12*num_samples:13*num_samples] == 2], 
                                 downsampled_SIDataStanding14[labels[13*num_samples:14*num_samples] == 2], 
                                 downsampled_SIDataStanding15[labels[14*num_samples:15*num_samples] == 2], 
                                 downsampled_SIDataStanding16[labels[15*num_samples:16*num_samples] == 2], 
                                 downsampled_SIDataStanding17[labels[16*num_samples:17*num_samples] == 2], 
                                 downsampled_SIDataStanding18[labels[17*num_samples:18*num_samples] == 2], 
                                 downsampled_SIDataStanding19[labels[18*num_samples:19*num_samples] == 2], 
                                 downsampled_SIDataStanding20[labels[19*num_samples:20*num_samples] == 2], 
                                 downsampled_SIDataStanding21[labels[20*num_samples:] == 2]), axis=0)

# Determine which original data each group belongs to
group_1_data = []
group_1_origins = []
group_1_origin_sizes = {}
group_2_data = []
group_2_origins = []
group_2_origin_sizes = {}
group_3_data = []
group_3_origins = []
group_3_origin_sizes = {}

for index in group_1_indices:
    if index < len(FPDataStanding1Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding1Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding2Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding3Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding4Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding5Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding6Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding7Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding8Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding9Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding10Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg):
        group_1_data.append(data[index])
        gorigin = "FPDataStanding11Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding12Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding13Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding14Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding15Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding16Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg) + len(FPDataStanding17Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding17Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg) + len(FPDataStanding17Avg) + len(FPDataStanding18Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding18Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg) + len(FPDataStanding17Avg) + len(FPDataStanding18Avg) + len(FPDataStanding19Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding19Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg) + len(FPDataStanding17Avg) + len(FPDataStanding18Avg) + len(FPDataStanding19Avg) + len(FPDataStanding20Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding20Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg) + len(FPDataStanding17Avg) + len(FPDataStanding18Avg) + len(FPDataStanding19Avg) + len(FPDataStanding20Avg) + len(FPDataStanding21Avg):
        group_1_data.append(data[index])
        origin = "FPDataStanding21Avg"
        group_1_origins.append(origin)
        group_1_origin_sizes[origin] = group_1_origin_sizes.get(origin, 0) + 1

for index in group_2_indices:
    if index < len(FPDataStanding1Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding1Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding2Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding3Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding4Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding5Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding6Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding7Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding8Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding9Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding10Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding11Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding12Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding13Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding14Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding15Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding16Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg) + len(FPDataStanding17Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding17Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) +len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg) + len(FPDataStanding17Avg) + len(FPDataStanding18Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding18Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg) + len(FPDataStanding17Avg) + len(FPDataStanding18Avg) + len(FPDataStanding19Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding19Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg) + len(FPDataStanding17Avg) + len(FPDataStanding18Avg) + len(FPDataStanding19Avg) + len(FPDataStanding20Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding20Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg) + len(FPDataStanding17Avg) + len(FPDataStanding18Avg) + len(FPDataStanding19Avg) + len(FPDataStanding20Avg) + len(FPDataStanding21Avg):
        group_2_data.append(data[index])
        origin = "FPDataStanding21Avg"
        group_2_origins.append(origin)
        group_2_origin_sizes[origin] = group_2_origin_sizes.get(origin, 0) + 1


for index in group_3_indices:
    if index < len(FPDataStanding1Avg):
        group_3_data.append(data[index])
        gorigin = "FPDataStanding1Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding2Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding3Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding4Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding5Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding6Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding7Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding8Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding9Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding10Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding11Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding12Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding13Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding14Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding15Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding16Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg) + len(FPDataStanding17Avg):
        group_3_data.append(data[index])
        gorigin = "FPDataStanding17Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) +len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg) + len(FPDataStanding17Avg) + len(FPDataStanding18Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding18Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg) + len(FPDataStanding17Avg) + len(FPDataStanding18Avg) + len(FPDataStanding19Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding19Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg) + len(FPDataStanding17Avg) + len(FPDataStanding18Avg) + len(FPDataStanding19Avg) + len(FPDataStanding20Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding20Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1
    elif index < len(FPDataStanding1Avg) + len(FPDataStanding2Avg) + len(FPDataStanding3Avg) + len(FPDataStanding4Avg) + len(FPDataStanding5Avg) + len(FPDataStanding6Avg) + len(FPDataStanding7Avg) + len(FPDataStanding8Avg) + len(FPDataStanding9Avg) + len(FPDataStanding10Avg) + len(FPDataStanding11Avg) + len(FPDataStanding12Avg) + len(FPDataStanding13Avg) + len(FPDataStanding14Avg) + len(FPDataStanding15Avg) + len(FPDataStanding16Avg) + len(FPDataStanding17Avg) + len(FPDataStanding18Avg) + len(FPDataStanding19Avg) + len(FPDataStanding20Avg) + len(FPDataStanding21Avg):
        group_3_data.append(data[index])
        origin = "FPDataStanding21Avg"
        group_3_origins.append(origin)
        group_3_origin_sizes[origin] = group_3_origin_sizes.get(origin, 0) + 1

# %%
print("Group 1 Origin Sizes:")
for origin, size in group_1_origin_sizes.items():
    print(f"{origin}: {size}")

print("Group 2 Origin Sizes:")
for origin, size in group_2_origin_sizes.items():
    print(f"{origin}: {size}")

print("Group 3 Origin Sizes:")
for origin, size in group_3_origin_sizes.items():
    print(f"{origin}: {size}")

# %%
group_1_data=np.array(group_1_data)
print(group_1_data.shape)
SIData_group_1=np.array(SIData_group_1)
print(SIData_group_1.shape)
group_2_data=np.array(group_2_data)
print(group_2_data.shape)
SIData_group_2=np.array(SIData_group_2)
print(SIData_group_2.shape)
group_3_data=np.array(group_3_data)
print(group_3_data.shape)
SIData_group_3=np.array(SIData_group_3)
print(SIData_group_3.shape)

# %%
SIDataset = SIData_group_1
FPDataset = group_1_data
print(SIDataset.shape)
print(FPDataset.shape)

# %%
SIDataset1 = SIDataset[:6342]
FPDataset1 = FPDataset[:6342]

SIDataset2 = SIDataset[6342:7842]
FPDataset2 = FPDataset[6342:7842]

SIDataset3 = SIDataset[7842:]
FPDataset3 = FPDataset[7842:]

SIDatasetNew = np.concatenate((SIDataset1,SIDataset3,SIDataset2), axis=0)
FPDatasetNew = np.concatenate((FPDataset1,FPDataset3,FPDataset2), axis=0)
print(SIDatasetNew.shape)
print(FPDatasetNew.shape)

# %%
# x=[]
# colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
# colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
# x = np.arange(0,1500)*10/1500
# for i in range(0,1):
#     plt.figure(figsize=(15,6))
#     # plt.figure()
#     plt.plot(x,FPDataset[11608:13108,i],color='red')
#     plt.title('Resnet Regression (Training Data)')
#     if i < 3:
#       plt.ylabel('Force/'+columns[i])
#     else:
#       plt.ylabel('Moment/'+columns[i])
#     plt.xlabel('Time(s)')
#     plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
#     plt.show()

# %%
import numpy as np
import pandas as pd
# import seaborn as sns
from numpy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Conv2D, MaxPooling2D, Reshape, Flatten, Dense
from keras.models import Model, model_from_json
from keras.optimizers import Adam, RMSprop
# from tensorflow.keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import Normalizer,MinMaxScaler,StandardScaler, RobustScaler, QuantileTransformer, PowerTransformer
# sns.set_theme(style="whitegrid")
import pywt
np.set_printoptions(suppress=True)
# Import ResNet1D Module
from ResNet_1DCNN import ResNet
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error, r2_score

wavelet = 'db4'
max_iter = 5
iter = 0

def seed_everything(seed=42):
    np.random.seed(seed)
    tf.random.set_seed(seed)


# SIDWTcoeffs = []
# for i in range(89):
#     coeffs = pywt.wavedec(SIDataset[:, i], wavelet)
#     coeffs[-1] = np.zeros_like(coeffs[-1])
# #     coeffs[-2] = np.zeros_like(coeffs[-2])
# #     coeffs[-3] = np.zeros_like(coeffs[-3])
# #     coeffs[-4] = np.zeros_like(coeffs[-4])
# #     coeffs[-5] = np.zeros_like(coeffs[-5])
# #     coeffs[-6] = np.zeros_like(coeffs[-6])
#     SIDWTcoeffs.append(coeffs)

# SIData_filtered = np.zeros(SIDataset.shape)
# for i in range(89):
#     SIData_filtered[:, i] = pywt.waverec(SIDWTcoeffs[i], wavelet, mode='symmetric', axis=0)


# mean = 0
# stddev = 0.1
# noise = np.random.normal(mean, stddev, SIDatasetNew.shape)
# SIDatasetNew += noise

max_iter = 5
iter = 0
for i in range(len(SIDatasetNew)):
    SIDatasetNew[i][0] = SIDatasetNew[i][0] + (iter % max_iter) + 1
    iter += 1

# Scale the smart insole data
minInsole = SIDatasetNew.min()
maxInsole = SIDatasetNew.max()
smart_insole_data_scaled = (SIDatasetNew - minInsole) / ( maxInsole - minInsole )

# Scale the force plate data
minForcePlate = FPDatasetNew.min()
maxForcePlate = FPDatasetNew.max()
force_plate_data_scaled = (FPDatasetNew - minForcePlate) / ( maxForcePlate - minForcePlate )


#Spliting Data
sample_size = smart_insole_data_scaled.shape[0] # number of samples in train set
time_steps  = smart_insole_data_scaled.shape[1] # number of features in train set
input_dimension = 1               # each feature is represented by 1 number

train_data_reshaped = smart_insole_data_scaled.reshape(sample_size,time_steps,input_dimension)

# X_train, X_test, y_train, y_test = train_test_split(train_data_reshaped[:13000],
#                                                     force_plate_data_scaled[:13000],
#                                                     test_size=0.20, random_state=2)

smart_insole_data_scaled_Train = train_data_reshaped[:13847]
smart_insole_data_scaled_Test = train_data_reshaped[13847:]
force_plate_data_scaled_Train = force_plate_data_scaled[:13847]
force_plate_data_scaled_Test = force_plate_data_scaled[13847:]

# Generate random indices for shuffling the data
indices = np.arange(smart_insole_data_scaled_Train.shape[0])
np.random.shuffle(indices)

seed_everything(42)
# Use the shuffled indices to randomly select training data
X_train = smart_insole_data_scaled_Train[indices]
y_train = force_plate_data_scaled_Train[indices]

Test_indices = np.arange(smart_insole_data_scaled_Test.shape[0])
np.random.shuffle(Test_indices)

seed_everything(42)
# # Assign the test data
X_test = smart_insole_data_scaled_Test[Test_indices]
y_test = force_plate_data_scaled_Test[Test_indices]

print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)

"Configurations for ResNet in Regression Mode"
length = X_train.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

Regression_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet18()
Regression_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

Regression_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('Saved_Model.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, shuffle=False)

plt.figure()
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
Regression_Model.evaluate(X_train, y_train)
ypred = Regression_Model.predict(X_train)

print('MSE: ',mean_squared_error(y_train, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_train, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_train, ypred))

# # Inverse transform the predictions and actual values
y_pred = (ypred * (maxForcePlate - minForcePlate)) + minForcePlate
y_real = (y_train * (maxForcePlate - minForcePlate)) + minForcePlate

# y_pred = y_pred[np.argsort(indices)]
# y_real = y_real[np.argsort(indices)]

print('MSE: ',mean_squared_error(y_real, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_real, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real, ypred))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real[0:3000,i],color='red')
    plt.plot(x,y_pred[0:3000,i], markerfacecolor='none',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(Regression_Model, '1ouput.h5')
#End Training Process

# Load Model to Predict Real Data
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(X_test, y_test)
Test_Pred = modelCoy.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred))

predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
Real = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions = predictions[np.argsort(Test_indices)]
Real = Real[np.argsort(Test_indices)]

x=[]
x = np.arange(0,991)*10/991
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:991,i],color='red')
    plt.plot(x,predictions[0:991,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
print("sukses")

# %%
import numpy as np
import pandas as pd
# import seaborn as sns
from numpy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Conv2D, MaxPooling2D, Reshape, Flatten, Dense
from keras.models import Model, model_from_json
from keras.optimizers import Adam, RMSprop
# from tensorflow.keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import Normalizer,MinMaxScaler,StandardScaler, RobustScaler, QuantileTransformer, PowerTransformer
# sns.set_theme(style="whitegrid")
import pywt
np.set_printoptions(suppress=True)
# Import ResNet1D Module
from ResNet_11DCNN import ResNet
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error, r2_score

wavelet = 'db4'
max_iter = 5
iter = 0

def seed_everything(seed=42):
    np.random.seed(seed)
    tf.random.set_seed(seed)


# SIDWTcoeffs = []
# for i in range(89):
#     coeffs = pywt.wavedec(SIDataset[:, i], wavelet)
#     coeffs[-1] = np.zeros_like(coeffs[-1])
# #     coeffs[-2] = np.zeros_like(coeffs[-2])
# #     coeffs[-3] = np.zeros_like(coeffs[-3])
# #     coeffs[-4] = np.zeros_like(coeffs[-4])
# #     coeffs[-5] = np.zeros_like(coeffs[-5])
# #     coeffs[-6] = np.zeros_like(coeffs[-6])
#     SIDWTcoeffs.append(coeffs)

# SIData_filtered = np.zeros(SIDataset.shape)
# for i in range(89):
#     SIData_filtered[:, i] = pywt.waverec(SIDWTcoeffs[i], wavelet, mode='symmetric', axis=0)


# mean = 0
# stddev = 0.1
# noise = np.random.normal(mean, stddev, SIDatasetNew.shape)
# SIDatasetNew += noise

max_iter = 5
iter = 0
for i in range(len(SIDatasetNew)):
    SIDatasetNew[i][0] = SIDatasetNew[i][0] + (iter % max_iter) + 1
    iter += 1

# Scale the smart insole data
minInsole = SIDatasetNew.min()
maxInsole = SIDatasetNew.max()
smart_insole_data_scaled = (SIDatasetNew - minInsole) / ( maxInsole - minInsole )

# Scale the force plate data
minForcePlate = FPDatasetNew.min()
maxForcePlate = FPDatasetNew.max()
force_plate_data_scaled = (FPDatasetNew - minForcePlate) / ( maxForcePlate - minForcePlate )


#Spliting Data
sample_size = smart_insole_data_scaled.shape[0] # number of samples in train set
time_steps  = smart_insole_data_scaled.shape[1] # number of features in train set
input_dimension = 1               # each feature is represented by 1 number

train_data_reshaped = smart_insole_data_scaled.reshape(sample_size,time_steps,input_dimension)

# X_train, X_test, y_train, y_test = train_test_split(train_data_reshaped[:13000],
#                                                     force_plate_data_scaled[:13000],
#                                                     test_size=0.20, random_state=2)

smart_insole_data_scaled_Train = train_data_reshaped[:13153]
smart_insole_data_scaled_Test = train_data_reshaped[13153:]
force_plate_data_scaled_Train = force_plate_data_scaled[:13153]
force_plate_data_scaled_Test = force_plate_data_scaled[13153:]

# Generate random indices for shuffling the data
indices = np.arange(smart_insole_data_scaled_Train.shape[0])
np.random.shuffle(indices)

seed_everything(42)
# Use the shuffled indices to randomly select training data
X_train = smart_insole_data_scaled_Train[indices]
y_train = force_plate_data_scaled_Train[indices]

Test_indices = np.arange(smart_insole_data_scaled_Test.shape[0])
np.random.shuffle(Test_indices)

seed_everything(42)
# # Assign the test data
X_test = smart_insole_data_scaled_Test[Test_indices]
y_test = force_plate_data_scaled_Test[Test_indices]

print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)

"Configurations for ResNet in Regression Mode"
length = X_train.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

Regression_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet11()
Regression_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

Regression_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('Saved_Model.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, shuffle=False)

plt.figure()
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
Regression_Model.evaluate(X_train, y_train)
ypred = Regression_Model.predict(X_train)

print('MSE: ',mean_squared_error(y_train, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_train, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_train, ypred))

# # Inverse transform the predictions and actual values
y_pred = (ypred * (maxForcePlate - minForcePlate)) + minForcePlate
y_real = (y_train * (maxForcePlate - minForcePlate)) + minForcePlate

# y_pred = y_pred[np.argsort(indices)]
# y_real = y_real[np.argsort(indices)]

print('MSE: ',mean_squared_error(y_real, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_real, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real, ypred))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real[0:3000,i],color='red')
    plt.plot(x,y_pred[0:3000,i], markerfacecolor='none',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(Regression_Model, '1ouput.h5')
#End Training Process

# Load Model to Predict Real Data
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(X_test, y_test)
Test_Pred = modelCoy.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred))

predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
Real = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions = predictions[np.argsort(Test_indices)]
Real = Real[np.argsort(Test_indices)]

x=[]
x = np.arange(0,991)*10/991
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:991,i],color='red')
    plt.plot(x,predictions[0:991,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
import numpy as np
import pandas as pd
# import seaborn as sns
from numpy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Conv2D, MaxPooling2D, Reshape, Flatten, Dense
from keras.models import Model, model_from_json
from keras.optimizers import Adam, RMSprop
# from tensorflow.keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import Normalizer,MinMaxScaler,StandardScaler, RobustScaler, QuantileTransformer, PowerTransformer
# sns.set_theme(style="whitegrid")
import pywt
np.set_printoptions(suppress=True)
# Import ResNet1D Module
from ResNet_11DCNN import ResNet
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error, r2_score

wavelet = 'db4'
max_iter = 5
iter = 0

def seed_everything(seed=42):
    np.random.seed(seed)
    tf.random.set_seed(seed)


# SIDWTcoeffs = []
# for i in range(89):
#     coeffs = pywt.wavedec(SIDataset[:, i], wavelet)
#     coeffs[-1] = np.zeros_like(coeffs[-1])
# #     coeffs[-2] = np.zeros_like(coeffs[-2])
# #     coeffs[-3] = np.zeros_like(coeffs[-3])
# #     coeffs[-4] = np.zeros_like(coeffs[-4])
# #     coeffs[-5] = np.zeros_like(coeffs[-5])
# #     coeffs[-6] = np.zeros_like(coeffs[-6])
#     SIDWTcoeffs.append(coeffs)

# SIData_filtered = np.zeros(SIDataset.shape)
# for i in range(89):
#     SIData_filtered[:, i] = pywt.waverec(SIDWTcoeffs[i], wavelet, mode='symmetric', axis=0)


# mean = 0
# stddev = 0.1
# noise = np.random.normal(mean, stddev, SIDatasetNew.shape)
# SIDatasetNew += noise

max_iter = 5
iter = 0
for i in range(len(SIDatasetNew)):
    SIDatasetNew[i][0] = SIDatasetNew[i][0] + (iter % max_iter) + 1
    iter += 1

# Scale the smart insole data
minInsole = SIDatasetNew.min()
maxInsole = SIDatasetNew.max()
smart_insole_data_scaled = (SIDatasetNew - minInsole) / ( maxInsole - minInsole )

# Scale the force plate data
minForcePlate = FPDatasetNew.min()
maxForcePlate = FPDatasetNew.max()
force_plate_data_scaled = (FPDatasetNew - minForcePlate) / ( maxForcePlate - minForcePlate )


#Spliting Data
sample_size = smart_insole_data_scaled.shape[0] # number of samples in train set
time_steps  = smart_insole_data_scaled.shape[1] # number of features in train set
input_dimension = 1               # each feature is represented by 1 number

train_data_reshaped = smart_insole_data_scaled.reshape(sample_size,time_steps,input_dimension)

# X_train, X_test, y_train, y_test = train_test_split(train_data_reshaped[:13000],
#                                                     force_plate_data_scaled[:13000],
#                                                     test_size=0.20, random_state=2)

smart_insole_data_scaled_Train = train_data_reshaped[:13153]
smart_insole_data_scaled_Test = train_data_reshaped[13153:]
force_plate_data_scaled_Train = force_plate_data_scaled[:13153]
force_plate_data_scaled_Test = force_plate_data_scaled[13153:]

# Generate random indices for shuffling the data
indices = np.arange(smart_insole_data_scaled_Train.shape[0])
np.random.shuffle(indices)

seed_everything(42)
# Use the shuffled indices to randomly select training data
X_train = smart_insole_data_scaled_Train[indices]
y_train = force_plate_data_scaled_Train[indices]

Test_indices = np.arange(smart_insole_data_scaled_Test.shape[0])
np.random.shuffle(Test_indices)

seed_everything(42)
# # Assign the test data
X_test = smart_insole_data_scaled_Test[Test_indices]
y_test = force_plate_data_scaled_Test[Test_indices]

print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)

"Configurations for ResNet in Regression Mode"
length = X_train.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

Regression_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet18()
Regression_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

Regression_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('Saved_Model.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, shuffle=False)

plt.figure()
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
Regression_Model.evaluate(X_train, y_train)
ypred = Regression_Model.predict(X_train)

print('MSE: ',mean_squared_error(y_train, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_train, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_train, ypred))

# # Inverse transform the predictions and actual values
y_pred = (ypred * (maxForcePlate - minForcePlate)) + minForcePlate
y_real = (y_train * (maxForcePlate - minForcePlate)) + minForcePlate

# y_pred = y_pred[np.argsort(indices)]
# y_real = y_real[np.argsort(indices)]

print('MSE: ',mean_squared_error(y_real, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_real, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real, ypred))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real[0:3000,i],color='red')
    plt.plot(x,y_pred[0:3000,i], markerfacecolor='none',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(Regression_Model, '1ouput.h5')
#End Training Process

# Load Model to Predict Real Data
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(X_test, y_test)
Test_Pred = modelCoy.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred))

predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
Real = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions = predictions[np.argsort(Test_indices)]
Real = Real[np.argsort(Test_indices)]

x=[]
x = np.arange(0,991)*10/991
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:991,i],color='red')
    plt.plot(x,predictions[0:991,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()

# %%
##NEW

# %%
from scipy.spatial.distance import euclidean
from scipy.signal import correlate
from sklearn.cluster import KMeans
from fastdtw import fastdtw
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd

columns = ['Fx']

InsoleStanding1 = pd.read_csv('0310AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding2 = pd.read_csv('0310HudaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding3 = pd.read_csv('0311LalaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding4 = pd.read_csv('0311YunitaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding5 = pd.read_csv('0312AbelStand5Min1.txt', header=None, low_memory=False)
InsoleStanding6 = pd.read_csv('0312AbiStand5Min1.txt', header=None, low_memory=False)
InsoleStanding7 = pd.read_csv('0312AryaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding8 = pd.read_csv('0312HawaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding9 = pd.read_csv('0312NisaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding10 = pd.read_csv('0313ChenChengStand5Min1.txt', header=None, low_memory=False)
InsoleStanding11 = pd.read_csv('0313RezaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding12 = pd.read_csv('0313RilaniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding13 = pd.read_csv('0313SariStand5Min1.txt', header=None, low_memory=False)
InsoleStanding14 = pd.read_csv('0313ShelbyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding15 = pd.read_csv('0314HelenStand5Min1.txt', header=None, low_memory=False)
InsoleStanding16 = pd.read_csv('0315AyuStand5Min1.txt', header=None, low_memory=False)
InsoleStanding17 = pd.read_csv('0315HappyStand5Min1.txt', header=None, low_memory=False)
InsoleStanding18 = pd.read_csv('0317HeniStand5Min1.txt', header=None, low_memory=False)
InsoleStanding19 = pd.read_csv('0317NadiaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding20 = pd.read_csv('0317VikaStand5Min1.txt', header=None, low_memory=False)
InsoleStanding21 = pd.read_csv('0319AlfianStand5Min1.txt', header=None, low_memory=False)
InsoleStanding22 = pd.read_csv('0310JakaStand2Min.txt', header=None, low_memory=False)
SIDatasStanding1 =  np.array(InsoleStanding1)
SIDatasStanding2 =  np.array(InsoleStanding2)
SIDatasStanding3 =  np.array(InsoleStanding3)
SIDatasStanding4 =  np.array(InsoleStanding4)
SIDatasStanding5 =  np.array(InsoleStanding5)
SIDatasStanding6 =  np.array(InsoleStanding6)
SIDatasStanding7 =  np.array(InsoleStanding7)
SIDatasStanding8 =  np.array(InsoleStanding8)
SIDatasStanding9 =  np.array(InsoleStanding9)
SIDatasStanding10 =  np.array(InsoleStanding10)
SIDatasStanding11 =  np.array(InsoleStanding11)
SIDatasStanding12 =  np.array(InsoleStanding12)
SIDatasStanding13 =  np.array(InsoleStanding13)
SIDatasStanding14 =  np.array(InsoleStanding14)
SIDatasStanding15 =  np.array(InsoleStanding15)
SIDatasStanding16 =  np.array(InsoleStanding16)
SIDatasStanding17 =  np.array(InsoleStanding17)
SIDatasStanding18 =  np.array(InsoleStanding18)
SIDatasStanding19 =  np.array(InsoleStanding19)
SIDatasStanding20 =  np.array(InsoleStanding20)
SIDatasStanding21 =  np.array(InsoleStanding21)

dfStanding1 = pd.read_csv('0310AyuStand5Min1.csv', low_memory=False)
dfStanding2 = pd.read_csv('0310HudaStand5Min1.csv', low_memory=False)
dfStanding3 = pd.read_csv('0311LalaStand5Min1.csv', low_memory=False)
dfStanding4 = pd.read_csv('0311YunitaStand5Min1.csv', low_memory=False)
dfStanding5 = pd.read_csv('0312AbelStand5Min1.csv', low_memory=False)
dfStanding6 = pd.read_csv('0312AbiStand5Min1.csv', low_memory=False)
dfStanding7 = pd.read_csv('0312AryaStand5Min1.csv', low_memory=False)
dfStanding8 = pd.read_csv('0312HawaStand5Min1.csv', low_memory=False)
dfStanding9 = pd.read_csv('0312NisaStand5Min1.csv', low_memory=False)
dfStanding10 = pd.read_csv('0313ChenChengStand5Min1.csv', low_memory=False)
dfStanding11 = pd.read_csv('0313RezaStand5Min1.csv', low_memory=False)
dfStanding12 = pd.read_csv('0313RilaniStand5Min1.csv', low_memory=False)
dfStanding13 = pd.read_csv('0313SariStand5Min1.csv', low_memory=False)
dfStanding14 = pd.read_csv('0313ShelbyStand5Min1.csv', low_memory=False)
dfStanding15 = pd.read_csv('0314HelenStand5Min1.csv', low_memory=False)
dfStanding16 = pd.read_csv('0315AyuStand5Min1.csv', low_memory=False)
dfStanding17 = pd.read_csv('0315HappyStand5Min1.csv', low_memory=False)
dfStanding18 = pd.read_csv('0317HeniStand5Min1.csv', low_memory=False)
dfStanding19 = pd.read_csv('0317NadiaStand5Min1.csv', low_memory=False)
dfStanding20 = pd.read_csv('0317VikaStand5Min1.csv', low_memory=False)
dfStanding21 = pd.read_csv('0319AlfianStand5Min1.csv', low_memory=False)

selected_dfStandings1 = dfStanding1[columns]
selected_dfStandings2 = dfStanding2[columns]
selected_dfStandings3 = dfStanding3[columns]
selected_dfStandings4 = dfStanding4[columns]
selected_dfStandings5 = dfStanding5[columns]
selected_dfStandings6 = dfStanding6[columns]
selected_dfStandings7 = dfStanding7[columns]
selected_dfStandings8 = dfStanding8[columns]
selected_dfStandings9 = dfStanding9[columns]
selected_dfStandings10 = dfStanding10[columns]
selected_dfStandings11 = dfStanding11[columns]
selected_dfStandings12 = dfStanding12[columns]
selected_dfStandings13 = dfStanding13[columns]
selected_dfStandings14 = dfStanding14[columns]
selected_dfStandings15 = dfStanding15[columns]
selected_dfStandings16 = dfStanding16[columns]
selected_dfStandings17 = dfStanding17[columns]
selected_dfStandings18 = dfStanding18[columns]
selected_dfStandings19 = dfStanding19[columns]
selected_dfStandings20 = dfStanding20[columns]
selected_dfStandings21 = dfStanding21[columns]
FPDataStandings1 = selected_dfStandings1[:15000]
FPDataStandings2 = selected_dfStandings2[:15000]
FPDataStandings3 = selected_dfStandings3[:15000]
FPDataStandings4 = selected_dfStandings4[:15000]
FPDataStandings5 = selected_dfStandings5[:15000]
FPDataStandings6 = selected_dfStandings6[:15000]
FPDataStandings7 = selected_dfStandings7[:15000]
FPDataStandings8 = selected_dfStandings8[:15000]
FPDataStandings9 = selected_dfStandings9[:15000]
FPDataStandings10 = selected_dfStandings10[:15000]
FPDataStandings11 = selected_dfStandings11[:15000]
FPDataStandings12 = selected_dfStandings12[:15000]
FPDataStandings13 = selected_dfStandings13[:15000]
FPDataStandings14 = selected_dfStandings14[:15000]
FPDataStandings15 = selected_dfStandings15[:15000]
FPDataStandings16 = selected_dfStandings16[:15000]
FPDataStandings17 = selected_dfStandings17[:15000]
FPDataStandings18 = selected_dfStandings18[:15000]
FPDataStandings19 = selected_dfStandings19[:15000]
FPDataStandings20 = selected_dfStandings20[:15000]
FPDataStandings21 = selected_dfStandings21[:15000]

SIDataStanding1 = np.array(SIDatasStanding1[:15000]).astype('float64')
SIDataStanding2 = np.array(SIDatasStanding2[:15000]).astype('float64')
SIDataStanding3 = np.array(SIDatasStanding3[:15000]).astype('float64')
SIDataStanding4 = np.array(SIDatasStanding4[:15000]).astype('float64')
SIDataStanding5 = np.array(SIDatasStanding5[:15000]).astype('float64')
SIDataStanding6 = np.array(SIDatasStanding6[:15000]).astype('float64')
SIDataStanding7 = np.array(SIDatasStanding7[:15000]).astype('float64')
SIDataStanding8 = np.array(SIDatasStanding8[:15000]).astype('float64')
SIDataStanding9 = np.array(SIDatasStanding9[:15000]).astype('float64')
SIDataStanding10 = np.array(SIDatasStanding10[:15000]).astype('float64')
SIDataStanding11 = np.array(SIDatasStanding11[:15000]).astype('float64')
SIDataStanding12 = np.array(SIDatasStanding12[:15000]).astype('float64')
SIDataStanding13 = np.array(SIDatasStanding13[:15000]).astype('float64')
SIDataStanding14 = np.array(SIDatasStanding14[:15000]).astype('float64')
SIDataStanding15 = np.array(SIDatasStanding15[:15000]).astype('float64')
SIDataStanding16 = np.array(SIDatasStanding16[:15000]).astype('float64')
SIDataStanding17 = np.array(SIDatasStanding17[:15000]).astype('float64')
SIDataStanding18 = np.array(SIDatasStanding18[:15000]).astype('float64')
SIDataStanding19 = np.array(SIDatasStanding19[:15000]).astype('float64')
SIDataStanding20 = np.array(SIDatasStanding20[:15000]).astype('float64')
SIDataStanding21 = np.array(SIDatasStanding21[:15000]).astype('float64')
FPDataStanding1 = np.array(FPDataStandings1).astype('float64')
FPDataStanding2 = np.array(FPDataStandings2).astype('float64')
FPDataStanding3= np.array(FPDataStandings3).astype('float64')
FPDataStanding4= np.array(FPDataStandings4).astype('float64')
FPDataStanding5= np.array(FPDataStandings5).astype('float64')
FPDataStanding6= np.array(FPDataStandings6).astype('float64')
FPDataStanding7= np.array(FPDataStandings7).astype('float64')
FPDataStanding8= np.array(FPDataStandings8).astype('float64')
FPDataStanding9= np.array(FPDataStandings9).astype('float64')
FPDataStanding10 = np.array(FPDataStandings10).astype('float64')
FPDataStanding11 = np.array(FPDataStandings11).astype('float64')
FPDataStanding12= np.array(FPDataStandings12).astype('float64')
FPDataStanding13= np.array(FPDataStandings13).astype('float64')
FPDataStanding14= np.array(FPDataStandings14).astype('float64')
FPDataStanding15= np.array(FPDataStandings15).astype('float64')
FPDataStanding16= np.array(FPDataStandings16).astype('float64')
FPDataStanding17= np.array(FPDataStandings17).astype('float64')
FPDataStanding18= np.array(FPDataStandings18).astype('float64')
FPDataStanding19= np.array(FPDataStandings19).astype('float64')
FPDataStanding20= np.array(FPDataStandings20).astype('float64')
FPDataStanding21= np.array(FPDataStandings21).astype('float64')

FPDataStanding1 = FPDataStanding1.reshape(1500,10,1)
FPDataStanding2 = FPDataStanding2.reshape(1500,10,1)
FPDataStanding3 = FPDataStanding3.reshape(1500,10,1)
FPDataStanding4 = FPDataStanding4.reshape(1500,10,1)
FPDataStanding5 = FPDataStanding5.reshape(1500,10,1)
FPDataStanding6 = FPDataStanding6.reshape(1500,10,1)
FPDataStanding7 = FPDataStanding7.reshape(1500,10,1)
FPDataStanding8 = FPDataStanding8.reshape(1500,10,1)
FPDataStanding9 = FPDataStanding9.reshape(1500,10,1)
FPDataStanding10 = FPDataStanding10.reshape(1500,10,1)
FPDataStanding11 = FPDataStanding11.reshape(1500,10,1)
FPDataStanding12 = FPDataStanding12.reshape(1500,10,1)
FPDataStanding13 = FPDataStanding13.reshape(1500,10,1)
FPDataStanding14 = FPDataStanding14.reshape(1500,10,1)
FPDataStanding15 = FPDataStanding15.reshape(1500,10,1)
FPDataStanding16 = FPDataStanding16.reshape(1500,10,1)
FPDataStanding17 = FPDataStanding17.reshape(1500,10,1)
FPDataStanding18 = FPDataStanding18.reshape(1500,10,1)
FPDataStanding19 = FPDataStanding19.reshape(1500,10,1)
FPDataStanding20 = FPDataStanding20.reshape(1500,10,1)
FPDataStanding21 = FPDataStanding21.reshape(1500,10,1)

FPDataStanding1Avg = np.average(FPDataStanding1, axis=1)
FPDataStanding2Avg = np.average(FPDataStanding2, axis=1)
FPDataStanding3Avg = np.average(FPDataStanding3, axis=1)
FPDataStanding4Avg = np.average(FPDataStanding4, axis=1)
FPDataStanding5Avg = np.average(FPDataStanding5, axis=1)
FPDataStanding6Avg = np.average(FPDataStanding6, axis=1)
FPDataStanding7Avg = np.average(FPDataStanding7, axis=1)
FPDataStanding8Avg = np.average(FPDataStanding8, axis=1)
FPDataStanding9Avg = np.average(FPDataStanding9, axis=1)
FPDataStanding10Avg = np.average(FPDataStanding10, axis=1)
FPDataStanding11Avg = np.average(FPDataStanding11, axis=1)
FPDataStanding12Avg = np.average(FPDataStanding12, axis=1)
FPDataStanding13Avg = np.average(FPDataStanding13, axis=1)
FPDataStanding14Avg = np.average(FPDataStanding14, axis=1)
FPDataStanding15Avg = np.average(FPDataStanding15, axis=1)
FPDataStanding16Avg = np.average(FPDataStanding16, axis=1)
FPDataStanding17Avg = np.average(FPDataStanding17, axis=1)
FPDataStanding18Avg = np.average(FPDataStanding18, axis=1)
FPDataStanding19Avg = np.average(FPDataStanding19, axis=1)
FPDataStanding20Avg = np.average(FPDataStanding20, axis=1)
FPDataStanding21Avg = np.average(FPDataStanding21, axis=1)

downsampled_SIDataStanding1 = SIDataStanding1[::10]
downsampled_SIDataStanding2 = SIDataStanding2[::10]
downsampled_SIDataStanding3 = SIDataStanding3[::10]
downsampled_SIDataStanding4 = SIDataStanding4[::10]
downsampled_SIDataStanding5 = SIDataStanding5[::10]
downsampled_SIDataStanding6 = SIDataStanding6[::10]
downsampled_SIDataStanding7 = SIDataStanding7[::10]
downsampled_SIDataStanding8 = SIDataStanding8[::10]
downsampled_SIDataStanding9 = SIDataStanding9[::10]
downsampled_SIDataStanding10 = SIDataStanding10[::10]
downsampled_SIDataStanding11 = SIDataStanding11[::10]
downsampled_SIDataStanding12 = SIDataStanding12[::10]
downsampled_SIDataStanding13 = SIDataStanding13[::10]
downsampled_SIDataStanding14 = SIDataStanding14[::10]
downsampled_SIDataStanding15 = SIDataStanding15[::10]
downsampled_SIDataStanding16 = SIDataStanding16[::10]
downsampled_SIDataStanding17 = SIDataStanding17[::10]
downsampled_SIDataStanding18 = SIDataStanding18[::10]
downsampled_SIDataStanding19 = SIDataStanding19[::10]
downsampled_SIDataStanding20 = SIDataStanding20[::10]
downsampled_SIDataStanding21 = SIDataStanding21[::10]


# Combine the 21 datasets into one
sequences = [FPDataStanding1Avg, FPDataStanding2Avg, FPDataStanding3Avg, 
             FPDataStanding4Avg, FPDataStanding5Avg, FPDataStanding6Avg, 
             FPDataStanding7Avg, FPDataStanding8Avg, FPDataStanding9Avg, 
             FPDataStanding10Avg, FPDataStanding11Avg, FPDataStanding12Avg, 
             FPDataStanding13Avg, FPDataStanding14Avg,  FPDataStanding15Avg, 
             FPDataStanding16Avg, FPDataStanding17Avg, FPDataStanding18Avg,
             FPDataStanding19Avg, FPDataStanding20Avg, FPDataStanding21Avg]

SI_sequences = [downsampled_SIDataStanding1, downsampled_SIDataStanding2, downsampled_SIDataStanding3, 
             downsampled_SIDataStanding4, downsampled_SIDataStanding5, downsampled_SIDataStanding6, 
             downsampled_SIDataStanding7, downsampled_SIDataStanding8, downsampled_SIDataStanding9, 
             downsampled_SIDataStanding10, downsampled_SIDataStanding11, downsampled_SIDataStanding12, 
             downsampled_SIDataStanding13, downsampled_SIDataStanding14,  downsampled_SIDataStanding15, 
             downsampled_SIDataStanding16, downsampled_SIDataStanding17, downsampled_SIDataStanding18,
             downsampled_SIDataStanding19, downsampled_SIDataStanding20, downsampled_SIDataStanding21]

# sequences = [FPDataStanding1, FPDataStanding2, FPDataStanding3, 
#              FPDataStanding4, FPDataStanding5, FPDataStanding6, 
#              FPDataStanding7, FPDataStanding8, FPDataStanding9, 
#              FPDataStanding10, FPDataStanding11, FPDataStanding12, 
#              FPDataStanding13, FPDataStanding14,  FPDataStanding15, 
#              FPDataStanding16, FPDataStanding17, FPDataStanding18,
#              FPDataStanding19, FPDataStanding20, FPDataStanding21]

# SI_sequences = [SIDataStanding1, SIDataStanding2, SIDataStanding3, 
#              SIDataStanding4, SIDataStanding5, SIDataStanding6, 
#              SIDataStanding7, SIDataStanding8, SIDataStanding9, 
#              SIDataStanding10, SIDataStanding11, SIDataStanding12, 
#              SIDataStanding13, SIDataStanding14,  SIDataStanding15, 
#              SIDataStanding16, SIDataStanding17, SIDataStanding18,
#              SIDataStanding19, SIDataStanding20, SIDataStanding21]


# Mapping of index to sequence name
sequence_names = {
    0: "FPDataStanding1",
    1: "FPDataStanding2",
    2: "FPDataStanding3",
    3: "FPDataStanding4",
    4: "FPDataStanding5",
    5: "FPDataStanding6",
    6: "FPDataStanding7",
    7: "FPDataStanding8",
    8: "FPDataStanding9",
    9: "FPDataStanding10",
    10: "FPDataStanding11",
    11: "FPDataStanding12",
    12: "FPDataStanding13",
    13: "FPDataStanding14",
    14: "FPDataStanding15",
    15: "FPDataStanding16",
    16: "FPDataStanding17",
    17: "FPDataStanding18",
    18: "FPDataStanding19",
    19: "FPDataStanding20",
    20: "FPDataStanding21"
}

SI_original_dataset_names = {
    0: "SIDataStanding1",
    1: "SIDataStanding2",
    2: "SIDataStanding3",
    3: "SIDataStanding4",
    4: "SIDataStanding5",
    5: "SIDataStanding6",
    6: "SIDataStanding7",
    7: "SIDataStanding8",
    8: "SIDataStanding9",
    9: "SIDataStanding10",
    10: "SIDataStanding11",
    11: "SIDataStanding12",
    12: "SIDataStanding13",
    13: "SIDataStanding14",
    14: "SIDataStanding15",
    15: "SIDataStanding16",
    16: "SIDataStanding17",
    17: "SIDataStanding18",
    18: "SIDataStanding19",
    19: "SIDataStanding20",
    20: "SIDataStanding21"
}

# Compute pairwise DTW distances between time series
distances = np.zeros((len(sequences), len(sequences)))
for i in range(len(sequences)):
    for j in range(i+1, len(sequences)):
        distance, path = fastdtw(sequences[i], sequences[j], dist=euclidean)
        distances[i, j] = distance
        distances[j, i] = distance

# Perform K-means clustering with 3 clusters
kmeans = KMeans(n_clusters=3)
kmeans.fit(distances)

# Get the cluster labels
labels = kmeans.labels_

# Initialize dictionaries for each group
group_1_data = []
group_1_origins = []
group_1_origin_sizes = {}
group_2_data = []
group_2_origins = []
group_2_origin_sizes = {}
group_3_data = []
group_3_origins = []
group_3_origin_sizes = {}


group1_data = {}
group2_data = {}
group3_data = {}

SI_group1_data = {}
SI_group2_data = {}
SI_group3_data = {}

SIData_group_1 = []
SIData_group_2 = []
SIData_group_3 = []


# Loop through all the labels
for i, label in enumerate(labels):
    # Append the corresponding sequence to the appropriate group
    if label == 0:
        group1_data[sequence_names[i]] = sequences[i]
        group_1_data.append(sequences[i])
        SI_group1_data[SI_original_dataset_names[i]] = SI_sequences[i]
        SIData_group_1.append(SI_sequences[i])
    elif label == 1:
        group2_data[sequence_names[i]] = sequences[i]
        group_2_data.append(sequences[i])
        SI_group2_data[SI_original_dataset_names[i]] = SI_sequences[i]
        SIData_group_2.append(SI_sequences[i])
    else:  # label == 2
        group3_data[sequence_names[i]] = sequences[i]
        group_3_data.append(sequences[i])
        SI_group3_data[SI_original_dataset_names[i]] = SI_sequences[i]
        SIData_group_3.append(SI_sequences[i])

# Print the data of each group and associated original dataset names
print("Group 1 data:")
for dataset_name, data in group1_data.items():
    print(f"{dataset_name}:{len(data)}")

print("Group 1 SI data:")
for dataset_name, data in SI_group1_data.items():
    print(f"{dataset_name}:{len(data)}")

print("\nGroup 2 data:")
for dataset_name, data in group2_data.items():
     print(f"{dataset_name}:{len(data)}")

print("Group 2 SI data:")
for dataset_name, data in SI_group2_data.items():
    print(f"{dataset_name}:{len(data)}")

print("\nGroup 3 data:")
for dataset_name, data in group3_data.items():
    print(f"{dataset_name}:{len(data)}")

print("Group 3 SI data:")
for dataset_name, data in SI_group3_data.items():
    print(f"{dataset_name}:{len(data)}")
# Out:
# Group 1 data:
# FPDataStanding1:1500
# FPDataStanding3:1500
# FPDataStanding4:1500
# FPDataStanding6:1500
# FPDataStanding7:1500
# FPDataStanding8:1500
# FPDataStanding9:1500
# FPDataStanding10:1500
# FPDataStanding11:1500
# FPDataStanding16:1500
# FPDataStanding19:1500
# Group 1 SI data:
# SIDataStanding1:1500
# SIDataStanding3:1500
# SIDataStanding4:1500
# SIDataStanding6:1500
# SIDataStanding7:1500
# SIDataStanding8:1500
# SIDataStanding9:1500
# SIDataStanding10:1500
# SIDataStanding11:1500
# SIDataStanding16:1500
# SIDataStanding19:1500
#
# Group 2 data:
# FPDataStanding5:1500
# FPDataStanding12:1500
# FPDataStanding13:1500
# FPDataStanding14:1500
# FPDataStanding15:1500
# FPDataStanding17:1500
# FPDataStanding18:1500
# FPDataStanding20:1500
# FPDataStanding21:1500
# Group 2 SI data:
# SIDataStanding5:1500
# SIDataStanding12:1500
# SIDataStanding13:1500
# SIDataStanding14:1500
# SIDataStanding15:1500
# SIDataStanding17:1500
# SIDataStanding18:1500
# SIDataStanding20:1500
# ...

# %%
group_1_data=np.array(group_1_data).reshape(-1,1)
print(group_1_data.shape)
SIData_group_1=np.array(SIData_group_1).reshape(-1,89)
print(SIData_group_1.shape)
group_2_data=np.array(group_2_data).reshape(-1,1)
print(group_2_data.shape)
SIData_group_2=np.array(SIData_group_2).reshape(-1,89)
print(SIData_group_2.shape)
group_3_data=np.array(group_3_data).reshape(-1,1)
print(group_3_data.shape)
SIData_group_3=np.array(SIData_group_3).reshape(-1,89)
print(SIData_group_3.shape)

# (135000, 1)
# (9, 15000, 89) How to reshape it to (135000,89)
# (165000, 1)
# (11, 15000, 89) How to reshape it to (165000,89)
# (15000, 1)
# (1, 15000, 89) How to reshape it to (15000,89)
# Out:
# (16500, 1)
# (16500, 89)
# (13500, 1)
# (13500, 89)
# (1500, 1)
# (1500, 89)

# %%
SIDataset = SIData_group_1
FPDataset = group_1_data
print(SIDataset.shape)
print(FPDataset.shape)

SIDataset1 = SIDataset[:6000]
FPDataset1 = FPDataset[:6000]

SIDataset2 = SIDataset[6000:7500]
FPDataset2 = FPDataset[6000:7500]

SIDataset3 = SIDataset[7500:]
FPDataset3 = FPDataset[7500:]

SIDatasetNew = np.concatenate((SIDataset1,SIDataset3,SIDataset2), axis=0)
FPDatasetNew = np.concatenate((FPDataset1,FPDataset3,FPDataset2), axis=0)
print(SIDatasetNew.shape)
print(FPDatasetNew.shape)
# Out:
# (16500, 89)
# (16500, 1)
# (16500, 89)
# (16500, 1)

# %%
import numpy as np
import pandas as pd
# import seaborn as sns
from numpy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Conv2D, MaxPooling2D, Reshape, Flatten, Dense
from keras.models import Model, model_from_json
from keras.optimizers import Adam, RMSprop
# from tensorflow.keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import Normalizer,MinMaxScaler,StandardScaler, RobustScaler, QuantileTransformer, PowerTransformer
# sns.set_theme(style="whitegrid")
import pywt
np.set_printoptions(suppress=True)
# Import ResNet1D Module
from ResNet_12DCNN import ResNet
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error, r2_score

def seed_everything(seed=42):
    np.random.seed(seed)
    tf.random.set_seed(seed)


# SIDWTcoeffs = []
# for i in range(89):
#     coeffs = pywt.wavedec(SIDataset[:, i], wavelet)
#     coeffs[-1] = np.zeros_like(coeffs[-1])
# #     coeffs[-2] = np.zeros_like(coeffs[-2])
# #     coeffs[-3] = np.zeros_like(coeffs[-3])
# #     coeffs[-4] = np.zeros_like(coeffs[-4])
# #     coeffs[-5] = np.zeros_like(coeffs[-5])
# #     coeffs[-6] = np.zeros_like(coeffs[-6])
#     SIDWTcoeffs.append(coeffs)

# SIData_filtered = np.zeros(SIDataset.shape)
# for i in range(89):
#     SIData_filtered[:, i] = pywt.waverec(SIDWTcoeffs[i], wavelet, mode='symmetric', axis=0)


# mean = 0
# stddev = 0.1
# noise = np.random.normal(mean, stddev, SIDatasetNew.shape)
# SIDatasetNew += noise

max_iter = 5
iter = 0
for i in range(len(SIDatasetNew)):
    SIDatasetNew[i][0] = SIDatasetNew[i][0] + (iter % max_iter) + 1
    iter += 1

# Scale the smart insole data
minInsole = SIDatasetNew.min()
maxInsole = SIDatasetNew.max()
smart_insole_data_scaled = (SIDatasetNew - minInsole) / ( maxInsole - minInsole )

# Scale the force plate data
minForcePlate = FPDatasetNew.min()
maxForcePlate = FPDatasetNew.max()
force_plate_data_scaled = (FPDatasetNew - minForcePlate) / ( maxForcePlate - minForcePlate )


#Spliting Data
sample_size = smart_insole_data_scaled.shape[0] # number of samples in train set
time_steps  = smart_insole_data_scaled.shape[1] # number of features in train set
input_dimension = 1               # each feature is represented by 1 number

train_data_reshaped = smart_insole_data_scaled.reshape(sample_size,time_steps,input_dimension)

# X_train, X_test, y_train, y_test = train_test_split(train_data_reshaped[:13000],
#                                                     force_plate_data_scaled[:13000],
#                                                     test_size=0.20, random_state=2)

smart_insole_data_scaled_Train = train_data_reshaped[:15000]
smart_insole_data_scaled_Test = train_data_reshaped[15000:]
force_plate_data_scaled_Train = force_plate_data_scaled[:15000]
force_plate_data_scaled_Test = force_plate_data_scaled[15000:]

# Generate random indices for shuffling the data
indices = np.arange(smart_insole_data_scaled_Train.shape[0])
np.random.shuffle(indices)

seed_everything(42)
# Use the shuffled indices to randomly select training data
X_train = smart_insole_data_scaled_Train[indices]
y_train = force_plate_data_scaled_Train[indices]

Test_indices = np.arange(smart_insole_data_scaled_Test.shape[0])
np.random.shuffle(Test_indices)

seed_everything(42)
# # Assign the test data
X_test = smart_insole_data_scaled_Test[Test_indices]
y_test = force_plate_data_scaled_Test[Test_indices]

print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)

"Configurations for ResNet in Regression Mode"
length = X_train.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

Regression_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet50()
Regression_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

Regression_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('Saved_Model.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, shuffle=False)

plt.figure()
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
Regression_Model.evaluate(X_train, y_train)
ypred = Regression_Model.predict(X_train)

print('MSE: ',mean_squared_error(y_train, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_train, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_train, ypred))

# # Inverse transform the predictions and actual values
y_pred = (ypred * (maxForcePlate - minForcePlate)) + minForcePlate
y_real = (y_train * (maxForcePlate - minForcePlate)) + minForcePlate

# y_pred = y_pred[np.argsort(indices)]
# y_real = y_real[np.argsort(indices)]

print('MSE: ',mean_squared_error(y_real, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_real, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real, ypred))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real[0:3000,i],color='red')
    plt.plot(x,y_pred[0:3000,i], markerfacecolor='none',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(Regression_Model, '1ouput.h5')
#End Training Process

# Load Model to Predict Real Data
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(X_test, y_test)
Test_Pred = modelCoy.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred))

predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
Real = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions = predictions[np.argsort(Test_indices)]
Real = Real[np.argsort(Test_indices)]

x=[]
x = np.arange(0,991)*10/991
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:991,i],color='red')
    plt.plot(x,predictions[0:991,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()
# Out:
# (15000, 89, 1) (1500, 89, 1)
# (15000, 1) (1500, 1)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 89, 1)]      0           []
#
#  conv1d (Conv1D)                (None, 45, 64)       512         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 45, 64)      256         ['conv1d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 45, 64)       0           ['batch_normalization[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 22, 64)       0           ['activation[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 22, 64)       4160        ['max_pooling1d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 22, 64)      256         ['conv1d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 22, 64)       0           ['batch_normalization_2[0][0]']
#
# ...

# %%
import numpy as np
import pandas as pd
# import seaborn as sns
from numpy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Conv2D, MaxPooling2D, Reshape, Flatten, Dense
from keras.models import Model, model_from_json
from keras.optimizers import Adam, RMSprop
# from tensorflow.keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import Normalizer,MinMaxScaler,StandardScaler, RobustScaler, QuantileTransformer, PowerTransformer
# sns.set_theme(style="whitegrid")
import pywt
np.set_printoptions(suppress=True)
# Import ResNet1D Module
from ResNet_12DCNN import ResNet
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error, r2_score

def seed_everything(seed=42):
    np.random.seed(seed)
    tf.random.set_seed(seed)


# SIDWTcoeffs = []
# for i in range(89):
#     coeffs = pywt.wavedec(SIDataset[:, i], wavelet)
#     coeffs[-1] = np.zeros_like(coeffs[-1])
# #     coeffs[-2] = np.zeros_like(coeffs[-2])
# #     coeffs[-3] = np.zeros_like(coeffs[-3])
# #     coeffs[-4] = np.zeros_like(coeffs[-4])
# #     coeffs[-5] = np.zeros_like(coeffs[-5])
# #     coeffs[-6] = np.zeros_like(coeffs[-6])
#     SIDWTcoeffs.append(coeffs)

# SIData_filtered = np.zeros(SIDataset.shape)
# for i in range(89):
#     SIData_filtered[:, i] = pywt.waverec(SIDWTcoeffs[i], wavelet, mode='symmetric', axis=0)


# mean = 0
# stddev = 0.1
# noise = np.random.normal(mean, stddev, SIDatasetNew.shape)
# SIDatasetNew += noise

max_iter = 5
iter = 0
for i in range(len(SIDatasetNew)):
    SIDatasetNew[i][0] = SIDatasetNew[i][0] + (iter % max_iter) + 1
    iter += 1

# Scale the smart insole data
minInsole = SIDatasetNew.min()
maxInsole = SIDatasetNew.max()
smart_insole_data_scaled = (SIDatasetNew - minInsole) / ( maxInsole - minInsole )

# Scale the force plate data
minForcePlate = FPDatasetNew.min()
maxForcePlate = FPDatasetNew.max()
force_plate_data_scaled = (FPDatasetNew - minForcePlate) / ( maxForcePlate - minForcePlate )


#Spliting Data
sample_size = smart_insole_data_scaled.shape[0] # number of samples in train set
time_steps  = smart_insole_data_scaled.shape[1] # number of features in train set
input_dimension = 1               # each feature is represented by 1 number

train_data_reshaped = smart_insole_data_scaled.reshape(sample_size,time_steps,input_dimension)

# X_train, X_test, y_train, y_test = train_test_split(train_data_reshaped[:13000],
#                                                     force_plate_data_scaled[:13000],
#                                                     test_size=0.20, random_state=2)

smart_insole_data_scaled_Train = train_data_reshaped[:15000]
smart_insole_data_scaled_Test = train_data_reshaped[15000:]
force_plate_data_scaled_Train = force_plate_data_scaled[:15000]
force_plate_data_scaled_Test = force_plate_data_scaled[15000:]

# Generate random indices for shuffling the data
indices = np.arange(smart_insole_data_scaled_Train.shape[0])
np.random.shuffle(indices)

seed_everything(42)
# Use the shuffled indices to randomly select training data
X_train = smart_insole_data_scaled_Train[indices]
y_train = force_plate_data_scaled_Train[indices]

Test_indices = np.arange(smart_insole_data_scaled_Test.shape[0])
np.random.shuffle(Test_indices)

seed_everything(42)
# # Assign the test data
X_test = smart_insole_data_scaled_Test[Test_indices]
y_test = force_plate_data_scaled_Test[Test_indices]

print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)

"Configurations for ResNet in Regression Mode"
length = X_train.shape[1]   # Number of Features (or length of the signal)
model_width = 64           # Number of Filter or Kernel in the Input Layer
num_channel = 1             # Number of Input Channels
problem_type = 'Regression' # Regression or Classification
output_number = 1           # Number of Outputs in the Regression Mode

Regression_Model = ResNet(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_number).ResNet18()
Regression_Model.compile(loss='mse', optimizer=Adam(learning_rate=0.0001), metrics= ['mse']) # Compile Model

Regression_Model.summary()

callbacks = [EarlyStopping(monitor='val_loss', patience=30, mode='min'), ModelCheckpoint('Saved_Model.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='min')]
# history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, validation_split=0.2, shuffle=True)
seed_everything(42)
history = Regression_Model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1, shuffle=False)

plt.figure()
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# plt.show()
plt.savefig('Loss Result.png')

#Evaluate Model
Regression_Model.evaluate(X_train, y_train)
ypred = Regression_Model.predict(X_train)

print('MSE: ',mean_squared_error(y_train, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_train, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_train, ypred))

# # Inverse transform the predictions and actual values
y_pred = (ypred * (maxForcePlate - minForcePlate)) + minForcePlate
y_real = (y_train * (maxForcePlate - minForcePlate)) + minForcePlate

# y_pred = y_pred[np.argsort(indices)]
# y_real = y_real[np.argsort(indices)]

print('MSE: ',mean_squared_error(y_real, ypred))
print('RMSE: ',math.sqrt(mean_squared_error(y_real, ypred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_real, ypred))

x=[]
colors=['red','green','brown','teal','gray','black','maroon','orange','purple']
colors2=['green','red','orange','black','maroon','teal','blue','gray','brown']
x = np.arange(0,3000)*60/3000
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,y_real[0:3000,i],color='red')
    plt.plot(x,y_pred[0:3000,i], markerfacecolor='none',color='green')
    plt.title('Resnet Regression (Training Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted Value'], loc='best')
    plt.show()

tf.keras.models.save_model(Regression_Model, '1ouput.h5')
#End Training Process

# Load Model to Predict Real Data
modelCoy = tf.keras.models.load_model('1ouput.h5')

modelCoy.evaluate(X_test, y_test)
Test_Pred = modelCoy.predict(X_test)

print('MSE: ',mean_squared_error(y_test, Test_Pred))
print('RMSE: ',math.sqrt(mean_squared_error(y_test, Test_Pred)))
print('Coefficient of determination (r2 Score): ', r2_score(y_test, Test_Pred))

predictions = (Test_Pred * (maxForcePlate - minForcePlate)) + minForcePlate
Real = (y_test * (maxForcePlate - minForcePlate)) + minForcePlate

predictions = predictions[np.argsort(Test_indices)]
Real = Real[np.argsort(Test_indices)]

x=[]
x = np.arange(0,991)*10/991
for i in range(0,1):
    plt.figure(figsize=(15,6))
    # plt.figure()
    plt.plot(x,Real[0:991,i],color='red')
    plt.plot(x,predictions[0:991,i], markerfacecolor='none',color='green')
    plt.title('ResNet Regression (Testing Data)')
    if i < 3:
      plt.ylabel('Force/'+columns[i])
    else:
      plt.ylabel('Moment/'+columns[i])
    plt.xlabel('Time(s)')
    plt.legend(['Groundtruth', 'Predicted'], loc='best')
    plt.show()
# Out:
# (15000, 89, 1) (1500, 89, 1)
# (15000, 1) (1500, 1)
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 89, 1)]      0           []
#
#  conv1d_59 (Conv1D)             (None, 45, 64)       512         ['input_2[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 45, 64)      256         ['conv1d_59[0][0]']
#  ormalization)
#
#  activation_72 (Activation)     (None, 45, 64)       0           ['batch_normalization_59[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 22, 64)      0           ['activation_72[0][0]']
#
#  conv1d_60 (Conv1D)             (None, 22, 64)       12352       ['max_pooling1d_1[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 22, 64)      256         ['conv1d_60[0][0]']
#  ormalization)
#
# ...
